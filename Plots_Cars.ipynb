# %% [markdown]
# <a href="https://colab.research.google.com/github/TillVollmer5/mass_spectroscopy/blob/main/Plots_Cars.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Plots for the general levels of the different phthalates to create box-whisker plots for the gas phase, particulate matter phases, combined in one plot and seperate in one plot.

# %%
import matplotlib.pyplot as plt
import numpy as np
from google.colab import drive
import pandas as pd
import seaborn as sns
drive.mount('/content/drive', force_remount = True)
# Out:
# Mounted at /content/drive

# %%
#Import of df for samples

Zafira_1_gp_df = pd.read_csv('/content/drive/My Drive/conversion_export/Solvent_100ml_corrected/Sample_63_phthalate_concentration_2023-11-25.csv', header=1) #Blank solvent corrected
Zafira_1_pm_df = pd.read_csv('/content/drive/My Drive/conversion_export/Solvent_100ml_corrected/Sample_64_phthalate_concentration_2023-11-25.csv', header=1) #Blank solvent corrected
Zafira_2_gp_df = pd.read_csv('/content/drive/My Drive/conversion_export/Solvent_100ml_corrected/Sample_65_phthalate_concentration_2023-11-25.csv', header=1) #Blank solvent corrected
Zafira_2_pm_df = pd.read_csv('/content/drive/My Drive/conversion_export/Solvent_100ml_corrected/Sample_66_phthalate_concentration_2023-11-25.csv', header=1) #Blank solvent corrected
Auto_1_gp_df = pd.read_csv('/content/drive/My Drive/conversion_export/Solvent_100ml_corrected/Sample_130_phthalate_concentration_2023-11-25.csv', header=1) #Blank solvent corrected
Auto_1_pm_df = pd.read_csv('/content/drive/My Drive/conversion_export/Solvent_100ml_corrected/Sample_123_phthalate_concentration_2023-11-25.csv', header=1) #Blank solvent corrected
Auto_2_gp_df = pd.read_csv('/content/drive/My Drive/conversion_export/Solvent_100ml_corrected/Sample_144_phthalate_concentration_2023-11-25.csv', header=1) #Blank solvent corrected
Auto_2_pm_df = pd.read_csv('/content/drive/My Drive/conversion_export/Solvent_100ml_corrected/Sample_140_phthalate_concentration_2023-11-25.csv', header=1) #Blank solvent corrected
Auto_3_gp_df = pd.read_csv('/content/drive/My Drive/conversion_export/Sample_155_phthalate_concentration_2023-11-26.csv', header=1) #Blank solvent corrected
Auto_3_pm_df = pd.read_csv('/content/drive/My Drive/conversion_export/Sample_162_phthalate_concentration_2023-11-26.csv', header=1) #Blank solvent corrected

print(Zafira_1_gp_df)
print(Zafira_1_pm_df)
print(Zafira_2_gp_df)
print(Zafira_2_pm_df)
print(Auto_1_gp_df)
print(Auto_1_pm_df)
print(Auto_2_gp_df)
print(Auto_2_pm_df)
print(Auto_3_gp_df)
print(Auto_3_pm_df)
# Out:
#                      Phthalat:  Concentration [ng/m^3]
# 0            Dimethylphthalate                7.926815
# 1             Diethylphthalate              170.870953
# 2             Dibutylphthalate               41.039988
# 3         Benzylbutylphthalate                0.229087
# 4  Bis(2-ethyl-hexyl)phthalate               60.691125
# 5          Di-n-octylphthalate                0.907515
#                      Phthalat:  Concentration [ng/m^3]
# 0            Dimethylphthalate               -0.024527
# 1             Diethylphthalate                6.093230
# 2             Dibutylphthalate               14.264454
# 3         Benzylbutylphthalate                0.595923
# 4  Bis(2-ethyl-hexyl)phthalate               31.670400
# 5          Di-n-octylphthalate                3.077503
#                      Phthalat:  Concentration [ng/m^3]
# 0            Dimethylphthalate                3.110770
# 1             Diethylphthalate               40.989768
# ...

# %%
# Add 'Option' column to each DataFrame
Zafira_1_gp_df['Option'] = 'gp'
Zafira_1_pm_df['Option'] = 'pm'
Zafira_2_gp_df['Option'] = 'gp'
Zafira_2_pm_df['Option'] = 'pm'

# Combine all DataFrames into a single DataFrame
df_combined = pd.concat([Zafira_1_gp_df, Zafira_1_pm_df, Zafira_2_gp_df, Zafira_2_pm_df])

# Set the style to make the plot more readable (optional)
sns.set(style="whitegrid")

# Create a boxplot using seaborn
plt.figure(figsize=(10, 6))  # Adjust the figure size if needed
sns.boxplot(x='Phthalat:', y='Concentration [ng/m^3]', hue='Option', data=df_combined, width=0.6, palette="Set3")

# Add labels and title
plt.xlabel('Data Point')
plt.ylabel('Value')
plt.title('Boxplot for Options A and B')

# Show the plot
plt.show()
# Out:
#                      Phthalat:  Concentration [ng/m^3]
# 0            Dimethylphthalate                7.926815
# 1             Diethylphthalate              170.870953
# 2             Dibutylphthalate               41.039988
# 3         Benzylbutylphthalate                0.229087
# 4  Bis(2-ethyl-hexyl)phthalate               60.691125
# 5          Di-n-octylphthalate                0.907515
#                      Phthalat:  Concentration [ng/m^3]
# 0            Dimethylphthalate               -0.024527
# 1             Diethylphthalate                6.093230
# 2             Dibutylphthalate               14.264454
# 3         Benzylbutylphthalate                0.595923
# 4  Bis(2-ethyl-hexyl)phthalate               31.670400
# 5          Di-n-octylphthalate                3.077503
#                      Phthalat:  Concentration [ng/m^3]
# 0            Dimethylphthalate                3.110770
# 1             Diethylphthalate               40.989768
# ...

# %% [markdown]
# Barebone code for the creation of the boxplot using matplotlib.

# %%
# Add 'Option' column to each DataFrame
Zafira_1_gp_df['Option'] = 'gp'
Zafira_1_pm_df['Option'] = 'pm'
Zafira_2_gp_df['Option'] = 'gp'
Zafira_2_pm_df['Option'] = 'pm'

# Combine all DataFrames into a single DataFrame
df_combined = pd.concat([Zafira_1_gp_df, Zafira_1_pm_df, Zafira_2_gp_df, Zafira_2_pm_df])

# Set the style to make the plot more readable (optional)
plt.figure(figsize=(20, 12))  # Adjust the figure size if needed

# Create a boxplot using matplotlib
bp = df_combined.boxplot(column='Concentration [ng/m^3]', by=['Phthalat:', 'Option'], widths=0.6)

# Customize the plot
plt.suptitle('Boxplot for Options A and B')
plt.xlabel('Data Point')
plt.ylabel('Value')

# Show the plot
plt.show()

# %% [markdown]
# The following would be a boxplot using matplotlib for graphing, which in this case doesn't work due to coloration

# %%
# Add 'Option' column to each DataFrame
Zafira_1_gp_df['Option'] = 'gp'
Zafira_1_pm_df['Option'] = 'pm'
Zafira_2_gp_df['Option'] = 'gp'
Zafira_2_pm_df['Option'] = 'pm'

# Combine all DataFrames into a single DataFrame
df_combined = pd.concat([Zafira_1_gp_df, Zafira_1_pm_df, Zafira_2_gp_df, Zafira_2_pm_df])

# Set the style to make the plot more readable (optional)
plt.figure(figsize=(12, 8))  # Adjust the figure size if needed

# Define colors for 'gp' and 'pm'
colors = {'gp': 'skyblue', 'pm': 'lightcoral'}

# Create a boxplot using matplotlib
bp = df_combined.boxplot(column='Concentration [ng/m^3]', by=['Phthalat:', 'Option'], patch_artist=True, widths=0.6)

# Adjust spacing
bp_spacing = 2.5
for patch in bp.artists:
    current_width = patch.get_width()
    new_width = current_width / bp_spacing
    patch.set_width(new_width)
    patch.set_x(patch.get_x() + (current_width - new_width) / 2)

# Customize the plot
plt.suptitle('Boxplot for Options A and B')
plt.xlabel('Data Point')
plt.ylabel('Value')

# Add legend with correct colors
legend_handles = [plt.Rectangle((0, 0), 1, 1, color=colors[label]) for label in colors]
plt.legend(legend_handles, colors.keys(), title='Options', loc='upper right')

# Show the plot
plt.show()

# %%
# Assuming you have already imported the dataframes
Zafira_1_gp_df = pd.read_csv('/content/drive/My Drive/conversion_export/Solvent_100ml_corrected/Sample_63_phthalate_concentration_2023-11-25.csv', header=1)
Zafira_1_pm_df = pd.read_csv('/content/drive/My Drive/conversion_export/Solvent_100ml_corrected/Sample_64_phthalate_concentration_2023-11-25.csv', header=1)
Zafira_2_gp_df = pd.read_csv('/content/drive/My Drive/conversion_export/Solvent_100ml_corrected/Sample_65_phthalate_concentration_2023-11-25.csv', header=1)
Zafira_2_pm_df = pd.read_csv('/content/drive/My Drive/conversion_export/Solvent_100ml_corrected/Sample_66_phthalate_concentration_2023-11-25.csv', header=1)

# Add 'Option' column to each DataFrame
Zafira_1_gp_df['Option'] = 'gp'
Zafira_1_pm_df['Option'] = 'pm'
Zafira_2_gp_df['Option'] = 'gp'
Zafira_2_pm_df['Option'] = 'pm'

# Combine all DataFrames into a single DataFrame
df_combined = pd.concat([Zafira_1_gp_df, Zafira_1_pm_df, Zafira_2_gp_df, Zafira_2_pm_df])

# Set the style to make the plot more readable (optional)
plt.figure(figsize=(12, 8))

# Use seaborn to create a boxplot
sns.boxplot(x='Phthalat:', y='Concentration [ng/m^3]', hue='Option', data=df_combined, palette={'gp': 'skyblue', 'pm': 'lightcoral'})

# Customize the plot using Matplotlib
plt.title('Boxplot for Options A and B')
plt.xlabel('Phthalate')
plt.ylabel('Concentration [ng/m^3]')
plt.legend(title='Options', loc='upper right')
plt.grid(True, axis='y', alpha=0.7)
# Show the plot
plt.show()

# %%
Auto_1_gp_df['Option'] = 'gp'
Auto_1_pm_df['Option'] = 'pm'
Auto_2_gp_df['Option'] = 'gp'
Auto_2_pm_df['Option'] = 'pm'
Auto_3_gp_df['Option'] = 'gp'
Auto_3_pm_df['Option'] = 'pm'
# Combine all DataFrames into a single DataFrame
df_combined = pd.concat([Auto_1_gp_df, Auto_1_pm_df, Auto_2_gp_df, Auto_2_pm_df, Auto_3_gp_df, Auto_3_pm_df])

# Set the style to make the plot more readable (optional)
plt.figure(figsize=(12, 8))

# Use seaborn to create a boxplot
sns.boxplot(x='Phthalat:', y='Concentration [ng/m^3]', hue='Option', data=df_combined, palette={'gp': 'skyblue', 'pm': 'lightcoral'}, showfliers=True)
# Add individual data points
sns.swarmplot(x='Phthalat:', y='Concentration [ng/m^3]', hue='Option', data=df_combined, palette={'gp': 'skyblue', 'pm': 'lightcoral'}, size=5, dodge=True, edgecolor='black', linewidth=0.5)

# Customize the plot using Matplotlib
plt.title('Boxplot for Options A and B with Mean Values')
plt.xlabel('Phthalate')
plt.ylabel('Concentration [ng/m^3]')
plt.legend(title='Options', loc='upper right')
plt.grid(True, axis='y', alpha=0.7)
# Show the plot
plt.show()

# %% [markdown]
# Correct boxplot script, for total display, excluding the Auto_1_pm_df data

# %%
Auto_1_gp_df['Option'] = 'gp'
Auto_1_pm_df['Option'] = 'pm'
Auto_2_gp_df['Option'] = 'gp'
Auto_2_pm_df['Option'] = 'pm'
Auto_3_gp_df['Option'] = 'gp'
Auto_3_pm_df['Option'] = 'pm'

df_combined = pd.concat([Auto_1_gp_df, Auto_2_gp_df, Auto_2_pm_df, Auto_3_gp_df, Auto_3_pm_df])
# Map unique 'Phthalat:' values to numerical values
phthalate_mapping = {phthalate: i for i, phthalate in enumerate(df_combined['Phthalat:'].unique())}

# Add a new column 'PhthalateNumeric' to the DataFrame based on the mapping
df_combined['PhthalateNumeric'] = df_combined['Phthalat:'].map(phthalate_mapping)

# Calculate mean values for each combination of 'PhthalateNumeric' and 'Option'
means = df_combined.groupby(['PhthalateNumeric', 'Option'])['Concentration [ng/m^3]'].mean().reset_index()

# Set the style to make the plot more readable (optional)
plt.figure(figsize=(16, 10))

# Use seaborn to create a boxplot
ax = sns.boxplot(x='PhthalateNumeric', y='Concentration [ng/m^3]', hue='Option', data=df_combined, palette={'gp': 'skyblue', 'pm': 'lightcoral'}, showfliers=True)

# Add individual data points
sns.swarmplot(x='PhthalateNumeric', y='Concentration [ng/m^3]', hue='Option', data=df_combined, palette={'gp': 'skyblue', 'pm': 'lightcoral'}, size=5, dodge=True, edgecolor='black', linewidth=0.5)

# Add mean values with adjusted x-coordinates
for index, row in means.iterrows():
    x_offset = -0.2 if row['Option'] == 'gp' else 0.2  # Adjust x-coordinates for 'gp' and 'pm'
    ax.scatter(x=row['PhthalateNumeric'] + x_offset, y=row['Concentration [ng/m^3]'], color={'gp': 'black', 'pm': 'black'}[row['Option']], marker='x', s=100, linewidths=2)

# Customize the plot using Matplotlib
plt.title('Phthalate concentration of new cars (n=3)')
plt.xlabel('Phthalate')
plt.ylabel('Concentration [ng/m^3]')
plt.xticks(ticks=range(len(phthalate_mapping)), labels=df_combined['Phthalat:'].unique())  # Set x-axis ticks to original 'Phthalat:' values
plt.legend(loc='upper right')
plt.grid(True, axis='y', alpha=0.7)
plt.ylim(bottom=0)
# Show the plot
plt.show()
