# %% [markdown]
# <a href="https://colab.research.google.com/github/TillVollmer5/mass_spectroscopy/blob/main/Plots_Cars.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Plots for the general levels of the different phthalates to create box-whisker plots for the gas phase, particulate matter phases, combined in one plot and seperate in one plot.

# %%
import matplotlib.pyplot as plt
import numpy as np
from google.colab import drive
import pandas as pd
import seaborn as sns
from matplotlib.patches import Patch
import matplotlib.patches as mpatches
drive.mount('/content/drive', force_remount = True)
# Out:
# Mounted at /content/drive

# %%
#Import of df for samples
Zafira_1_gp_df = pd.read_csv('/content/drive/My Drive/conversion_export/Solvent_100ml_corrected/Sample_63_phthalate_concentration_2023-11-25.csv', header=1) #Blank solvent corrected
Zafira_1_pm_df = pd.read_csv('/content/drive/My Drive/conversion_export/Sample_64_phthalate_concentration_2024-02-27.csv', header=1) #Blank solvent corrected
Zafira_2_gp_df = pd.read_csv('/content/drive/My Drive/conversion_export/Solvent_100ml_corrected/Sample_65_phthalate_concentration_2023-11-25.csv', header=1) #Blank solvent corrected
Zafira_2_pm_df = pd.read_csv('/content/drive/My Drive/conversion_export/Sample_66_phthalate_concentration_2024-02-27.csv', header=1) #Blank solvent corrected
Auto_1_gp_df = pd.read_csv('/content/drive/My Drive/conversion_export/Solvent_100ml_corrected/Sample_130_phthalate_concentration_2023-11-25.csv', header=1) #Blank solvent corrected
Auto_1_pm_df = pd.read_csv('/content/drive/My Drive/conversion_export/Sample_123_phthalate_concentration_2024-02-27.csv', header=1) #Blank solvent corrected
Auto_2_gp_df = pd.read_csv('/content/drive/My Drive/conversion_export/Solvent_100ml_corrected/Sample_144_phthalate_concentration_2023-11-25.csv', header=1) #Blank solvent corrected
Auto_2_pm_df = pd.read_csv('/content/drive/My Drive/conversion_export/Sample_140_phthalate_concentration_2024-02-27.csv', header=1) #Blank solvent corrected
Auto_3_gp_df = pd.read_csv('/content/drive/My Drive/conversion_export/Sample_155_phthalate_concentration_2023-11-26.csv', header=1) #QC F4 corrected
Auto_3_pm_df = pd.read_csv('/content/drive/My Drive/conversion_export/Sample_162_phthalate_concentration_2023-11-26.csv', header=1) #QC pm corrected
Auto_4_gp_df = pd.read_csv('/content/drive/My Drive/conversion_export/Sample_170_phthalate_concentration_2023-11-28.csv', header=1) #QC F4 corrected
Auto_4_pm_df = pd.read_csv('/content/drive/My Drive/conversion_export/Sample_177_phthalate_concentration_2023-11-29.csv', header=1) #QC pm corrected
Auto_5_pm_df = pd.read_csv('/content/drive/My Drive/conversion_export/Sample_183_phthalate_concentration_2023-12-01.csv', header=1) #QC pm corrected
Auto_5_gp_df = pd.read_csv('/content/drive/My Drive/conversion_export/Sample_185_phthalate_concentration_2023-12-05.csv', header=1) #QC pm corrected

Zafira_1_gp_df['Concentration [ng/m^3]'] = Zafira_1_gp_df['Concentration [ng/m^3]'].apply(lambda x: max(0, x))
Zafira_1_pm_df['Concentration [ng/m^3]'] = Zafira_1_pm_df['Concentration [ng/m^3]'].apply(lambda x: max(0, x))
Zafira_2_gp_df['Concentration [ng/m^3]'] = Zafira_2_gp_df['Concentration [ng/m^3]'].apply(lambda x: max(0, x))
Zafira_2_pm_df['Concentration [ng/m^3]'] = Zafira_2_pm_df['Concentration [ng/m^3]'].apply(lambda x: max(0, x))
Auto_1_gp_df['Concentration [ng/m^3]'] = Auto_1_gp_df['Concentration [ng/m^3]'].apply(lambda x: max(0, x))
Auto_1_pm_df['Concentration [ng/m^3]'] = Auto_1_pm_df['Concentration [ng/m^3]'].apply(lambda x: max(0, x))
Auto_2_gp_df['Concentration [ng/m^3]'] = Auto_2_gp_df['Concentration [ng/m^3]'].apply(lambda x: max(0, x))
Auto_2_pm_df['Concentration [ng/m^3]'] = Auto_2_pm_df['Concentration [ng/m^3]'].apply(lambda x: max(0, x))
Auto_3_gp_df['Concentration [ng/m^3]'] = Auto_3_gp_df['Concentration [ng/m^3]'].apply(lambda x: max(0, x))
Auto_3_pm_df['Concentration [ng/m^3]'] = Auto_3_pm_df['Concentration [ng/m^3]'].apply(lambda x: max(0, x))
Auto_4_gp_df['Concentration [ng/m^3]'] = Auto_4_gp_df['Concentration [ng/m^3]'].apply(lambda x: max(0, x))
Auto_4_pm_df['Concentration [ng/m^3]'] = Auto_4_pm_df['Concentration [ng/m^3]'].apply(lambda x: max(0, x))
Auto_5_pm_df['Concentration [ng/m^3]'] = Auto_5_pm_df['Concentration [ng/m^3]'].apply(lambda x: max(0, x))
Auto_5_gp_df['Concentration [ng/m^3]'] = Auto_5_gp_df['Concentration [ng/m^3]'].apply(lambda x: max(0, x))

Zafira_1_gp_df['Option'] = 'gp'
Zafira_1_pm_df['Option'] = 'pm'
Zafira_2_gp_df['Option'] = 'gp'
Zafira_2_pm_df['Option'] = 'pm'
Auto_1_gp_df['Option'] = 'gp'
Auto_1_pm_df['Option'] = 'pm'
Auto_2_gp_df['Option'] = 'gp'
Auto_2_pm_df['Option'] = 'pm'
Auto_3_gp_df['Option'] = 'gp'
Auto_3_pm_df['Option'] = 'pm'
Auto_4_gp_df['Option'] = 'gp'
Auto_4_pm_df['Option'] = 'pm'
Auto_5_pm_df['Option'] = 'pm'
Auto_5_gp_df['Option'] = 'gp'

Italy_2009_df = pd.read_csv('/content/drive/My Drive/Italy_usedprivatecars_2009_Lit.csv', header=2)
Japan_2006_df = pd.read_csv('/content/drive/My Drive/Japan_3yearoldcars_2006_Lit.csv', header=2)

print(Zafira_1_gp_df)
print(Zafira_1_pm_df)
print(Zafira_2_gp_df)
print(Zafira_2_pm_df)
print(Auto_1_gp_df)
print(Auto_1_pm_df)
print(Auto_2_gp_df)
print(Auto_2_pm_df)
print(Auto_3_gp_df)
print(Auto_3_pm_df)
print(Auto_4_gp_df)
print(Auto_4_pm_df)
print(Auto_5_pm_df)
print(Auto_5_gp_df)
print(Italy_2009_df)
print(Japan_2006_df)
# Out:
#                      Phthalat:  Concentration [ng/m^3] Option
# 0            Dimethylphthalate                7.926815     gp
# 1             Diethylphthalate              170.870953     gp
# 2             Dibutylphthalate               41.039988     gp
# 3         Benzylbutylphthalate                0.229087     gp
# 4  Bis(2-ethyl-hexyl)phthalate               60.691125     gp
# 5          Di-n-octylphthalate                0.907515     gp
#                      Phthalat:  Concentration [ng/m^3] Option
# 0            Dimethylphthalate                0.175458     pm
# 1             Diethylphthalate                6.940621     pm
# 2             Dibutylphthalate               34.704096     pm
# 3         Benzylbutylphthalate                0.824068     pm
# 4  Bis(2-ethyl-hexyl)phthalate               47.271517     pm
# 5          Di-n-octylphthalate                3.242683     pm
#                      Phthalat:  Concentration [ng/m^3] Option
# ...

# %%
gp_dfs = [Auto_1_gp_df, Auto_2_gp_df, Auto_3_gp_df, Auto_4_gp_df, Auto_5_gp_df]
pm_dfs = [Auto_2_pm_df, Auto_3_pm_df, Auto_4_pm_df, Auto_5_pm_df]

# Create an empty dataframe to store the mean values for gp and pm separately
mean_df = pd.DataFrame()

# Calculate the mean concentration for 'gp' and 'pm' options separately
mean_df['gp'] = pd.concat([df['Concentration [ng/m^3]'] for df in gp_dfs], axis=1).mean(axis=1)
mean_df['pm'] = pd.concat([df['Concentration [ng/m^3]'] for df in pm_dfs], axis=1).mean(axis=1)

std_df = pd.DataFrame()

# Calculate the standard deviation for 'gp' and 'pm' options separately
std_df['gp'] = pd.concat([df['Concentration [ng/m^3]'] for df in gp_dfs], axis=1).std(axis=1)
std_df['pm'] = pd.concat([df['Concentration [ng/m^3]'] for df in pm_dfs], axis=1).std(axis=1)

# Display the resulting mean_df and std_df
print("Mean DataFrame:")
print(mean_df)
print("\nSTD DataFrame:")
print(std_df)

# Sum all rows in each column independently
sum_mean = mean_df.sum()
sum_std = std_df.sum()

# Display the resulting sum values
print("\nSum Mean Values:")
print(sum_mean)
print("\nSum STD Values:")
print(sum_std)
# Out:
# Mean DataFrame:
#           gp         pm
# 0   7.981999   1.449228
# 1  10.626891  25.384819
# 2  28.076121  15.128909
# 3   0.021091   0.475486
# 4  77.369795  87.782264
# 5   0.298435   0.613685
#
# STD DataFrame:
#           gp         pm
# 0   6.372059   1.116352
# 1   5.512118  18.553243
# 2  39.109169   6.965778
# 3   0.038489   0.720956
# 4  45.215326  91.999974
# 5   0.394342   0.422801
#
# Sum Mean Values:
# gp    124.374332
# pm    130.834392
# dtype: float64
#
# Sum STD Values:
# gp     96.641503
# pm    119.779104
# dtype: float64

# %%
df_combined = pd.concat([Zafira_1_gp_df, Zafira_1_pm_df, Zafira_2_gp_df, Zafira_2_pm_df])
sns.set(style="whitegrid")

plt.figure(figsize=(10, 6))
sns.boxplot(x='Phthalat:', y='Concentration [ng/m^3]', hue='Option', data=df_combined, width=0.6, palette="Set3")
plt.xlabel('Data Point')
plt.ylabel('Value')
plt.title('Boxplot for Options A and B')
plt.show()

# %% [markdown]
# The following would be a boxplot using matplotlib for graphing, which in this case doesn't work due to coloration

# %%
df_combined = pd.concat([Auto_1_gp_df, Auto_1_pm_df, Auto_2_gp_df, Auto_2_pm_df, Auto_3_gp_df, Auto_3_pm_df, Auto_4_gp_df, Auto_4_pm_df, Auto_5_gp_df, Auto_5_pm_df])

plt.figure(figsize=(12, 8))

sns.boxplot(x='Phthalat:', y='Concentration [ng/m^3]', hue='Option', data=df_combined, palette={'gp': 'skyblue', 'pm': 'lightcoral'}, showfliers=True)

sns.swarmplot(x='Phthalat:', y='Concentration [ng/m^3]', hue='Option', data=df_combined, palette={'gp': 'skyblue', 'pm': 'lightcoral'}, size=5, dodge=True, edgecolor='black', linewidth=0.5)

plt.title('Boxplot for Options A and B with Mean Values')
plt.xlabel('Phthalate')
plt.ylabel('Concentration [ng/m^3]')
plt.legend(title='Options', loc='upper right')
plt.grid(True, axis='y', alpha=0.7)
plt.ylim(top=300, bottom=0)
plt.show()

# %% [markdown]
# Correct boxplot script, for total display, excluding the Auto_1_pm_df data

# %%
df_combined = pd.concat([Auto_1_gp_df, Auto_2_gp_df, Auto_2_pm_df, Auto_3_gp_df, Auto_3_pm_df, Auto_4_gp_df, Auto_4_pm_df, Auto_5_gp_df, Auto_5_pm_df])

# Map unique 'Phthalat:' values to numerical values
phthalate_mapping = {phthalate: i for i, phthalate in enumerate(df_combined['Phthalat:'].unique())}

# Add a new column 'PhthalateNumeric' to the DataFrame based on the mapping
df_combined['PhthalateNumeric'] = df_combined['Phthalat:'].map(phthalate_mapping)

means = df_combined.groupby(['PhthalateNumeric', 'Option'])['Concentration [ng/m^3]'].mean().reset_index()


plt.figure(figsize=(9, 5))

ax = sns.barplot(x='PhthalateNumeric', y='Concentration [ng/m^3]', hue='Option', data=df_combined, palette={'gp': 'skyblue', 'pm': 'lightcoral'}, capsize=0.2, errwidth=1.5, edgecolor='black')

#sns.swarmplot(x='PhthalateNumeric', y='Concentration [ng/m^3]', hue='Option', data=df_combined, palette={'gp': 'skyblue', 'pm': 'lightcoral'}, size=5, dodge=True, edgecolor='black', linewidth=0.5)

plt.xlabel('')
plt.ylabel('Average concentration [ng/m$^3$]')
custom_tick_labels = df_combined['Phthalat:'].unique()
custom_tick_labels = ['DMP', 'DEP', 'DBP', 'BBP', 'DEHP', 'DnOP']  # Replace with your custom labels
ax.set_xticks(range(len(custom_tick_labels)))
ax.set_xticklabels(custom_tick_labels)
ax.spines['bottom'].set_linewidth(2)
ax.spines['bottom'].set_color('black')
ax.spines['left'].set_linewidth(2)
ax.spines['left'].set_color('black')
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.grid(True, axis='y', linestyle='--', alpha=0.7)
plt.ylim(bottom=0, top=249)
legend_labels = ['Gas', 'Particle']  # Add your specific labels here
legend = plt.legend(title='', loc='upper right')

for i, text in enumerate(legend.get_texts()):
    text.set_text(legend_labels[i])
plt.savefig('/content/drive/My Drive/Plot_GPPM_Barplot.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# <ipython-input-6-98b602f62225>:14: FutureWarning:
#
# The `errwidth` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'linewidth': 1.5}` instead.
#
#   ax = sns.barplot(x='PhthalateNumeric', y='Concentration [ng/m^3]', hue='Option', data=df_combined, palette={'gp': 'skyblue', 'pm': 'lightcoral'}, capsize=0.2, errwidth=1.5, edgecolor='black')

# %%
df_combined = pd.concat([Auto_1_gp_df, Auto_2_gp_df, Auto_2_pm_df, Auto_3_gp_df, Auto_3_pm_df, Auto_4_gp_df, Auto_4_pm_df, Auto_5_gp_df, Auto_5_pm_df])

# Map unique 'Phthalat:' values to numerical values
phthalate_mapping = {phthalate: i for i, phthalate in enumerate(df_combined['Phthalat:'].unique())}

# Add a new column 'PhthalateNumeric' to the DataFrame based on the mapping
df_combined['PhthalateNumeric'] = df_combined['Phthalat:'].map(phthalate_mapping)

means = df_combined.groupby(['PhthalateNumeric', 'Option'])['Concentration [ng/m^3]'].mean().reset_index()


plt.figure(figsize=(9, 5))

ax = sns.boxplot(x='PhthalateNumeric', y='Concentration [ng/m^3]', hue='Option', data=df_combined, palette={'gp': 'skyblue', 'pm': 'lightcoral'})

#sns.swarmplot(x='PhthalateNumeric', y='Concentration [ng/m^3]', hue='Option', data=df_combined, palette={'gp': 'skyblue', 'pm': 'lightcoral'}, size=5, dodge=True, edgecolor='black', linewidth=0.5)

for index, row in means.iterrows():
    x_offset = -0.2 if row['Option'] == 'gp' else 0.2
    ax.scatter(x=row['PhthalateNumeric'] + x_offset, y=row['Concentration [ng/m^3]'], color={'gp': 'black', 'pm': 'black'}[row['Option']], marker='x', s=100, linewidths=2)

plt.xlabel('')
plt.ylabel('Average concentration [ng/m$^3$]')
custom_tick_labels = df_combined['Phthalat:'].unique()
custom_tick_labels = ['DMP', 'DEP', 'DBP', 'BBP', 'DEHP', 'DnOP']  # Replace with your custom labels
ax.set_xticks(range(len(custom_tick_labels)))
ax.set_xticklabels(custom_tick_labels)
ax.spines['bottom'].set_linewidth(2)
ax.spines['bottom'].set_color('black')
ax.spines['left'].set_linewidth(2)
ax.spines['left'].set_color('black')
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.grid(True, axis='y', linestyle='--', alpha=0.7)
plt.ylim(bottom=0, top=249)
legend_labels = ['Gas', 'Particle']  # Add your specific labels here
legend = plt.legend(title='', loc='upper right')

for i, text in enumerate(legend.get_texts()):
    text.set_text(legend_labels[i])
plt.savefig('/content/drive/My Drive/Plot_GPPM_Boxplot.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
df_gps = [Auto_1_gp_df, Auto_2_gp_df, Auto_3_gp_df, Auto_4_gp_df, Auto_5_gp_df]
df_pms = [Auto_2_pm_df, Auto_3_pm_df, Auto_4_pm_df, Auto_5_pm_df]

# Initialize mean_df_gp, std_df_gp, mean_df_pm, and std_df_pm using the 'Phthalat:' column from the first DataFrame
mean_df_gp = pd.DataFrame({'Phthalat:': df_gps[0]['Phthalat:']}).copy()
std_df_gp = pd.DataFrame({'Phthalat:': df_gps[0]['Phthalat:']}).copy()
mean_df_pm = pd.DataFrame({'Phthalat:': df_pms[0]['Phthalat:']}).copy()
std_df_pm = pd.DataFrame({'Phthalat:': df_pms[0]['Phthalat:']}).copy()

for i, df_gp in enumerate(df_gps):
    col_name = df_gp.columns[1] + f'_{i+1}'
    mean_df_gp[col_name] = df_gp.iloc[:, 1].copy()
    std_df_gp[col_name] = df_gp.iloc[:, 1].copy()
for i, df_pm in enumerate(df_pms):
    col_name = df_pm.columns[1] + f'_{i+1}'
    mean_df_pm[col_name] = df_pm.iloc[:, 1].copy()
    std_df_pm[col_name] = df_pm.iloc[:, 1].copy()

mean_df_gp['Mean'] = mean_df_gp.iloc[:, 1:].mean(axis=1)
std_df_gp['Std'] = std_df_gp.iloc[:, 1:].std(axis=1)
mean_df_pm['Mean'] = mean_df_pm.iloc[:, 1:].mean(axis=1)
std_df_pm['Std'] = std_df_pm.iloc[:, 1:].std(axis=1)

mean_df_gp = mean_df_gp[['Phthalat:', 'Mean']]
std_df_gp = std_df_gp[['Phthalat:', 'Std']]
mean_df_pm = mean_df_pm[['Phthalat:', 'Mean']]
std_df_pm = std_df_pm[['Phthalat:', 'Std']]

print(mean_df_gp)
print(std_df_gp)
print(mean_df_pm)
print(std_df_pm)

mean_df_gp['Option'] = 'gp'
mean_df_pm['Option'] = 'pm'

df_gp_combined = pd.concat([mean_df_gp, std_df_gp['Std']], axis=1)
df_pm_combined = pd.concat([mean_df_pm, std_df_pm['Std']], axis=1)

fig, ax = plt.subplots(figsize=(16, 10))
bar_width = 0.35
index_gp = np.arange(len(df_gp_combined))
index_pm = np.arange(len(df_pm_combined))

ax.bar(index_gp, df_gp_combined['Mean'], bar_width, yerr=df_gp_combined['Std'], label='gp', capsize=5)
ax.bar(index_pm + bar_width, df_pm_combined['Mean'], bar_width, yerr=df_pm_combined['Std'], label='pm', capsize=5)

ax.set_xlabel('Phthalat:')
ax.set_ylabel('Mean')
ax.set_xticks(index_gp + bar_width / 2)
ax.set_xticklabels(df_gp_combined['Phthalat:'])
plt.grid(True, axis='y', alpha=0.7)
ax.legend()
ax.set_ylim(bottom=0)
plt.show()
# Out:
#                      Phthalat:       Mean
# 0            Dimethylphthalate   7.981999
# 1             Diethylphthalate  10.626891
# 2             Dibutylphthalate  28.076121
# 3         Benzylbutylphthalate   0.021091
# 4  Bis(2-ethyl-hexyl)phthalate  77.369795
# 5          Di-n-octylphthalate   0.298435
#                      Phthalat:        Std
# 0            Dimethylphthalate   6.372059
# 1             Diethylphthalate   5.512118
# 2             Dibutylphthalate  39.109169
# 3         Benzylbutylphthalate   0.038489
# 4  Bis(2-ethyl-hexyl)phthalate  45.215326
# 5          Di-n-octylphthalate   0.394342
#                      Phthalat:       Mean
# 0            Dimethylphthalate   1.449228
# 1             Diethylphthalate  25.384819
# 2             Dibutylphthalate  15.128909
# 3         Benzylbutylphthalate   0.475486
# 4  Bis(2-ethyl-hexyl)phthalate  87.782264
# 5          Di-n-octylphthalate   0.613685
#                      Phthalat:        Std
# ...

# %%
df_gps = [Auto_1_gp_df, Auto_2_gp_df, Auto_3_gp_df, Auto_4_gp_df, Auto_5_gp_df]
df_pms = [Auto_2_pm_df, Auto_3_pm_df, Auto_4_pm_df, Auto_5_pm_df]

# Initialize mean_df_gp, std_df_gp, mean_df_pm, and std_df_pm using the 'Phthalat:' column from the first DataFrame
mean_df_gp = pd.DataFrame({'Phthalat:': df_gps[0]['Phthalat:']}).copy()
std_df_gp = pd.DataFrame({'Phthalat:': df_gps[0]['Phthalat:']}).copy()
mean_df_pm = pd.DataFrame({'Phthalat:': df_pms[0]['Phthalat:']}).copy()
std_df_pm = pd.DataFrame({'Phthalat:': df_pms[0]['Phthalat:']}).copy()

for i, df_gp in enumerate(df_gps):
    col_name = df_gp.columns[1] + f'_{i+1}'
    mean_df_gp[col_name] = df_gp.iloc[:, 1].copy()
    std_df_gp[col_name] = df_gp.iloc[:, 1].copy()
for i, df_pm in enumerate(df_pms):
    col_name = df_pm.columns[1] + f'_{i+1}'
    mean_df_pm[col_name] = df_pm.iloc[:, 1].copy()
    std_df_pm[col_name] = df_pm.iloc[:, 1].copy()

mean_df_gp['Mean'] = mean_df_gp.iloc[:, 1:].mean(axis=1)
std_df_gp['Std'] = std_df_gp.iloc[:, 1:].std(axis=1)
mean_df_pm['Mean'] = mean_df_pm.iloc[:, 1:].mean(axis=1)
std_df_pm['Std'] = std_df_pm.iloc[:, 1:].std(axis=1)

mean_df_gp = mean_df_gp[['Phthalat:', 'Mean']]
std_df_gp = std_df_gp[['Phthalat:', 'Std']]
mean_df_pm = mean_df_pm[['Phthalat:', 'Mean']]
std_df_pm = std_df_pm[['Phthalat:', 'Std']]

print(mean_df_gp)
print(mean_df_pm)

mean_gp = mean_df_gp[['Mean']]
mean_pm = mean_df_pm[['Mean']]

# Normalize the 'Mean' column to 100% for each group (gp and pm) independently
mean_gp_normalized = (mean_gp / mean_gp.sum()) * 100
mean_pm_normalized = (mean_pm / mean_pm.sum()) * 100

# Plotting
fig, ax = plt.subplots(figsize=(10, 6))

# Increase the width parameter for the "gp" bars and adjust the position accordingly
mean_gp_normalized.T.plot(kind='bar', stacked=True, ax=ax, colormap='viridis', alpha=0.7, position=-0.2, width=0.8, label='gp')

# Increase the position value to shift the "pm" bars to the right
mean_pm_normalized.T.plot(kind='bar', stacked=True, ax=ax, colormap='plasma', alpha=0.7, position=4.5, width=0.4, label='pm')

# Customize the plot
ax.set_ylabel('Percentage')
ax.set_title('Normalized Distribution of Means')
ax.set_xticks([0, 4.5])  # Adjust the x-ticks accordingly
ax.set_xticklabels(['gp', 'pm'], rotation=0)
ax.legend(title='Phthalate', bbox_to_anchor=(1, 1))

# Show the plot
plt.show()
# Out:
#                      Phthalat:       Mean
# 0            Dimethylphthalate   7.981999
# 1             Diethylphthalate  10.626891
# 2             Dibutylphthalate  28.076121
# 3         Benzylbutylphthalate   0.021091
# 4  Bis(2-ethyl-hexyl)phthalate  77.369795
# 5          Di-n-octylphthalate   0.298435
#                      Phthalat:       Mean
# 0            Dimethylphthalate   1.449228
# 1             Diethylphthalate  25.384819
# 2             Dibutylphthalate  15.128909
# 3         Benzylbutylphthalate   0.475486
# 4  Bis(2-ethyl-hexyl)phthalate  87.782264
# 5          Di-n-octylphthalate   0.613685

# %%
df_gps = [Auto_1_gp_df, Auto_2_gp_df, Auto_3_gp_df, Auto_4_gp_df, Auto_5_gp_df]
df_pms = [Auto_2_pm_df, Auto_3_pm_df, Auto_4_pm_df, Auto_5_pm_df]

# Initialize mean_df_gp, std_df_gp, mean_df_pm, and std_df_pm using the 'Phthalat:' column from the first DataFrame
mean_df_gp = pd.DataFrame({'Phthalat:': df_gps[0]['Phthalat:']}).copy()
std_df_gp = pd.DataFrame({'Phthalat:': df_gps[0]['Phthalat:']}).copy()
mean_df_pm = pd.DataFrame({'Phthalat:': df_pms[0]['Phthalat:']}).copy()
std_df_pm = pd.DataFrame({'Phthalat:': df_pms[0]['Phthalat:']}).copy()

for i, df_gp in enumerate(df_gps):
    col_name = df_gp.columns[1] + f'_{i+1}'
    mean_df_gp[col_name] = df_gp.iloc[:, 1].copy()
    std_df_gp[col_name] = df_gp.iloc[:, 1].copy()
for i, df_pm in enumerate(df_pms):
    col_name = df_pm.columns[1] + f'_{i+1}'
    mean_df_pm[col_name] = df_pm.iloc[:, 1].copy()
    std_df_pm[col_name] = df_pm.iloc[:, 1].copy()

mean_df_gp['Mean'] = mean_df_gp.iloc[:, 1:].mean(axis=1)
std_df_gp['Std'] = std_df_gp.iloc[:, 1:].std(axis=1)
mean_df_pm['Mean'] = mean_df_pm.iloc[:, 1:].mean(axis=1)
std_df_pm['Std'] = std_df_pm.iloc[:, 1:].std(axis=1)

mean_df_gp = mean_df_gp[['Phthalat:', 'Mean']]
std_df_gp = std_df_gp[['Phthalat:', 'Std']]
mean_df_pm = mean_df_pm[['Phthalat:', 'Mean']]
std_df_pm = std_df_pm[['Phthalat:', 'Std']]

print(mean_df_gp)
print(mean_df_pm)

mean_gp = mean_df_gp[['Phthalat:', 'Mean']]
mean_pm = mean_df_pm[['Phthalat:', 'Mean']]

# Normalize the 'Mean' column to 100% for each group (gp and pm) independently
mean_gp['Mean'] = (mean_gp['Mean'] / mean_gp['Mean'].sum()) * 100
mean_pm['Mean'] = (mean_pm['Mean'] / mean_pm['Mean'].sum()) * 100

# Add 'Group' column and concatenate the DataFrames
mean_gp['Group'] = 'gp'
mean_pm['Group'] = 'pm'

normalized_data = pd.concat([mean_gp, mean_pm])

# Reset index for proper indexing in the plot
normalized_data = normalized_data.reset_index(drop=True)

# Define a dictionary for manual color mapping
color_mapping = {
    'Dimethylphthalate': 'purple',
    'Diethylphthalate': 'orange',
    'Dibutylphthalate': 'green',
    'Benzylbutylphthalate': 'red',
    'Bis(2-ethyl-hexyl)phthalate': 'blue',
    'Di-n-octylphthalate': 'brown'
}

# Plotting
fig, ax = plt.subplots(figsize=(10, 6))

# Use Seaborn to create a stacked bar plot with manual color mapping
sns.barplot(x='Group', y='Mean', hue='Phthalat:', data=normalized_data, ax=ax, palette=color_mapping, yerr=None)

# Customize the plot
ax.set_ylabel('Percentage')
ax.set_title('Stacked Distribution of Means')
ax.legend(title='Phthalate', bbox_to_anchor=(1, 1))

# Show the plot
plt.show()
# Out:
#                      Phthalat:       Mean
# 0            Dimethylphthalate   7.981999
# 1             Diethylphthalate  10.626891
# 2             Dibutylphthalate  28.076121
# 3         Benzylbutylphthalate   0.021091
# 4  Bis(2-ethyl-hexyl)phthalate  77.369795
# 5          Di-n-octylphthalate   0.298435
#                      Phthalat:       Mean
# 0            Dimethylphthalate   1.449228
# 1             Diethylphthalate  25.384819
# 2             Dibutylphthalate  15.128909
# 3         Benzylbutylphthalate   0.475486
# 4  Bis(2-ethyl-hexyl)phthalate  87.782264
# 5          Di-n-octylphthalate   0.613685
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-36732d6ed5cb> in <cell line: 62>()
#      60
#      61 # Use Seaborn to create a stacked bar plot with manual color mapping
# ...

# %%
df_gps = [Auto_1_gp_df, Auto_2_gp_df, Auto_3_gp_df, Auto_4_gp_df, Auto_5_gp_df]
df_pms = [Auto_2_pm_df, Auto_3_pm_df, Auto_4_pm_df, Auto_5_pm_df]

# Initialize mean_df_gp, std_df_gp, mean_df_pm, and std_df_pm using the 'Phthalat:' column from the first DataFrame
mean_df_gp = pd.DataFrame({'Phthalat:': df_gps[0]['Phthalat:']}).copy()
std_df_gp = pd.DataFrame({'Phthalat:': df_gps[0]['Phthalat:']}).copy()
mean_df_pm = pd.DataFrame({'Phthalat:': df_pms[0]['Phthalat:']}).copy()
std_df_pm = pd.DataFrame({'Phthalat:': df_pms[0]['Phthalat:']}).copy()

for i, df_gp in enumerate(df_gps):
    col_name = df_gp.columns[1] + f'_{i+1}'
    mean_df_gp[col_name] = df_gp.iloc[:, 1].copy()
    std_df_gp[col_name] = df_gp.iloc[:, 1].copy()
for i, df_pm in enumerate(df_pms):
    col_name = df_pm.columns[1] + f'_{i+1}'
    mean_df_pm[col_name] = df_pm.iloc[:, 1].copy()
    std_df_pm[col_name] = df_pm.iloc[:, 1].copy()

mean_df_gp['Mean'] = mean_df_gp.iloc[:, 1:].mean(axis=1)
std_df_gp['Std'] = std_df_gp.iloc[:, 1:].std(axis=1)
mean_df_pm['Mean'] = mean_df_pm.iloc[:, 1:].mean(axis=1)
std_df_pm['Std'] = std_df_pm.iloc[:, 1:].std(axis=1)

mean_df_gp = mean_df_gp[['Phthalat:', 'Mean']]
std_df_gp = std_df_gp[['Phthalat:', 'Std']]
mean_df_pm = mean_df_pm[['Phthalat:', 'Mean']]
std_df_pm = std_df_pm[['Phthalat:', 'Std']]

print(mean_df_gp)
print(mean_df_pm)

mean_gp = mean_df_gp[['Phthalat:', 'Mean']]
mean_pm = mean_df_pm[['Phthalat:', 'Mean']]

mean_japan = Japan_2006_df[['phthalat', 'mean']].copy()
mean_italy = Italy_2009_df[['phthalat', 'mean']].copy()
new_column_names = {'phthalat': 'Phthalat:', 'mean': 'Mean'}

# Corrected renaming for mean_japan and mean_italy
mean_japan.rename(columns=new_column_names, inplace=True)
mean_italy.rename(columns=new_column_names, inplace=True)
mean_japan['Phthalat:'].replace({'Diethyllphthalate': 'Diethylphthalate', 'Bis(2-ethylhexyl)phthalate': 'Bis(2-ethyl-hexyl)phthalate'}, inplace=True)
mean_italy['Phthalat:'].replace({'Diethyllphthalate': 'Diethylphthalate', 'Bis(2-ethylhexyl)phthalate': 'Bis(2-ethyl-hexyl)phthalate'}, inplace=True)
# Add 'Group' column and concatenate the DataFrames
mean_gp['Group'] = 'gp'
mean_pm['Group'] = 'pm'
mean_japan['Group'] = 'japan'
mean_italy['Group'] = 'italy'

print(mean_japan)
merged_df = pd.concat([mean_gp, mean_pm, mean_japan, mean_italy])


# Pivot the dataframe to make 'Phthalat:' values as columns
pivot_df = merged_df.pivot(index='Group', columns='Phthalat:', values='Mean')

# Normalize the data to 100%
pivot_df = pivot_df.div(pivot_df.sum(axis=1), axis=0) * 100

# Define custom colors
# Create a custom color dictionary
phthalate_colors = {
    'Dimethylphthalate': 'white',
    'Diethylphthalate': 'lightcoral',
    'Dibutylphthalate': 'darkgray',
    'Benzylbutylphthalate': 'lightgray',
    'Bis(2-ethyl-hexyl)phthalate': 'lightblue',
    'Di-n-octylphthalate': 'black',
    'DMP': 'white',
    'DEP': 'lightcoral',
    'DBP': 'darkgray',
    'BBP': 'lightgray',
    'DEHP': 'lightblue',
    'DnOP': 'black'
}

# Fill NaN values with zeros before plotting
pivot_df_filled = pivot_df.fillna(0)

category_order = ['gp', 'pm', 'japan', 'italy']

# Pivot the dataframe with specified category order
pivot_df_filled = pivot_df_filled.loc[category_order]


# Normalize the data to 100%
pivot_df_filled = pivot_df_filled.div(pivot_df_filled.sum(axis=1), axis=0) * 100

desired_order = ['Dimethylphthalate', 'Diethylphthalate', 'Dibutylphthalate', 'Benzylbutylphthalate', 'Bis(2-ethyl-hexyl)phthalate', 'Di-n-octylphthalate']
pivot_df_filled = pivot_df_filled[desired_order]
# Plotting with custom colors
sns.set(style="whitegrid")
plt.figure(figsize=(9, 5))
ax = pivot_df_filled.plot(kind='bar', stacked=True, color=[phthalate_colors[col] for col in pivot_df_filled.columns], edgecolor="black")
print("Order of columns in pivot_df_filled:", list(pivot_df_filled.columns))
legend_labels = ['DMP', 'DEP', 'DBP', 'BBP', 'DEHP', 'DnOP']
legend_handles = [
    Patch(facecolor=phthalate_colors[col], label=label, edgecolor='black') for col, label in zip(pivot_df_filled.columns, legend_labels)
]
# Create the legend with explicit handles and labels
legend = plt.legend(handles=legend_handles, title='', loc='center right', bbox_to_anchor=(1.2, 0.5))


# Remove vertical grid lines
ax.xaxis.grid(False)
# Add labels and title
ax.set_xticklabels(['Gaseous', 'Particulate', '2006 Japan', '2009 Italy'], rotation=0)
ax.spines['bottom'].set_linewidth(2)
ax.spines['bottom'].set_color('black')
ax.spines['left'].set_linewidth(2)
ax.spines['left'].set_color('black')
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.grid(True, axis='y', linestyle='--', alpha=0.7)
plt.xlabel('')
plt.ylabel('%', rotation=0)
plt.savefig('/content/drive/My Drive/Plot_TPAE_stacknorm_bar.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
#                      Phthalat:       Mean
# 0            Dimethylphthalate   7.981999
# 1             Diethylphthalate  10.626891
# 2             Dibutylphthalate  28.076121
# 3         Benzylbutylphthalate   0.021091
# 4  Bis(2-ethyl-hexyl)phthalate  77.369795
# 5          Di-n-octylphthalate   0.298435
#                      Phthalat:       Mean
# 0            Dimethylphthalate   1.449228
# 1             Diethylphthalate  25.384819
# 2             Dibutylphthalate  15.128909
# 3         Benzylbutylphthalate   0.475486
# 4  Bis(2-ethyl-hexyl)phthalate  87.782264
# 5          Di-n-octylphthalate   0.613685
#                      Phthalat:   Mean  Group
# 0            Dimethylphthalate   30.0  japan
# 1             Diethylphthalate   80.0  japan
# 2             Dibutylphthalate  270.0  japan
# 3         Benzylbutylphthalate   10.0  japan
# 4  Bis(2-ethyl-hexyl)phthalate  120.0  japan
# 5          Di-n-octylphthalate    NaN  japan
# ...

# %%
df_gps = [Auto_1_gp_df, Auto_2_gp_df, Auto_3_gp_df, Auto_4_gp_df, Auto_5_gp_df]
df_pms = [Auto_2_pm_df, Auto_3_pm_df, Auto_4_pm_df, Auto_5_pm_df]
df_o_gps = [Zafira_1_gp_df, Zafira_2_gp_df]
df_o_pms = [Zafira_1_pm_df, Zafira_2_pm_df]

# Initialize mean_df_gp, std_df_gp, mean_df_pm, and std_df_pm using the 'Phthalat:' column from the first DataFrame
mean_df_gp = pd.DataFrame({'Phthalat:': df_gps[0]['Phthalat:']}).copy()
std_df_gp = pd.DataFrame({'Phthalat:': df_gps[0]['Phthalat:']}).copy()
mean_df_pm = pd.DataFrame({'Phthalat:': df_pms[0]['Phthalat:']}).copy()
std_df_pm = pd.DataFrame({'Phthalat:': df_pms[0]['Phthalat:']}).copy()
mean_df_o_gp = pd.DataFrame({'Phthalat:': df_pms[0]['Phthalat:']}).copy()
std_df_o_gp = pd.DataFrame({'Phthalat:': df_pms[0]['Phthalat:']}).copy()
mean_df_o_pm = pd.DataFrame({'Phthalat:': df_pms[0]['Phthalat:']}).copy()
std_df_o_pm = pd.DataFrame({'Phthalat:': df_pms[0]['Phthalat:']}).copy()

for i, df_gp in enumerate(df_gps):
    col_name = df_gp.columns[1] + f'_{i+1}'
    mean_df_gp[col_name] = df_gp.iloc[:, 1].copy()
    std_df_gp[col_name] = df_gp.iloc[:, 1].copy()
for i, df_pm in enumerate(df_pms):
    col_name = df_pm.columns[1] + f'_{i+1}'
    mean_df_pm[col_name] = df_pm.iloc[:, 1].copy()
    std_df_pm[col_name] = df_pm.iloc[:, 1].copy()

for i, df_o_gp in enumerate(df_o_gps):
    col_name = df_o_gp.columns[1] + f'_{i+1}'
    mean_df_o_gp[col_name] = df_o_gp.iloc[:, 1].copy()
    std_df_o_gp[col_name] = df_o_gp.iloc[:, 1].copy()
for i, df_o_pm in enumerate(df_o_pms):
    col_name = df_o_pm.columns[1] + f'_{i+1}'
    mean_df_o_pm[col_name] = df_o_pm.iloc[:, 1].copy()
    std_df_o_pm[col_name] = df_o_pm.iloc[:, 1].copy()

mean_df_gp['Mean'] = mean_df_gp.iloc[:, 1:].mean(axis=1)
std_df_gp['Std'] = std_df_gp.iloc[:, 1:].std(axis=1)
mean_df_pm['Mean'] = mean_df_pm.iloc[:, 1:].mean(axis=1)
std_df_pm['Std'] = std_df_pm.iloc[:, 1:].std(axis=1)

mean_df_o_gp['Mean'] = mean_df_o_gp.iloc[:, 1:].mean(axis=1)
std_df_o_gp['Std'] = std_df_o_gp.iloc[:, 1:].std(axis=1)
mean_df_o_pm['Mean'] = mean_df_o_pm.iloc[:, 1:].mean(axis=1)
std_df_o_pm['Std'] = std_df_o_pm.iloc[:, 1:].std(axis=1)

mean_df_gp = mean_df_gp[['Phthalat:', 'Mean']]
std_df_gp = std_df_gp[['Phthalat:', 'Std']]
mean_df_pm = mean_df_pm[['Phthalat:', 'Mean']]
std_df_pm = std_df_pm[['Phthalat:', 'Std']]

mean_df_o_gp = mean_df_o_gp[['Phthalat:', 'Mean']]
std_df_o_gp = std_df_o_gp[['Phthalat:', 'Std']]
mean_df_o_pm = mean_df_o_pm[['Phthalat:', 'Mean']]
std_df_o_pm = std_df_o_pm[['Phthalat:', 'Std']]

total_new_car = pd.DataFrame({'Phthalat:': mean_df_gp['Phthalat:'], 'Mean': mean_df_gp['Mean'] + mean_df_pm['Mean']})
total_old_car = pd.DataFrame({'Phthalat:': mean_df_o_gp['Phthalat:'], 'Mean': mean_df_o_gp['Mean'] + mean_df_o_pm['Mean']})
Lit_Japan = pd.DataFrame({'Phthalat:': Japan_2006_df['phthalat'], 'Mean': Japan_2006_df['mean']})
Lit_Italy = pd.DataFrame({'Phthalat:': Italy_2009_df['phthalat'], 'Mean': Italy_2009_df['mean']})


combined_df = pd.concat([Lit_Japan, Lit_Italy, total_new_car], keys=['Japan', 'Italy', 'new_car'])
combined_df = combined_df.reset_index(level=0)


combined_df['Country'] = combined_df['level_0']

combined_df = combined_df.drop(columns=['level_0'])
combined_df = combined_df.reset_index(drop=True)

combined_df['Mean'].fillna(0, inplace=True)
combined_df.loc[(combined_df['Country'] == 'Italy') | (combined_df['Country'] == 'Japan'), 'Phthalat:'] = combined_df['Phthalat:'].str.replace('ll', 'l')
combined_df.loc[combined_df['Country'] == 'new_car', 'Phthalat:'] = combined_df['Phthalat:'].str.replace('-hexyl', 'hexyl')
print(combined_df)
sns.set(style="whitegrid")

custom_colors = ["lightcoral", "lightblue", "lightgray"]
plt.figure(figsize=(9, 5))

ax = sns.barplot(x='Phthalat:', y='Mean', hue='Country', data=combined_df, capsize=0.2, palette=custom_colors, edgecolor="black")

plt.ylabel('Average concentration [ng/m$^3$]')
custom_tick_labels = ['DMP', 'DEP', 'DBP', 'BBP', 'DEHP', 'DnOP']  # Replace with your custom labels
ax.set_xticks(range(len(custom_tick_labels)))
ax.set_xticklabels(custom_tick_labels)


ax.spines['bottom'].set_linewidth(2)
ax.spines['bottom'].set_color('black')
ax.spines['left'].set_linewidth(2)
ax.spines['left'].set_color('black')
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.grid(True, axis='y', linestyle='--', alpha=0.7)

# Customize legend
legend_labels = ['T. Yoshida et al., 2006, Japan', 'O. Geiss et al., 2009, Italy', 'This study']  # Add your specific labels here
legend = plt.legend(title='', loc='upper left')

for i, text in enumerate(legend.get_texts()):
    text.set_text(legend_labels[i])
plt.savefig('/content/drive/My Drive/Plot_TPAE_Lit.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
#                      Phthalat:        Mean  Country
# 0            Dimethylphthalate   30.000000    Japan
# 1             Diethylphthalate   80.000000    Japan
# 2             Dibutylphthalate  270.000000    Japan
# 3         Benzylbutylphthalate   10.000000    Japan
# 4   Bis(2-ethylhexyl)phthalate  120.000000    Japan
# 5          Di-n-octylphthalate    0.000000    Japan
# 6            Dimethylphthalate    0.000000    Italy
# 7             Diethylphthalate  234.000000    Italy
# 8             Dibutylphthalate  286.000000    Italy
# 9         Benzylbutylphthalate    0.000000    Italy
# 10  Bis(2-ethylhexyl)phthalate  487.000000    Italy
# 11         Di-n-octylphthalate    0.000000    Italy
# 12           Dimethylphthalate    9.431227  new_car
# 13            Diethylphthalate   36.011710  new_car
# 14            Dibutylphthalate   43.205030  new_car
# 15        Benzylbutylphthalate    0.496577  new_car
# 16  Bis(2-ethylhexyl)phthalate  165.152059  new_car
# ...

# %%
total_Auto1 = pd.DataFrame({'Phthalat:': Auto_1_gp_df['Phthalat:'], 'Total_phthalate': Auto_1_gp_df['Concentration [ng/m^3]'] + Auto_1_pm_df['Concentration [ng/m^3]']}) # + Auto_1_pm_df['Concentration [ng/m^3]']}) removed for display purposes...
total_Auto2 = pd.DataFrame({'Phthalat:': Auto_2_gp_df['Phthalat:'], 'Total_phthalate': Auto_2_gp_df['Concentration [ng/m^3]'] + Auto_2_pm_df['Concentration [ng/m^3]']})
total_Auto3 = pd.DataFrame({'Phthalat:': Auto_3_gp_df['Phthalat:'], 'Total_phthalate': Auto_3_gp_df['Concentration [ng/m^3]'] + Auto_3_pm_df['Concentration [ng/m^3]']})
total_Auto4 = pd.DataFrame({'Phthalat:': Auto_4_gp_df['Phthalat:'], 'Total_phthalate': Auto_4_gp_df['Concentration [ng/m^3]'] + Auto_4_pm_df['Concentration [ng/m^3]']})
total_Auto5 = pd.DataFrame({'Phthalat:': Auto_5_pm_df['Phthalat:'], 'Total_phthalate': Auto_5_gp_df['Concentration [ng/m^3]'] + Auto_5_pm_df['Concentration [ng/m^3]']})

total_Zafira1 = pd.DataFrame({'Phthalat:': Zafira_1_gp_df['Phthalat:'], 'Total_phthalate': Zafira_1_gp_df['Concentration [ng/m^3]'] + Zafira_1_pm_df['Concentration [ng/m^3]']})
total_Zafira2 = pd.DataFrame({'Phthalat:': Zafira_2_gp_df['Phthalat:'], 'Total_phthalate': Zafira_2_gp_df['Concentration [ng/m^3]'] + Zafira_2_pm_df['Concentration [ng/m^3]']})

total_Auto1['Option'] = 'new_car'
total_Auto2['Option'] = 'new_car'
total_Auto3['Option'] = 'new_car'
total_Auto4['Option'] = 'new_car'
total_Auto5['Option'] = 'new_car'
total_Zafira1['Option'] = 'old_car'
total_Zafira2['Option'] = 'old_car'

df_combined = pd.concat([total_Auto1, total_Auto2, total_Auto3, total_Auto4, total_Auto5, total_Zafira1, total_Zafira2])
phthalate_mapping = {phthalate: i for i, phthalate in enumerate(df_combined['Phthalat:'].unique())}
df_combined['PhthalateNumeric'] = df_combined['Phthalat:'].map(phthalate_mapping)
print(df_combined)

means = df_combined.groupby(['PhthalateNumeric', 'Option'])['Total_phthalate'].mean().reset_index()

plt.figure(figsize=(9, 5))

df_combined_reset = df_combined.reset_index(drop=True).dropna(subset=['Total_phthalate'])

ax = sns.barplot(x='PhthalateNumeric', y='Total_phthalate', hue='Option', data=df_combined_reset, palette={'new_car': 'skyblue', 'old_car': 'lightcoral'}, capsize=0.2, errwidth=1.5, edgecolor='black')

#sns.swarmplot(x='PhthalateNumeric', y='Total_phthalate', hue='Option', data=df_combined_reset, palette={'new_car': 'skyblue', 'old_car': 'lightcoral'}, size=5, dodge=True, edgecolor='black', linewidth=0.5)

plt.xlabel('Phthalate')
plt.ylabel('Total phthalate concentration')
custom_tick_labels = ['DMP', 'DEP', 'DBP', 'BBP', 'DEHP', 'DnOP']  # Replace with your custom labels
ax.set_xticks(range(len(custom_tick_labels)))
ax.set_xticklabels(custom_tick_labels)
plt.legend(loc='upper right')
plt.grid(True, axis='y', alpha=0.7)
plt.ylim(bottom=0, top=500)
plt.savefig('/content/drive/My Drive/Plot_TPEA_Zafira.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
#                      Phthalat:  Total_phthalate   Option  PhthalateNumeric
# 0            Dimethylphthalate         9.777172  new_car                 0
# 1             Diethylphthalate        48.629270  new_car                 1
# 2             Dibutylphthalate       218.016985  new_car                 2
# 3         Benzylbutylphthalate         2.171993  new_car                 3
# 4  Bis(2-ethyl-hexyl)phthalate      3604.442397  new_car                 4
# 5          Di-n-octylphthalate         1.989667  new_car                 5
# 0            Dimethylphthalate         6.752052  new_car                 0
# 1             Diethylphthalate        55.369189  new_car                 1
# 2             Dibutylphthalate        37.361588  new_car                 2
# 3         Benzylbutylphthalate         1.544740  new_car                 3
# 4  Bis(2-ethyl-hexyl)phthalate       127.166484  new_car                 4
# ...

# %%
# Combine dataframes
total_Auto1['Option'] = 'new_car'
total_Auto2['Option'] = 'new_car'
total_Auto3['Option'] = 'new_car'
total_Auto4['Option'] = 'new_car'
total_Auto5['Option'] = 'new_car'
total_Zafira1['Option'] = 'old_car'
total_Zafira2['Option'] = 'old_car'

df_combined = pd.concat([total_Auto1, total_Auto2, total_Auto3, total_Auto4, total_Auto5, total_Zafira1, total_Zafira2])

# Mapping for PhthalateNumeric
phthalate_mapping = {phthalate: i for i, phthalate in enumerate(df_combined['Phthalat:'].unique())}
df_combined['PhthalateNumeric'] = df_combined['Phthalat:'].map(phthalate_mapping)

plt.figure(figsize=(9, 5))

# Create boxplot
ax = sns.boxplot(x='PhthalateNumeric', y='Total_phthalate', hue='Option', data=df_combined, palette={'new_car': 'skyblue', 'old_car': 'lightcoral'}, showfliers=True, color='black')

# Add labels and title
plt.xlabel('')
plt.ylabel('Total phthalate concentration [\u00B5g/m$^3$]')  # Microgram per cubic meter symbol
custom_tick_labels = ['DMP', 'DEP', 'DBP', 'BBP', 'DEHP', 'DnOP']  # Replace with your custom labels
ax.set_xticks(range(len(custom_tick_labels)))
ax.set_xticklabels(custom_tick_labels)
plt.legend(loc='upper right')

# Customize spines
ax.spines['bottom'].set_linewidth(2)
ax.spines['bottom'].set_color('black')
ax.spines['left'].set_linewidth(2)
ax.spines['left'].set_color('black')
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Add grid lines
plt.grid(True, axis='y', alpha=0.7, linestyle='--')

# Adjust ylim if needed
plt.ylim(bottom=0, top=500)

# Save the plot
plt.savefig('/content/drive/My Drive/Plot_TPEA_Zafira_boxplot.png', dpi=300, bbox_inches='tight')

# Show the plot
plt.show()

# %%
partition_Auto1 = pd.DataFrame({'Phthalat:': Auto_1_gp_df['Phthalat:'], 'partition_phthalate': Auto_1_pm_df['Concentration [ng/m^3]'] / Auto_1_gp_df['Concentration [ng/m^3]']})
partition_Auto2 = pd.DataFrame({'Phthalat:': Auto_2_gp_df['Phthalat:'], 'partition_phthalate': Auto_2_pm_df['Concentration [ng/m^3]'] / Auto_2_gp_df['Concentration [ng/m^3]']})
partition_Auto3 = pd.DataFrame({'Phthalat:': Auto_3_gp_df['Phthalat:'], 'partition_phthalate': Auto_3_pm_df['Concentration [ng/m^3]'] / Auto_3_gp_df['Concentration [ng/m^3]']})
partition_Auto4 = pd.DataFrame({'Phthalat:': Auto_4_gp_df['Phthalat:'], 'partition_phthalate': Auto_4_pm_df['Concentration [ng/m^3]'] / Auto_4_gp_df['Concentration [ng/m^3]']})
partition_Auto5 = pd.DataFrame({'Phthalat:': Auto_5_gp_df['Phthalat:'], 'partition_phthalate': Auto_5_pm_df['Concentration [ng/m^3]'] / Auto_5_gp_df['Concentration [ng/m^3]']})

partition_Zafira1 = pd.DataFrame({'Phthalat:': Zafira_1_gp_df['Phthalat:'], 'partition_phthalate': Zafira_1_pm_df['Concentration [ng/m^3]'] / Zafira_1_gp_df['Concentration [ng/m^3]']})
partition_Zafira2 = pd.DataFrame({'Phthalat:': Zafira_2_gp_df['Phthalat:'], 'partition_phthalate': Zafira_2_pm_df['Concentration [ng/m^3]'] / Zafira_2_gp_df['Concentration [ng/m^3]']})

partition_Auto1['Option'] = 'new_car'
partition_Auto2['Option'] = 'new_car'
partition_Auto3['Option'] = 'new_car'
partition_Auto4['Option'] = 'new_car'
partition_Auto5['Option'] = 'new_car'
partition_Zafira1['Option'] = 'old_car'
partition_Zafira2['Option'] = 'old_car'

partition_Auto1['Auto'] = 'Auto1'
partition_Auto2['Auto'] = 'Auto2'
partition_Auto3['Auto'] = 'Auto3'
partition_Auto4['Auto'] = 'Auto4'
partition_Auto5['Auto'] = 'Auto5'
partition_Zafira1['Auto'] = 'Zafira1'
partition_Zafira2['Auto'] = 'Zafira2'

df_combined = pd.concat([partition_Auto1, partition_Auto2, partition_Auto3, partition_Auto4, partition_Auto5, partition_Zafira1, partition_Zafira2])
phthalate_mapping = {phthalate: i for i, phthalate in enumerate(df_combined['Phthalat:'].unique())}
df_combined['PhthalateNumeric'] = df_combined['Phthalat:'].map(phthalate_mapping)

print(df_combined)

means = df_combined.groupby(['PhthalateNumeric', 'Option'])['partition_phthalate'].mean().reset_index()
df_combined_reset = df_combined.reset_index(drop=True).dropna(subset=['partition_phthalate'])
# Out:
#                      Phthalat:  partition_phthalate   Option     Auto  \
# 0            Dimethylphthalate             0.241228  new_car    Auto1
# 1             Diethylphthalate             1.626308  new_car    Auto1
# 2             Dibutylphthalate             1.258575  new_car    Auto1
# 3         Benzylbutylphthalate           205.863020  new_car    Auto1
# 4  Bis(2-ethyl-hexyl)phthalate            21.847995  new_car    Auto1
# 5          Di-n-octylphthalate             1.365345  new_car    Auto1
# 0            Dimethylphthalate             0.580787  new_car    Auto2
# 1             Diethylphthalate             8.350890  new_car    Auto2
# 2             Dibutylphthalate             0.713286  new_car    Auto2
# 3         Benzylbutylphthalate           282.056567  new_car    Auto2
# 4  Bis(2-ethyl-hexyl)phthalate             1.498920  new_car    Auto2
# 5          Di-n-octylphthalate             1.729055  new_car    Auto2
# ...

# %%
plt.figure(figsize=(16, 10))
for option, color, marker in [('new_car', 'black', 'x'), ('old_car', 'black', 's')]:
    option_data = df_combined[df_combined['Option'] == option]
    plt.scatter(
        x=option_data['PhthalateNumeric'],
        y=option_data['partition_phthalate'],
        label=option,
        color=color,
        marker=marker,
        alpha=0.7
    )

for auto, color in zip(df_combined['Auto'].unique(), sns.color_palette('husl', n_colors=len(df_combined['Auto'].unique()))):
    auto_data = df_combined[df_combined['Auto'] == auto]
    plt.plot(
        auto_data['PhthalateNumeric'],
        auto_data['partition_phthalate'],
        linestyle='-',
        color=color,
        label=f'{auto} Line'
    )



plt.title('Phthalate partition comparison: new cars (n=4) and old cars (n=2)')
plt.xlabel('Phthalate')
plt.ylabel('gp/pm')
plt.xticks(ticks=range(len(phthalate_mapping)), labels=df_combined['Phthalat:'].unique())
plt.legend(loc='upper right')
plt.grid(True, axis='y', alpha=0.7)
plt.ylim(bottom=0, top=30)
plt.show()

# %%
plt.figure(figsize=(16, 10))
for option, color, marker in [('new_car', 'black', 'x'), ('old_car', 'black', 's')]:
    option_data = df_combined[df_combined['Option'] == option]
    plt.scatter(
        x=option_data['PhthalateNumeric'],
        y=option_data['partition_phthalate'],
        label=option,
        color=color,
        marker=marker,
        alpha=0.7
    )

for auto, color in zip(df_combined['Auto'].unique(), sns.color_palette('husl', n_colors=len(df_combined['Auto'].unique()))):
    auto_data = df_combined[df_combined['Auto'] == auto]
    plt.plot(
        auto_data['PhthalateNumeric'],
        auto_data['partition_phthalate'],
        linestyle='-',
        color=color,
        label=f'{auto} Line'
    )

plt.title('Phthalate partition comparison: new cars (n=4) and old cars (n=2)')
plt.xlabel('Phthalate')
plt.ylabel('gp/pm')
plt.xticks(ticks=range(len(phthalate_mapping)), labels=df_combined['Phthalat:'].unique())
plt.legend(loc='upper right')
plt.grid(True, axis='y', alpha=0.7)
plt.ylim(bottom=0, top=10)
plt.show()

# %%
partition_Auto1 = pd.DataFrame({'Phthalat:': Auto_1_gp_df['Phthalat:'], 'partition_phthalate': Auto_1_pm_df['Concentration [ng/m^3]'] / Auto_1_gp_df['Concentration [ng/m^3]']})
partition_Auto2 = pd.DataFrame({'Phthalat:': Auto_2_gp_df['Phthalat:'], 'partition_phthalate': Auto_2_pm_df['Concentration [ng/m^3]'] / Auto_2_gp_df['Concentration [ng/m^3]']})
partition_Auto3 = pd.DataFrame({'Phthalat:': Auto_3_gp_df['Phthalat:'], 'partition_phthalate': Auto_3_pm_df['Concentration [ng/m^3]'] / Auto_3_gp_df['Concentration [ng/m^3]']})
partition_Auto4 = pd.DataFrame({'Phthalat:': Auto_4_gp_df['Phthalat:'], 'partition_phthalate': Auto_4_pm_df['Concentration [ng/m^3]'] / Auto_4_gp_df['Concentration [ng/m^3]']})
partition_Auto5 = pd.DataFrame({'Phthalat:': Auto_5_gp_df['Phthalat:'], 'partition_phthalate': Auto_5_pm_df['Concentration [ng/m^3]'] / Auto_4_gp_df['Concentration [ng/m^3]']})

partition_Zafira1 = pd.DataFrame({'Phthalat:': Zafira_1_gp_df['Phthalat:'], 'partition_phthalate': Zafira_1_pm_df['Concentration [ng/m^3]'] / Zafira_1_gp_df['Concentration [ng/m^3]']})
partition_Zafira2 = pd.DataFrame({'Phthalat:': Zafira_2_gp_df['Phthalat:'], 'partition_phthalate': Zafira_2_pm_df['Concentration [ng/m^3]'] / Zafira_2_gp_df['Concentration [ng/m^3]']})

partition_Auto1['Option'] = 'new_car'
partition_Auto2['Option'] = 'new_car'
partition_Auto3['Option'] = 'new_car'
partition_Auto4['Option'] = 'new_car'
partition_Auto5['Option'] = 'new_car'
partition_Zafira1['Option'] = 'old_car'
partition_Zafira2['Option'] = 'old_car'

partition_Auto1['Auto'] = 'Auto1'
partition_Auto2['Auto'] = 'Auto2'
partition_Auto3['Auto'] = 'Auto3'
partition_Auto4['Auto'] = 'Auto4'
partition_Auto5['Auto'] = 'Auto5'
partition_Zafira1['Auto'] = 'Zafira1'
partition_Zafira2['Auto'] = 'Zafira2'

df_combined = pd.concat([partition_Auto1, partition_Auto2, partition_Auto3, partition_Auto4, partition_Auto5])

phthalate_mapping = {phthalate: i for i, phthalate in enumerate(df_combined['Phthalat:'].unique())}
df_combined['PhthalateNumeric'] = df_combined['Phthalat:'].map(phthalate_mapping)

# Create a mapping for Phthalate to numeric values
partition_mean = df_combined.groupby(['PhthalateNumeric'])['partition_phthalate'].mean().reset_index()

# Print the results
print("Mean:")
print(partition_mean)

# If you want to create a new dataframe with the averages
avg_df = pd.DataFrame({'PhthalateNumeric': partition_mean['PhthalateNumeric'], 'AveragePartition': partition_mean['partition_phthalate']})

# Print the new dataframe
print("\nNew Dataframe with Averages:")
print(avg_df)

partition_std = df_combined.groupby(['PhthalateNumeric'])['partition_phthalate'].std().reset_index()

# Print the results
print("Standard Deviation:")
print(partition_std)

# If you want to create a new dataframe with the standard deviations
std_df = pd.DataFrame({'PhthalateNumeric': partition_std['PhthalateNumeric'], 'StdDevPartition': partition_std['partition_phthalate']})

# Print the new dataframe
print("\nNew Dataframe with Standard Deviations:")
print(std_df)
# Out:
# Mean:
#    PhthalateNumeric  partition_phthalate
# 0                 0             0.243474
# 1                 1             3.480997
# 2                 2                  NaN
# 3                 3                  NaN
# 4                 4             5.539833
# 5                 5                  NaN
#
# New Dataframe with Averages:
#    PhthalateNumeric  AveragePartition
# 0                 0          0.243474
# 1                 1          3.480997
# 2                 2               NaN
# 3                 3               NaN
# 4                 4          5.539833
# 5                 5               NaN
# Standard Deviation:
#    PhthalateNumeric  partition_phthalate
# 0                 0             0.195698
# 1                 1             2.945518
# 2                 2                  NaN
# 3                 3                  NaN
# 4                 4             9.198666
# 5                 5                  NaN
#
# New Dataframe with Standard Deviations:
# ...

# %%
plt.figure(figsize=(12, 8))
#plt.scatter(x=avg_df['PhthalateNumeric'], y=avg_df['AveragePartition'], label=option, alpha=0.7)
plt.errorbar(x=std_df['PhthalateNumeric'], y=avg_df['AveragePartition'], yerr=std_df['StdDevPartition'],fmt = 'o',color = 'black', ecolor = 'black', capsize=10)
plt.ylabel('gp/pm')
custom_tick_labels = ['DMP', 'DEP', 'DBP', 'BBP', 'DEHP', 'DnOP']  # Replace with your custom labels
plt.xticks(ticks=range(len(custom_tick_labels)), labels=custom_tick_labels)
plt.grid(True, axis='y', alpha=0.7)
plt.yticks(np.arange(0, 11, 0.2))
plt.ylim(bottom=0, top=8)
plt.grid(False)

plt.savefig('/content/drive/My Drive/Plot_Partition.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(12, 8))
#plt.scatter(x=avg_df['PhthalateNumeric'], y=avg_df['AveragePartition'], label=option, alpha=0.7)
plt.errorbar(x=std_df['PhthalateNumeric'], y=avg_df['AveragePartition'], yerr=std_df['StdDevPartition'],fmt = 'o',color = 'black', ecolor = 'black', capsize=10)
plt.ylabel('gp/pm')
custom_tick_labels = ['DMP', 'DEP', 'DBP', 'BBP', 'DEHP', 'DnOP']  # Replace with your custom labels
plt.xticks(ticks=range(len(custom_tick_labels)), labels=custom_tick_labels)

ax = plt.gca()
ax.spines['bottom'].set_linewidth(2)
ax.spines['bottom'].set_color('black')
ax.spines['left'].set_linewidth(2)
ax.spines['left'].set_color('black')
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.grid(True, axis='y', alpha=0.5)
plt.yticks(np.arange(0, 11, 0.2))
plt.ylim(bottom=0, top=8)


plt.savefig('/content/drive/My Drive/Plot_Partition.png', dpi=300, bbox_inches='tight')
plt.show()
