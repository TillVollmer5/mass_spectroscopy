# %% [markdown]
# <a href="https://colab.research.google.com/github/TillVollmer5/mass_spectroscopy/blob/main/Hitlist_unknown_screening.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from google.colab import drive
import pandas as pd

drive.mount('/content/drive', force_remount = True)
# Out:
# Mounted at /content/drive

# %%
Auto_5_gp_df = pd.read_csv('/content/drive/My Drive/unknown_screening_data/Auto5_PUF_120k_blank_filtered.csv')
Auto_4_gp_df = pd.read_csv('/content/drive/My Drive/unknown_screening_data/Auto4_PUF_120k_blank_filtered.csv')
Auto_3_gp_df = pd.read_csv('/content/drive/My Drive/unknown_screening_data/Auto3_PUF_120k_blank_filtered.csv')
Auto_2_gp_df = pd.read_csv('/content/drive/My Drive/unknown_screening_data/Auto2_PUF_120k_blank_filtered.csv')
Auto_1_gp_df = pd.read_csv('/content/drive/My Drive/unknown_screening_data/Auto1_PUF_120k_blank_filtered.csv')
Zafira_2_gp_df = pd.read_csv('/content/drive/My Drive/unknown_screening_data/Zafira2_PUF_120k_blank_filtered.csv')
Zafira_1_gp_df = pd.read_csv('/content/drive/My Drive/unknown_screening_data/Zafira1_PUF_120k_blank_filtered.csv')

Auto_5_pm_df = pd.read_csv('/content/drive/My Drive/unknown_screening_data/Auto5_PF_120k_blank_filtered.csv')
Auto_4_pm_df = pd.read_csv('/content/drive/My Drive/unknown_screening_data/Auto4_PF_120k_blank_filtered.csv')
Auto_3_pm_df = pd.read_csv('/content/drive/My Drive/unknown_screening_data/Auto3_PF_120k_blank_filtered.csv')
Auto_2_pm_df = pd.read_csv('/content/drive/My Drive/unknown_screening_data/Auto2_PF_120k_blank_filtered.csv')
Auto_1_pm_df = pd.read_csv('/content/drive/My Drive/unknown_screening_data/Auto1_PF_120k_blank_filtered.csv')
Zafira_2_pm_df = pd.read_csv('/content/drive/My Drive/unknown_screening_data/Zafira2_PF_120k_blank_filtered.csv')
Zafira_1_pm_df = pd.read_csv('/content/drive/My Drive/unknown_screening_data/Zafira1_PF_120k_blank_filtered.csv')

U181_60k_df = pd.read_csv('/content/drive/My Drive/unknown_screening_data/U181_60k_blank_filtered.csv')
U181_120k_df = pd.read_csv('/content/drive/My Drive/unknown_screening_data/U181_120k_blank_filtered.csv')
U166_df = pd.read_csv('/content/drive/My Drive/unknown_screening_data/U166_blank_filtered.csv')
U164_df = pd.read_csv('/content/drive/My Drive/unknown_screening_data/U164_blank_filtered.csv')

# %%
dfs = [('Auto_5_gp_df', Auto_5_gp_df), ('Auto_4_gp_df', Auto_4_gp_df),
       ('Auto_3_gp_df', Auto_3_gp_df), ('Auto_2_gp_df', Auto_2_gp_df),
       ('Auto_1_gp_df', Auto_1_gp_df), ('Zafira_2_gp_df', Zafira_2_gp_df),
       ('Zafira_1_gp_df', Zafira_1_gp_df), ('Auto_5_pm_df', Auto_5_pm_df),
       ('Auto_4_pm_df', Auto_4_pm_df), ('Auto_3_pm_df', Auto_3_pm_df),
       ('Auto_2_pm_df', Auto_2_pm_df), ('Auto_1_pm_df', Auto_1_pm_df)]
       #,('Zafira_2_pm_df', Zafira_2_pm_df), ('Zafira_1_pm_df', Zafira_1_pm_df)
       #,('U181_60k_df', U181_60k_df), ('U181_120k_df', U181_120k_df),
       #('U166_df', U166_df), ('U164_df', U164_df)]

# %%
all_compounds = []
for _, df in dfs:
    all_compounds.extend(df['Component Name'].unique())

# Remove duplicates and create an empty dataframe with all compounds and samples
all_compounds = list(set(all_compounds))
compound_sample_df = pd.DataFrame(index=all_compounds)

# Add a new column for molecule formula
compound_sample_df['Formula (mol ion)'] = ''

# Fill the dataframe with area ratios and molecule formula
for df_name, df in dfs:
    for compound in all_compounds:
        # Check if the compound is in the current dataframe
        if compound in df['Component Name'].values:
            # Get the area ratio for the compound in the current sample
            area_ratio = df.loc[df['Component Name'] == compound, 'Area Ratio'].values[0]
            # Get the molecule formula for the compound in the current sample
            formula = df.loc[df['Component Name'] == compound, 'Formula (mol ion)'].values[0]

            # Set the values in the compound_sample_df
            compound_sample_df.loc[compound, df_name] = area_ratio
            compound_sample_df.loc[compound, 'Formula (mol ion)'] = formula
        else:
            # If compound is not in the current sample, set the value to 0 for area ratio
            compound_sample_df.loc[compound, df_name] = 0

# Display the resulting dataframe
print(compound_sample_df)
# Out:
#                                                    Formula (mol ion)  \
# Pyrrole, 2-methyl-5-phenyl-                                  C11H11N
# Octanoic acid, ethyl ester                                  C10H20O2
# 2H-1,2-Oxaborin, 2,3,3-triethyl-3,6-dihydro-                C10H19BO
# 2-Ethyl-1-hexanol, trifluoroacetate                       C10H17F3O2
# Furan, 2-(1,1-dimethylethyl)-4-methyl-                        C9H14O
# ...                                                              ...
# Cyclohexane, 1-(cyclohexylmethyl)-4-ethyl-, trans-            C15H28
# 3-(3,4-dihydroxyphenyl)-2-hydroxypropanoic acid              C9H10O5
# 2-(1-Benzoylaminoethyl)-3-methyl-4-nitrobutyric...        C15H20N2O5
# 5-Chloro-1,3-dimethyl-1H-pyrazole-4-sulfonic ac...   C10H10ClF3N4O3S
# m-Aminophenylacetylene                                         C8H7N
#
#                                                     Auto_5_gp_df  \
# Pyrrole, 2-methyl-5-phenyl-                             0.000000
# Octanoic acid, ethyl ester                              0.000000
# 2H-1,2-Oxaborin, 2,3,3-triethyl-3,6-dihydro-            0.000000
# 2-Ethyl-1-hexanol, trifluoroacetate                     0.000000
# Furan, 2-(1,1-dimethylethyl)-4-methyl-                  0.000000
# ...                                                          ...
# Cyclohexane, 1-(cyclohexylmethyl)-4-ethyl-, trans-      0.000000
# 3-(3,4-dihydroxyphenyl)-2-hydroxypropanoic acid         0.000000
# 2-(1-Benzoylaminoethyl)-3-methyl-4-nitrobutyric...      0.016439
# 5-Chloro-1,3-dimethyl-1H-pyrazole-4-sulfonic ac...      0.000000
# m-Aminophenylacetylene                                  0.000000
#
#                                                     Auto_4_gp_df  \
# Pyrrole, 2-methyl-5-phenyl-                             0.000000
# Octanoic acid, ethyl ester                              0.000000
# 2H-1,2-Oxaborin, 2,3,3-triethyl-3,6-dihydro-            0.000000
# 2-Ethyl-1-hexanol, trifluoroacetate                     0.000000
# Furan, 2-(1,1-dimethylethyl)-4-methyl-                  0.000000
# ...                                                          ...
# Cyclohexane, 1-(cyclohexylmethyl)-4-ethyl-, trans-      0.000000
# 3-(3,4-dihydroxyphenyl)-2-hydroxypropanoic acid         0.001641
# 2-(1-Benzoylaminoethyl)-3-methyl-4-nitrobutyric...      0.000000
# 5-Chloro-1,3-dimethyl-1H-pyrazole-4-sulfonic ac...      0.000000
# m-Aminophenylacetylene                                  0.000000
#
#                                                     Auto_3_gp_df  \
# Pyrrole, 2-methyl-5-phenyl-                             0.000000
# Octanoic acid, ethyl ester                              0.000000
# 2H-1,2-Oxaborin, 2,3,3-triethyl-3,6-dihydro-            0.000000
# 2-Ethyl-1-hexanol, trifluoroacetate                     0.608262
# Furan, 2-(1,1-dimethylethyl)-4-methyl-                  0.014899
# ...                                                          ...
# Cyclohexane, 1-(cyclohexylmethyl)-4-ethyl-, trans-      0.000000
# 3-(3,4-dihydroxyphenyl)-2-hydroxypropanoic acid         0.000000
# 2-(1-Benzoylaminoethyl)-3-methyl-4-nitrobutyric...      0.000000
# 5-Chloro-1,3-dimethyl-1H-pyrazole-4-sulfonic ac...      0.000000
# m-Aminophenylacetylene                                  0.000000
#
#                                                     Auto_2_gp_df  \
# Pyrrole, 2-methyl-5-phenyl-                             0.000000
# Octanoic acid, ethyl ester                              0.000000
# 2H-1,2-Oxaborin, 2,3,3-triethyl-3,6-dihydro-            0.000000
# 2-Ethyl-1-hexanol, trifluoroacetate                     0.000000
# Furan, 2-(1,1-dimethylethyl)-4-methyl-                  0.000000
# ...                                                          ...
# Cyclohexane, 1-(cyclohexylmethyl)-4-ethyl-, trans-      0.059472
# 3-(3,4-dihydroxyphenyl)-2-hydroxypropanoic acid         0.000000
# 2-(1-Benzoylaminoethyl)-3-methyl-4-nitrobutyric...      0.000000
# 5-Chloro-1,3-dimethyl-1H-pyrazole-4-sulfonic ac...      0.000000
# m-Aminophenylacetylene                                  0.000000
#
#                                                     Auto_1_gp_df  \
# Pyrrole, 2-methyl-5-phenyl-                             0.000000
# Octanoic acid, ethyl ester                              0.000000
# 2H-1,2-Oxaborin, 2,3,3-triethyl-3,6-dihydro-            0.942981
# 2-Ethyl-1-hexanol, trifluoroacetate                     0.000000
# Furan, 2-(1,1-dimethylethyl)-4-methyl-                  0.026270
# ...                                                          ...
# Cyclohexane, 1-(cyclohexylmethyl)-4-ethyl-, trans-      0.000000
# 3-(3,4-dihydroxyphenyl)-2-hydroxypropanoic acid         0.000000
# 2-(1-Benzoylaminoethyl)-3-methyl-4-nitrobutyric...      0.000000
# 5-Chloro-1,3-dimethyl-1H-pyrazole-4-sulfonic ac...      0.000000
# m-Aminophenylacetylene                                  0.000000
#
#                                                     Zafira_2_gp_df  \
# Pyrrole, 2-methyl-5-phenyl-                                    0.0
# Octanoic acid, ethyl ester                                     0.0
# 2H-1,2-Oxaborin, 2,3,3-triethyl-3,6-dihydro-                   0.0
# 2-Ethyl-1-hexanol, trifluoroacetate                            0.0
# Furan, 2-(1,1-dimethylethyl)-4-methyl-                         0.0
# ...                                                            ...
# Cyclohexane, 1-(cyclohexylmethyl)-4-ethyl-, trans-             0.0
# 3-(3,4-dihydroxyphenyl)-2-hydroxypropanoic acid                0.0
# 2-(1-Benzoylaminoethyl)-3-methyl-4-nitrobutyric...             0.0
# 5-Chloro-1,3-dimethyl-1H-pyrazole-4-sulfonic ac...             0.0
# m-Aminophenylacetylene                                         0.0
#
#                                                     Zafira_1_gp_df  \
# Pyrrole, 2-methyl-5-phenyl-                               0.000000
# Octanoic acid, ethyl ester                                0.000000
# 2H-1,2-Oxaborin, 2,3,3-triethyl-3,6-dihydro-              0.000000
# 2-Ethyl-1-hexanol, trifluoroacetate                       0.000000
# Furan, 2-(1,1-dimethylethyl)-4-methyl-                    0.000000
# ...                                                            ...
# Cyclohexane, 1-(cyclohexylmethyl)-4-ethyl-, trans-        0.152960
# 3-(3,4-dihydroxyphenyl)-2-hydroxypropanoic acid           0.000000
# 2-(1-Benzoylaminoethyl)-3-methyl-4-nitrobutyric...        0.000000
# 5-Chloro-1,3-dimethyl-1H-pyrazole-4-sulfonic ac...        0.000000
# m-Aminophenylacetylene                                    0.004259
#
#                                                     Auto_5_pm_df  \
# Pyrrole, 2-methyl-5-phenyl-                             0.038105
# Octanoic acid, ethyl ester                              0.000000
# 2H-1,2-Oxaborin, 2,3,3-triethyl-3,6-dihydro-            0.000000
# 2-Ethyl-1-hexanol, trifluoroacetate                     0.000000
# Furan, 2-(1,1-dimethylethyl)-4-methyl-                  0.000000
# ...                                                          ...
# Cyclohexane, 1-(cyclohexylmethyl)-4-ethyl-, trans-      0.000000
# 3-(3,4-dihydroxyphenyl)-2-hydroxypropanoic acid         0.000000
# 2-(1-Benzoylaminoethyl)-3-methyl-4-nitrobutyric...      0.000000
# 5-Chloro-1,3-dimethyl-1H-pyrazole-4-sulfonic ac...      0.268443
# m-Aminophenylacetylene                                  0.000000
#
#                                                     Auto_4_pm_df  \
# Pyrrole, 2-methyl-5-phenyl-                             0.000000
# Octanoic acid, ethyl ester                              0.008376
# 2H-1,2-Oxaborin, 2,3,3-triethyl-3,6-dihydro-            0.000000
# 2-Ethyl-1-hexanol, trifluoroacetate                     0.000000
# Furan, 2-(1,1-dimethylethyl)-4-methyl-                  0.000000
# ...                                                          ...
# Cyclohexane, 1-(cyclohexylmethyl)-4-ethyl-, trans-      0.000000
# 3-(3,4-dihydroxyphenyl)-2-hydroxypropanoic acid         0.000000
# 2-(1-Benzoylaminoethyl)-3-methyl-4-nitrobutyric...      0.000000
# 5-Chloro-1,3-dimethyl-1H-pyrazole-4-sulfonic ac...      0.000000
# m-Aminophenylacetylene                                  0.000000
#
#                                                     Auto_3_pm_df  \
# Pyrrole, 2-methyl-5-phenyl-                             0.000000
# Octanoic acid, ethyl ester                              0.008079
# 2H-1,2-Oxaborin, 2,3,3-triethyl-3,6-dihydro-            0.000000
# 2-Ethyl-1-hexanol, trifluoroacetate                     0.000000
# Furan, 2-(1,1-dimethylethyl)-4-methyl-                  0.000000
# ...                                                          ...
# Cyclohexane, 1-(cyclohexylmethyl)-4-ethyl-, trans-      0.000000
# 3-(3,4-dihydroxyphenyl)-2-hydroxypropanoic acid         0.000000
# 2-(1-Benzoylaminoethyl)-3-methyl-4-nitrobutyric...      0.000000
# 5-Chloro-1,3-dimethyl-1H-pyrazole-4-sulfonic ac...      0.000000
# m-Aminophenylacetylene                                  0.000000
#
#                                                     Auto_2_pm_df  Auto_1_pm_df
# Pyrrole, 2-methyl-5-phenyl-                              0.00000           0.0
# Octanoic acid, ethyl ester                               0.00000           0.0
# 2H-1,2-Oxaborin, 2,3,3-triethyl-3,6-dihydro-             0.00000           0.0
# 2-Ethyl-1-hexanol, trifluoroacetate                      0.00000           0.0
# Furan, 2-(1,1-dimethylethyl)-4-methyl-                   0.00000           0.0
# ...                                                          ...           ...
# Cyclohexane, 1-(cyclohexylmethyl)-4-ethyl-, trans-       0.00000           0.0
# 3-(3,4-dihydroxyphenyl)-2-hydroxypropanoic acid          0.00000           0.0
# 2-(1-Benzoylaminoethyl)-3-methyl-4-nitrobutyric...       0.00000           0.0
# 5-Chloro-1,3-dimethyl-1H-pyrazole-4-sulfonic ac...       0.20405           0.0
# m-Aminophenylacetylene                                   0.00000           0.0
#
# [3827 rows x 13 columns]

# %%
compound_sample_df_rearanged = compound_sample_df.sort_values(by='Formula (mol ion)')

print(compound_sample_df_rearanged)
# Out:
#                                                    Formula (mol ion)  \
# Pyrimidine, 2-[4'-(1                                          101948
# Alanylalanylalanine, N,N',N-trimethyl-N"-propar...            117774
# 4-Ethylphenylacetylene                                        C10H10
# Benzene, (1-methyl-2-cyclopropen-1-yl)-                       C10H10
# Benzene, (cyclopropylidenemethyl)-                            C10H10
# ...                                                              ...
# 4-Penten-1-ol, heptafluorobutyrate                          C9H9F7O2
# 2-Propyn-1-amine, N,N-di-2-propynyl-                           C9H9N
# 1H-1,2,3-Triazole, 4-(4-methoxyphenyl)-                      C9H9N3O
# 5-Dicyanomethylene-pyrrolidin-2-carboxylic acid...          C9H9N3O2
# 3H-indol-3-one, 1,2-dihydro-1-(methylsulfonyl)-             C9H9NO3S
#
#                                                     Auto_5_gp_df  \
# Pyrimidine, 2-[4'-(1                                         0.0
# Alanylalanylalanine, N,N',N-trimethyl-N"-propar...           0.0
# 4-Ethylphenylacetylene                                       0.0
# Benzene, (1-methyl-2-cyclopropen-1-yl)-                      0.0
# Benzene, (cyclopropylidenemethyl)-                           0.0
# ...                                                          ...
# 4-Penten-1-ol, heptafluorobutyrate                           0.0
# 2-Propyn-1-amine, N,N-di-2-propynyl-                         0.0
# 1H-1,2,3-Triazole, 4-(4-methoxyphenyl)-                      0.0
# 5-Dicyanomethylene-pyrrolidin-2-carboxylic acid...           0.0
# 3H-indol-3-one, 1,2-dihydro-1-(methylsulfonyl)-              0.0
#
#                                                     Auto_4_gp_df  \
# Pyrimidine, 2-[4'-(1                                    0.000000
# Alanylalanylalanine, N,N',N-trimethyl-N"-propar...      0.000000
# 4-Ethylphenylacetylene                                  0.000000
# Benzene, (1-methyl-2-cyclopropen-1-yl)-                 0.050326
# Benzene, (cyclopropylidenemethyl)-                      0.008046
# ...                                                          ...
# 4-Penten-1-ol, heptafluorobutyrate                      0.000000
# 2-Propyn-1-amine, N,N-di-2-propynyl-                    0.000000
# 1H-1,2,3-Triazole, 4-(4-methoxyphenyl)-                 0.000000
# 5-Dicyanomethylene-pyrrolidin-2-carboxylic acid...      0.000000
# 3H-indol-3-one, 1,2-dihydro-1-(methylsulfonyl)-         0.000000
#
#                                                     Auto_3_gp_df  \
# Pyrimidine, 2-[4'-(1                                         0.0
# Alanylalanylalanine, N,N',N-trimethyl-N"-propar...           0.0
# 4-Ethylphenylacetylene                                       0.0
# Benzene, (1-methyl-2-cyclopropen-1-yl)-                      0.0
# Benzene, (cyclopropylidenemethyl)-                           0.0
# ...                                                          ...
# 4-Penten-1-ol, heptafluorobutyrate                           0.0
# 2-Propyn-1-amine, N,N-di-2-propynyl-                         0.0
# 1H-1,2,3-Triazole, 4-(4-methoxyphenyl)-                      0.0
# 5-Dicyanomethylene-pyrrolidin-2-carboxylic acid...           0.0
# 3H-indol-3-one, 1,2-dihydro-1-(methylsulfonyl)-              0.0
#
#                                                     Auto_2_gp_df  \
# Pyrimidine, 2-[4'-(1                                    0.000000
# Alanylalanylalanine, N,N',N-trimethyl-N"-propar...      0.000000
# 4-Ethylphenylacetylene                                  0.000000
# Benzene, (1-methyl-2-cyclopropen-1-yl)-                 0.056242
# Benzene, (cyclopropylidenemethyl)-                      0.000000
# ...                                                          ...
# 4-Penten-1-ol, heptafluorobutyrate                      0.000000
# 2-Propyn-1-amine, N,N-di-2-propynyl-                    0.000000
# 1H-1,2,3-Triazole, 4-(4-methoxyphenyl)-                 0.000000
# 5-Dicyanomethylene-pyrrolidin-2-carboxylic acid...      0.000000
# 3H-indol-3-one, 1,2-dihydro-1-(methylsulfonyl)-         0.000000
#
#                                                     Auto_1_gp_df  \
# Pyrimidine, 2-[4'-(1                                    0.000000
# Alanylalanylalanine, N,N',N-trimethyl-N"-propar...      0.000000
# 4-Ethylphenylacetylene                                  0.000000
# Benzene, (1-methyl-2-cyclopropen-1-yl)-                 0.000000
# Benzene, (cyclopropylidenemethyl)-                      0.017299
# ...                                                          ...
# 4-Penten-1-ol, heptafluorobutyrate                      0.000000
# 2-Propyn-1-amine, N,N-di-2-propynyl-                    0.000000
# 1H-1,2,3-Triazole, 4-(4-methoxyphenyl)-                 0.000000
# 5-Dicyanomethylene-pyrrolidin-2-carboxylic acid...      0.000000
# 3H-indol-3-one, 1,2-dihydro-1-(methylsulfonyl)-         0.004043
#
#                                                     Zafira_2_gp_df  \
# Pyrimidine, 2-[4'-(1                                  0.000000e+00
# Alanylalanylalanine, N,N',N-trimethyl-N"-propar...    2.382282e-07
# 4-Ethylphenylacetylene                                0.000000e+00
# Benzene, (1-methyl-2-cyclopropen-1-yl)-               0.000000e+00
# Benzene, (cyclopropylidenemethyl)-                    4.787141e-03
# ...                                                            ...
# 4-Penten-1-ol, heptafluorobutyrate                    0.000000e+00
# 2-Propyn-1-amine, N,N-di-2-propynyl-                  0.000000e+00
# 1H-1,2,3-Triazole, 4-(4-methoxyphenyl)-               0.000000e+00
# 5-Dicyanomethylene-pyrrolidin-2-carboxylic acid...    0.000000e+00
# 3H-indol-3-one, 1,2-dihydro-1-(methylsulfonyl)-       0.000000e+00
#
#                                                     Zafira_1_gp_df  \
# Pyrimidine, 2-[4'-(1                                      0.000000
# Alanylalanylalanine, N,N',N-trimethyl-N"-propar...        0.000000
# 4-Ethylphenylacetylene                                    0.012349
# Benzene, (1-methyl-2-cyclopropen-1-yl)-                   0.000000
# Benzene, (cyclopropylidenemethyl)-                        0.000000
# ...                                                            ...
# 4-Penten-1-ol, heptafluorobutyrate                        0.000000
# 2-Propyn-1-amine, N,N-di-2-propynyl-                      0.009232
# 1H-1,2,3-Triazole, 4-(4-methoxyphenyl)-                   0.000000
# 5-Dicyanomethylene-pyrrolidin-2-carboxylic acid...        0.005627
# 3H-indol-3-one, 1,2-dihydro-1-(methylsulfonyl)-           0.000000
#
#                                                     Auto_5_pm_df  \
# Pyrimidine, 2-[4'-(1                                1.232067e-07
# Alanylalanylalanine, N,N',N-trimethyl-N"-propar...  0.000000e+00
# 4-Ethylphenylacetylene                              0.000000e+00
# Benzene, (1-methyl-2-cyclopropen-1-yl)-             0.000000e+00
# Benzene, (cyclopropylidenemethyl)-                  0.000000e+00
# ...                                                          ...
# 4-Penten-1-ol, heptafluorobutyrate                  5.180287e-03
# 2-Propyn-1-amine, N,N-di-2-propynyl-                0.000000e+00
# 1H-1,2,3-Triazole, 4-(4-methoxyphenyl)-             0.000000e+00
# 5-Dicyanomethylene-pyrrolidin-2-carboxylic acid...  0.000000e+00
# 3H-indol-3-one, 1,2-dihydro-1-(methylsulfonyl)-     0.000000e+00
#
#                                                     Auto_4_pm_df  \
# Pyrimidine, 2-[4'-(1                                         0.0
# Alanylalanylalanine, N,N',N-trimethyl-N"-propar...           0.0
# 4-Ethylphenylacetylene                                       0.0
# Benzene, (1-methyl-2-cyclopropen-1-yl)-                      0.0
# Benzene, (cyclopropylidenemethyl)-                           0.0
# ...                                                          ...
# 4-Penten-1-ol, heptafluorobutyrate                           0.0
# 2-Propyn-1-amine, N,N-di-2-propynyl-                         0.0
# 1H-1,2,3-Triazole, 4-(4-methoxyphenyl)-                      0.0
# 5-Dicyanomethylene-pyrrolidin-2-carboxylic acid...           0.0
# 3H-indol-3-one, 1,2-dihydro-1-(methylsulfonyl)-              0.0
#
#                                                     Auto_3_pm_df  \
# Pyrimidine, 2-[4'-(1                                         0.0
# Alanylalanylalanine, N,N',N-trimethyl-N"-propar...           0.0
# 4-Ethylphenylacetylene                                       0.0
# Benzene, (1-methyl-2-cyclopropen-1-yl)-                      0.0
# Benzene, (cyclopropylidenemethyl)-                           0.0
# ...                                                          ...
# 4-Penten-1-ol, heptafluorobutyrate                           0.0
# 2-Propyn-1-amine, N,N-di-2-propynyl-                         0.0
# 1H-1,2,3-Triazole, 4-(4-methoxyphenyl)-                      0.0
# 5-Dicyanomethylene-pyrrolidin-2-carboxylic acid...           0.0
# 3H-indol-3-one, 1,2-dihydro-1-(methylsulfonyl)-              0.0
#
#                                                     Auto_2_pm_df  \
# Pyrimidine, 2-[4'-(1                                    0.000000
# Alanylalanylalanine, N,N',N-trimethyl-N"-propar...      0.000000
# 4-Ethylphenylacetylene                                  0.000000
# Benzene, (1-methyl-2-cyclopropen-1-yl)-                 0.000000
# Benzene, (cyclopropylidenemethyl)-                      0.000000
# ...                                                          ...
# 4-Penten-1-ol, heptafluorobutyrate                      0.000000
# 2-Propyn-1-amine, N,N-di-2-propynyl-                    0.000000
# 1H-1,2,3-Triazole, 4-(4-methoxyphenyl)-                 0.001966
# 5-Dicyanomethylene-pyrrolidin-2-carboxylic acid...      0.000000
# 3H-indol-3-one, 1,2-dihydro-1-(methylsulfonyl)-         0.000000
#
#                                                     Auto_1_pm_df  \
# Pyrimidine, 2-[4'-(1                                         0.0
# Alanylalanylalanine, N,N',N-trimethyl-N"-propar...           0.0
# 4-Ethylphenylacetylene                                       0.0
# Benzene, (1-methyl-2-cyclopropen-1-yl)-                      0.0
# Benzene, (cyclopropylidenemethyl)-                           0.0
# ...                                                          ...
# 4-Penten-1-ol, heptafluorobutyrate                           0.0
# 2-Propyn-1-amine, N,N-di-2-propynyl-                         0.0
# 1H-1,2,3-Triazole, 4-(4-methoxyphenyl)-                      0.0
# 5-Dicyanomethylene-pyrrolidin-2-carboxylic acid...           0.0
# 3H-indol-3-one, 1,2-dihydro-1-(methylsulfonyl)-              0.0
#
#                                                     Zafira_2_pm_df  \
# Pyrimidine, 2-[4'-(1                                      0.000000
# Alanylalanylalanine, N,N',N-trimethyl-N"-propar...        0.000000
# 4-Ethylphenylacetylene                                    0.000000
# Benzene, (1-methyl-2-cyclopropen-1-yl)-                   0.000404
# Benzene, (cyclopropylidenemethyl)-                        0.000000
# ...                                                            ...
# 4-Penten-1-ol, heptafluorobutyrate                        0.000000
# 2-Propyn-1-amine, N,N-di-2-propynyl-                      0.000000
# 1H-1,2,3-Triazole, 4-(4-methoxyphenyl)-                   0.000000
# 5-Dicyanomethylene-pyrrolidin-2-carboxylic acid...        0.000000
# 3H-indol-3-one, 1,2-dihydro-1-(methylsulfonyl)-           0.000000
#
#                                                     Zafira_1_pm_df
# Pyrimidine, 2-[4'-(1                                           0.0
# Alanylalanylalanine, N,N',N-trimethyl-N"-propar...             0.0
# 4-Ethylphenylacetylene                                         0.0
# Benzene, (1-methyl-2-cyclopropen-1-yl)-                        0.0
# Benzene, (cyclopropylidenemethyl)-                             0.0
# ...                                                            ...
# 4-Penten-1-ol, heptafluorobutyrate                             0.0
# 2-Propyn-1-amine, N,N-di-2-propynyl-                           0.0
# 1H-1,2,3-Triazole, 4-(4-methoxyphenyl)-                        0.0
# 5-Dicyanomethylene-pyrrolidin-2-carboxylic acid...             0.0
# 3H-indol-3-one, 1,2-dihydro-1-(methylsulfonyl)-                0.0
#
# [4253 rows x 15 columns]

# %%
duplicated_rows = compound_sample_df[compound_sample_df.duplicated(subset='Formula (mol ion)', keep=False)]

# Display the resulting dataframe with duplicated rows
print(duplicated_rows)
# Out:
#                                                    Formula (mol ion)  \
# Pyrrole, 2-methyl-5-phenyl-                                  C11H11N
# Octanoic acid, ethyl ester                                  C10H20O2
# 2-Ethyl-1-hexanol, trifluoroacetate                       C10H17F3O2
# Furan, 2-(1,1-dimethylethyl)-4-methyl-                        C9H14O
# Heptane, 2-methyl-3-methylene-                                 C9H18
# ...                                                              ...
# N-Methyl-2-isopropoxycarbonylazetidine                      C8H15NO2
# Cyclohexanecarboxylic acid, 1-cyclohpentylethyl...          C14H24O2
# 2-Propenenitrile, 3-phenyl-, (E)-                              C9H7N
# Cyclohexane, 1-(cyclohexylmethyl)-4-ethyl-, trans-            C15H28
# m-Aminophenylacetylene                                         C8H7N
#
#                                                     Auto_5_gp_df  \
# Pyrrole, 2-methyl-5-phenyl-                             0.000000
# Octanoic acid, ethyl ester                              0.000000
# 2-Ethyl-1-hexanol, trifluoroacetate                     0.000000
# Furan, 2-(1,1-dimethylethyl)-4-methyl-                  0.000000
# Heptane, 2-methyl-3-methylene-                          0.000000
# ...                                                          ...
# N-Methyl-2-isopropoxycarbonylazetidine                  0.000000
# Cyclohexanecarboxylic acid, 1-cyclohpentylethyl...      0.000000
# 2-Propenenitrile, 3-phenyl-, (E)-                       0.040952
# Cyclohexane, 1-(cyclohexylmethyl)-4-ethyl-, trans-      0.000000
# m-Aminophenylacetylene                                  0.000000
#
#                                                     Auto_4_gp_df  \
# Pyrrole, 2-methyl-5-phenyl-                             0.000000
# Octanoic acid, ethyl ester                              0.000000
# 2-Ethyl-1-hexanol, trifluoroacetate                     0.000000
# Furan, 2-(1,1-dimethylethyl)-4-methyl-                  0.000000
# Heptane, 2-methyl-3-methylene-                          0.000000
# ...                                                          ...
# N-Methyl-2-isopropoxycarbonylazetidine                  0.000000
# Cyclohexanecarboxylic acid, 1-cyclohpentylethyl...      0.000000
# 2-Propenenitrile, 3-phenyl-, (E)-                       0.028706
# Cyclohexane, 1-(cyclohexylmethyl)-4-ethyl-, trans-      0.000000
# m-Aminophenylacetylene                                  0.000000
#
#                                                     Auto_3_gp_df  \
# Pyrrole, 2-methyl-5-phenyl-                             0.000000
# Octanoic acid, ethyl ester                              0.000000
# 2-Ethyl-1-hexanol, trifluoroacetate                     0.608262
# Furan, 2-(1,1-dimethylethyl)-4-methyl-                  0.014899
# Heptane, 2-methyl-3-methylene-                          0.000000
# ...                                                          ...
# N-Methyl-2-isopropoxycarbonylazetidine                  0.015622
# Cyclohexanecarboxylic acid, 1-cyclohpentylethyl...      0.000000
# 2-Propenenitrile, 3-phenyl-, (E)-                       0.038224
# Cyclohexane, 1-(cyclohexylmethyl)-4-ethyl-, trans-      0.000000
# m-Aminophenylacetylene                                  0.000000
#
#                                                     Auto_2_gp_df  \
# Pyrrole, 2-methyl-5-phenyl-                             0.000000
# Octanoic acid, ethyl ester                              0.000000
# 2-Ethyl-1-hexanol, trifluoroacetate                     0.000000
# Furan, 2-(1,1-dimethylethyl)-4-methyl-                  0.000000
# Heptane, 2-methyl-3-methylene-                          0.012414
# ...                                                          ...
# N-Methyl-2-isopropoxycarbonylazetidine                  0.000000
# Cyclohexanecarboxylic acid, 1-cyclohpentylethyl...      0.026988
# 2-Propenenitrile, 3-phenyl-, (E)-                       0.049298
# Cyclohexane, 1-(cyclohexylmethyl)-4-ethyl-, trans-      0.059472
# m-Aminophenylacetylene                                  0.000000
#
#                                                     Auto_1_gp_df  \
# Pyrrole, 2-methyl-5-phenyl-                              0.00000
# Octanoic acid, ethyl ester                               0.00000
# 2-Ethyl-1-hexanol, trifluoroacetate                      0.00000
# Furan, 2-(1,1-dimethylethyl)-4-methyl-                   0.02627
# Heptane, 2-methyl-3-methylene-                           0.00000
# ...                                                          ...
# N-Methyl-2-isopropoxycarbonylazetidine                   0.00000
# Cyclohexanecarboxylic acid, 1-cyclohpentylethyl...       0.00000
# 2-Propenenitrile, 3-phenyl-, (E)-                        0.00000
# Cyclohexane, 1-(cyclohexylmethyl)-4-ethyl-, trans-       0.00000
# m-Aminophenylacetylene                                   0.00000
#
#                                                     Zafira_2_gp_df  \
# Pyrrole, 2-methyl-5-phenyl-                               0.000000
# Octanoic acid, ethyl ester                                0.000000
# 2-Ethyl-1-hexanol, trifluoroacetate                       0.000000
# Furan, 2-(1,1-dimethylethyl)-4-methyl-                    0.000000
# Heptane, 2-methyl-3-methylene-                            0.000000
# ...                                                            ...
# N-Methyl-2-isopropoxycarbonylazetidine                    0.000000
# Cyclohexanecarboxylic acid, 1-cyclohpentylethyl...        0.000000
# 2-Propenenitrile, 3-phenyl-, (E)-                         0.044932
# Cyclohexane, 1-(cyclohexylmethyl)-4-ethyl-, trans-        0.000000
# m-Aminophenylacetylene                                    0.000000
#
#                                                     Zafira_1_gp_df  \
# Pyrrole, 2-methyl-5-phenyl-                               0.000000
# Octanoic acid, ethyl ester                                0.000000
# 2-Ethyl-1-hexanol, trifluoroacetate                       0.000000
# Furan, 2-(1,1-dimethylethyl)-4-methyl-                    0.000000
# Heptane, 2-methyl-3-methylene-                            0.000000
# ...                                                            ...
# N-Methyl-2-isopropoxycarbonylazetidine                    0.000000
# Cyclohexanecarboxylic acid, 1-cyclohpentylethyl...        0.000000
# 2-Propenenitrile, 3-phenyl-, (E)-                         0.000000
# Cyclohexane, 1-(cyclohexylmethyl)-4-ethyl-, trans-        0.152960
# m-Aminophenylacetylene                                    0.004259
#
#                                                     Auto_5_pm_df  \
# Pyrrole, 2-methyl-5-phenyl-                             0.038105
# Octanoic acid, ethyl ester                              0.000000
# 2-Ethyl-1-hexanol, trifluoroacetate                     0.000000
# Furan, 2-(1,1-dimethylethyl)-4-methyl-                  0.000000
# Heptane, 2-methyl-3-methylene-                          0.000000
# ...                                                          ...
# N-Methyl-2-isopropoxycarbonylazetidine                  0.000000
# Cyclohexanecarboxylic acid, 1-cyclohpentylethyl...      0.000000
# 2-Propenenitrile, 3-phenyl-, (E)-                       0.000000
# Cyclohexane, 1-(cyclohexylmethyl)-4-ethyl-, trans-      0.000000
# m-Aminophenylacetylene                                  0.000000
#
#                                                     Auto_4_pm_df  \
# Pyrrole, 2-methyl-5-phenyl-                             0.000000
# Octanoic acid, ethyl ester                              0.008376
# 2-Ethyl-1-hexanol, trifluoroacetate                     0.000000
# Furan, 2-(1,1-dimethylethyl)-4-methyl-                  0.000000
# Heptane, 2-methyl-3-methylene-                          0.000000
# ...                                                          ...
# N-Methyl-2-isopropoxycarbonylazetidine                  0.000000
# Cyclohexanecarboxylic acid, 1-cyclohpentylethyl...      0.000000
# 2-Propenenitrile, 3-phenyl-, (E)-                       0.000000
# Cyclohexane, 1-(cyclohexylmethyl)-4-ethyl-, trans-      0.000000
# m-Aminophenylacetylene                                  0.000000
#
#                                                     Auto_3_pm_df  \
# Pyrrole, 2-methyl-5-phenyl-                             0.000000
# Octanoic acid, ethyl ester                              0.008079
# 2-Ethyl-1-hexanol, trifluoroacetate                     0.000000
# Furan, 2-(1,1-dimethylethyl)-4-methyl-                  0.000000
# Heptane, 2-methyl-3-methylene-                          0.000000
# ...                                                          ...
# N-Methyl-2-isopropoxycarbonylazetidine                  0.000000
# Cyclohexanecarboxylic acid, 1-cyclohpentylethyl...      0.000000
# 2-Propenenitrile, 3-phenyl-, (E)-                       0.000000
# Cyclohexane, 1-(cyclohexylmethyl)-4-ethyl-, trans-      0.000000
# m-Aminophenylacetylene                                  0.000000
#
#                                                     Auto_2_pm_df  Auto_1_pm_df
# Pyrrole, 2-methyl-5-phenyl-                                  0.0           0.0
# Octanoic acid, ethyl ester                                   0.0           0.0
# 2-Ethyl-1-hexanol, trifluoroacetate                          0.0           0.0
# Furan, 2-(1,1-dimethylethyl)-4-methyl-                       0.0           0.0
# Heptane, 2-methyl-3-methylene-                               0.0           0.0
# ...                                                          ...           ...
# N-Methyl-2-isopropoxycarbonylazetidine                       0.0           0.0
# Cyclohexanecarboxylic acid, 1-cyclohpentylethyl...           0.0           0.0
# 2-Propenenitrile, 3-phenyl-, (E)-                            0.0           0.0
# Cyclohexane, 1-(cyclohexylmethyl)-4-ethyl-, trans-           0.0           0.0
# m-Aminophenylacetylene                                       0.0           0.0
#
# [2233 rows x 13 columns]

# %%
combined_duplicated_rows = pd.DataFrame(columns=duplicated_rows.columns)

for formula, group in duplicated_rows.groupby('Formula (mol ion)'):
    # Initialize the selected row with the row having the minimum non-zero values
    selected_row = group.loc[group.ne(0).sum(axis=1).idxmin()].copy()

    # Iterate over columns to check the condition
    for col in group.columns[1:]:  # Skip the 'Formula (mol ion)' column
        # Check if there's a zero in the same column for the selected row
        if selected_row[col] == 0:
            # Debugging information
            print(f"Formula: {formula}, Column: {col}")

            # Find the row with the maximum non-zero values across all columns
            max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]

            # Combine the rows if there are two non-zero values in the same column
            selected_row[col] = max_nonzero_row[col]

    # Add the selected row to the combined dataframe
    combined_duplicated_rows = combined_duplicated_rows.append(selected_row)

# Display the resulting dataframe with combined duplicated rows
print(combined_duplicated_rows)

# Save the resulting dataframe to a CSV file
combined_duplicated_rows.to_csv('/content/drive/My Drive/unknown_screening_data/Hitlist_non_duplicates_total_reduction.csv')
# Out:
# Formula: C10H10, Column: Auto_5_gp_df
# Formula: C10H10, Column: Auto_3_gp_df
# Formula: C10H10, Column: Auto_2_gp_df
# Formula: C10H10, Column: Auto_1_gp_df
# Formula: C10H10, Column: Zafira_2_gp_df
# Formula: C10H10, Column: Zafira_1_gp_df
# Formula: C10H10, Column: Auto_5_pm_df
# Formula: C10H10, Column: Auto_4_pm_df
# Formula: C10H10, Column: Auto_3_pm_df
# Formula: C10H10, Column: Auto_2_pm_df
# Formula: C10H10, Column: Auto_1_pm_df
# Formula: C10H10O, Column: Auto_5_gp_df
# Formula: C10H10O, Column: Auto_4_gp_df
# Formula: C10H10O, Column: Auto_3_gp_df
# Formula: C10H10O, Column: Auto_1_gp_df
# Formula: C10H10O, Column: Zafira_2_gp_df
# Formula: C10H10O, Column: Zafira_1_gp_df
# Formula: C10H10O, Column: Auto_5_pm_df
# Formula: C10H10O, Column: Auto_4_pm_df
# Formula: C10H10O, Column: Auto_3_pm_df
# Formula: C10H10O, Column: Auto_2_pm_df
# Formula: C10H10O, Column: Auto_1_pm_df
# Formula: C10H10O2, Column: Auto_5_gp_df
# Formula: C10H10O2, Column: Auto_4_gp_df
# Formula: C10H10O2, Column: Auto_3_gp_df
# Formula: C10H10O2, Column: Auto_2_gp_df
# Formula: C10H10O2, Column: Zafira_2_gp_df
# Formula: C10H10O2, Column: Zafira_1_gp_df
# Formula: C10H10O2, Column: Auto_5_pm_df
# Formula: C10H10O2, Column: Auto_4_pm_df
# Formula: C10H10O2, Column: Auto_3_pm_df
# Formula: C10H10O2, Column: Auto_2_pm_df
# Formula: C10H10O2, Column: Auto_1_pm_df
# Formula: C10H10O3, Column: Auto_5_gp_df
# Formula: C10H10O3, Column: Auto_4_gp_df
# Formula: C10H10O3, Column: Auto_3_gp_df
# Formula: C10H10O3, Column: Auto_2_gp_df
# Formula: C10H10O3, Column: Auto_1_gp_df
# Formula: C10H10O3, Column: Zafira_2_gp_df
# Formula: C10H10O3, Column: Auto_5_pm_df
# Formula: C10H10O3, Column: Auto_4_pm_df
# Formula: C10H10O3, Column: Auto_3_pm_df
# Formula: C10H10O3, Column: Auto_2_pm_df
# Formula: C10H10O3, Column: Auto_1_pm_df
# Formula: C10H11N5O2, Column: Auto_5_gp_df
# Formula: C10H11N5O2, Column: Auto_3_gp_df
# Formula: C10H11N5O2, Column: Auto_2_gp_df
# Formula: C10H11N5O2, Column: Auto_1_gp_df
# Formula: C10H11N5O2, Column: Zafira_2_gp_df
# Formula: C10H11N5O2, Column: Zafira_1_gp_df
# Formula: C10H11N5O2, Column: Auto_5_pm_df
# Formula: C10H11N5O2, Column: Auto_4_pm_df
# Formula: C10H11N5O2, Column: Auto_3_pm_df
# Formula: C10H11N5O2, Column: Auto_2_pm_df
# Formula: C10H11N5O2, Column: Auto_1_pm_df
# Formula: C10H12, Column: Auto_5_gp_df
# Formula: C10H12, Column: Auto_4_gp_df
# Formula: C10H12, Column: Auto_3_gp_df
# Formula: C10H12, Column: Auto_2_gp_df
# Formula: C10H12, Column: Auto_1_gp_df
# Formula: C10H12, Column: Zafira_2_gp_df
# Formula: C10H12, Column: Auto_5_pm_df
# Formula: C10H12, Column: Auto_4_pm_df
# Formula: C10H12, Column: Auto_3_pm_df
# Formula: C10H12, Column: Auto_2_pm_df
# Formula: C10H12, Column: Auto_1_pm_df
# Formula: C10H12O, Column: Auto_5_gp_df
# Formula: C10H12O, Column: Auto_4_gp_df
# Formula: C10H12O, Column: Auto_3_gp_df
# Formula: C10H12O, Column: Auto_2_gp_df
# Formula: C10H12O, Column: Auto_1_gp_df
# Formula: C10H12O, Column: Zafira_2_gp_df
# Formula: C10H12O, Column: Auto_5_pm_df
# Formula: C10H12O, Column: Auto_4_pm_df
# Formula: C10H12O, Column: Auto_3_pm_df
# Formula: C10H12O, Column: Auto_2_pm_df
# Formula: C10H12O, Column: Auto_1_pm_df
# Formula: C10H12O2, Column: Auto_5_gp_df
# Formula: C10H12O2, Column: Auto_4_gp_df
# Formula: C10H12O2, Column: Auto_3_gp_df
# Formula: C10H12O2, Column: Auto_2_gp_df
# Formula: C10H12O2, Column: Auto_1_gp_df
# Formula: C10H12O2, Column: Zafira_2_gp_df
# Formula: C10H12O2, Column: Auto_5_pm_df
# Formula: C10H12O2, Column: Auto_4_pm_df
# Formula: C10H12O2, Column: Auto_3_pm_df
# Formula: C10H12O2, Column: Auto_2_pm_df
# Formula: C10H12O2, Column: Auto_1_pm_df
# Formula: C10H12O3, Column: Auto_5_gp_df
# Formula: C10H12O3, Column: Auto_4_gp_df
# Formula: C10H12O3, Column: Auto_3_gp_df
# Formula: C10H12O3, Column: Auto_2_gp_df
# Formula: C10H12O3, Column: Auto_1_gp_df
# Formula: C10H12O3, Column: Zafira_1_gp_df
# Formula: C10H12O3, Column: Auto_5_pm_df
# <ipython-input-7-97d9b4f17e14>:15: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-7-97d9b4f17e14>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-7-97d9b4f17e14>:15: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-7-97d9b4f17e14>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-7-97d9b4f17e14>:15: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-7-97d9b4f17e14>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-7-97d9b4f17e14>:15: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-7-97d9b4f17e14>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-7-97d9b4f17e14>:15: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-7-97d9b4f17e14>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-7-97d9b4f17e14>:15: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-7-97d9b4f17e14>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-7-97d9b4f17e14>:15: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-7-97d9b4f17e14>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-7-97d9b4f17e14>:15: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-7-97d9b4f17e14>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-7-97d9b4f17e14>:15: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# Formula: C10H12O3, Column: Auto_4_pm_df
# Formula: C10H12O3, Column: Auto_3_pm_df
# Formula: C10H12O3, Column: Auto_2_pm_df
# Formula: C10H12O3, Column: Auto_1_pm_df
# Formula: C10H13NO2, Column: Auto_5_gp_df
# Formula: C10H13NO2, Column: Auto_3_gp_df
# Formula: C10H13NO2, Column: Auto_2_gp_df
# Formula: C10H13NO2, Column: Auto_1_gp_df
# Formula: C10H13NO2, Column: Zafira_2_gp_df
# Formula: C10H13NO2, Column: Zafira_1_gp_df
# Formula: C10H13NO2, Column: Auto_5_pm_df
# Formula: C10H13NO2, Column: Auto_4_pm_df
# Formula: C10H13NO2, Column: Auto_3_pm_df
# Formula: C10H13NO2, Column: Auto_2_pm_df
# Formula: C10H13NO2, Column: Auto_1_pm_df
# Formula: C10H14, Column: Auto_5_gp_df
# Formula: C10H14, Column: Auto_4_gp_df
# Formula: C10H14, Column: Auto_3_gp_df
# Formula: C10H14, Column: Auto_1_gp_df
# Formula: C10H14, Column: Zafira_2_gp_df
# Formula: C10H14, Column: Zafira_1_gp_df
# Formula: C10H14, Column: Auto_5_pm_df
# Formula: C10H14, Column: Auto_4_pm_df
# Formula: C10H14, Column: Auto_3_pm_df
# Formula: C10H14, Column: Auto_2_pm_df
# Formula: C10H14, Column: Auto_1_pm_df
# Formula: C10H14N2, Column: Auto_5_gp_df
# Formula: C10H14N2, Column: Auto_4_gp_df
# Formula: C10H14N2, Column: Auto_2_gp_df
# Formula: C10H14N2, Column: Auto_1_gp_df
# Formula: C10H14N2, Column: Zafira_2_gp_df
# Formula: C10H14N2, Column: Zafira_1_gp_df
# Formula: C10H14N2, Column: Auto_5_pm_df
# Formula: C10H14N2, Column: Auto_4_pm_df
# Formula: C10H14N2, Column: Auto_3_pm_df
# Formula: C10H14N2, Column: Auto_2_pm_df
# Formula: C10H14N2, Column: Auto_1_pm_df
# Formula: C10H14O, Column: Auto_5_gp_df
# Formula: C10H14O, Column: Auto_4_gp_df
# Formula: C10H14O, Column: Auto_3_gp_df
# Formula: C10H14O, Column: Auto_2_gp_df
# Formula: C10H14O, Column: Auto_1_gp_df
# Formula: C10H14O, Column: Zafira_1_gp_df
# Formula: C10H14O, Column: Auto_5_pm_df
# Formula: C10H14O, Column: Auto_4_pm_df
# Formula: C10H14O, Column: Auto_3_pm_df
# Formula: C10H14O, Column: Auto_2_pm_df
# Formula: C10H14O, Column: Auto_1_pm_df
# Formula: C10H14O2, Column: Auto_5_gp_df
# Formula: C10H14O2, Column: Auto_4_gp_df
# Formula: C10H14O2, Column: Auto_3_gp_df
# Formula: C10H14O2, Column: Auto_2_gp_df
# Formula: C10H14O2, Column: Auto_1_gp_df
# Formula: C10H14O2, Column: Zafira_2_gp_df
# Formula: C10H14O2, Column: Zafira_1_gp_df
# Formula: C10H14O2, Column: Auto_5_pm_df
# Formula: C10H14O2, Column: Auto_3_pm_df
# Formula: C10H14O2, Column: Auto_2_pm_df
# Formula: C10H14O2, Column: Auto_1_pm_df
# Formula: C10H14O3, Column: Auto_5_gp_df
# Formula: C10H14O3, Column: Auto_4_gp_df
# Formula: C10H14O3, Column: Auto_3_gp_df
# Formula: C10H14O3, Column: Auto_2_gp_df
# Formula: C10H14O3, Column: Auto_1_gp_df
# Formula: C10H14O3, Column: Zafira_1_gp_df
# Formula: C10H14O3, Column: Auto_5_pm_df
# Formula: C10H14O3, Column: Auto_4_pm_df
# Formula: C10H14O3, Column: Auto_3_pm_df
# Formula: C10H14O3, Column: Auto_2_pm_df
# Formula: C10H14O3, Column: Auto_1_pm_df
# Formula: C10H14O4, Column: Auto_5_gp_df
# Formula: C10H14O4, Column: Auto_4_gp_df
# Formula: C10H14O4, Column: Auto_3_gp_df
# Formula: C10H14O4, Column: Auto_2_gp_df
# Formula: C10H14O4, Column: Auto_1_gp_df
# Formula: C10H14O4, Column: Zafira_2_gp_df
# Formula: C10H14O4, Column: Zafira_1_gp_df
# Formula: C10H14O4, Column: Auto_5_pm_df
# Formula: C10H14O4, Column: Auto_4_pm_df
# Formula: C10H14O4, Column: Auto_3_pm_df
# Formula: C10H14O4, Column: Auto_1_pm_df
# Formula: C10H15N, Column: Auto_5_gp_df
# Formula: C10H15N, Column: Auto_4_gp_df
# Formula: C10H15N, Column: Auto_2_gp_df
# Formula: C10H15N, Column: Auto_1_gp_df
# Formula: C10H15N, Column: Zafira_2_gp_df
# Formula: C10H15N, Column: Zafira_1_gp_df
# Formula: C10H15N, Column: Auto_5_pm_df
# Formula: C10H15N, Column: Auto_4_pm_df
# Formula: C10H15N, Column: Auto_3_pm_df
# Formula: C10H15N, Column: Auto_2_pm_df
# Formula: C10H15N, Column: Auto_1_pm_df
# Formula: C10H15NO, Column: Auto_5_gp_df
# <ipython-input-7-97d9b4f17e14>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-7-97d9b4f17e14>:15: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-7-97d9b4f17e14>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-7-97d9b4f17e14>:15: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-7-97d9b4f17e14>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-7-97d9b4f17e14>:15: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-7-97d9b4f17e14>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-7-97d9b4f17e14>:15: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-7-97d9b4f17e14>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-7-97d9b4f17e14>:15: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-7-97d9b4f17e14>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-7-97d9b4f17e14>:15: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-7-97d9b4f17e14>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-7-97d9b4f17e14>:15: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-7-97d9b4f17e14>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-7-97d9b4f17e14>:15: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-7-97d9b4f17e14>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-7-97d9b4f17e14>:15: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# Formula: C10H15NO, Column: Auto_3_gp_df
# Formula: C10H15NO, Column: Auto_2_gp_df
# Formula: C10H15NO, Column: Auto_1_gp_df
# Formula: C10H15NO, Column: Zafira_2_gp_df
# Formula: C10H15NO, Column: Zafira_1_gp_df
# Formula: C10H15NO, Column: Auto_5_pm_df
# Formula: C10H15NO, Column: Auto_4_pm_df
# Formula: C10H15NO, Column: Auto_3_pm_df
# Formula: C10H15NO, Column: Auto_2_pm_df
# Formula: C10H15NO, Column: Auto_1_pm_df
# Formula: C10H15NS, Column: Auto_5_gp_df
# Formula: C10H15NS, Column: Auto_4_gp_df
# Formula: C10H15NS, Column: Auto_3_gp_df
# Formula: C10H15NS, Column: Auto_1_gp_df
# Formula: C10H15NS, Column: Zafira_2_gp_df
# Formula: C10H15NS, Column: Zafira_1_gp_df
# Formula: C10H15NS, Column: Auto_5_pm_df
# Formula: C10H15NS, Column: Auto_4_pm_df
# Formula: C10H15NS, Column: Auto_3_pm_df
# Formula: C10H15NS, Column: Auto_2_pm_df
# Formula: C10H15NS, Column: Auto_1_pm_df
# Formula: C10H16, Column: Auto_5_gp_df
# Formula: C10H16, Column: Auto_4_gp_df
# Formula: C10H16, Column: Auto_3_gp_df
# Formula: C10H16, Column: Auto_2_gp_df
# Formula: C10H16, Column: Auto_1_gp_df
# Formula: C10H16, Column: Zafira_1_gp_df
# Formula: C10H16, Column: Auto_5_pm_df
# Formula: C10H16, Column: Auto_4_pm_df
# Formula: C10H16, Column: Auto_3_pm_df
# Formula: C10H16, Column: Auto_2_pm_df
# Formula: C10H16, Column: Auto_1_pm_df
# Formula: C10H16N2O2, Column: Auto_5_gp_df
# Formula: C10H16N2O2, Column: Auto_4_gp_df
# Formula: C10H16N2O2, Column: Auto_3_gp_df
# Formula: C10H16N2O2, Column: Auto_1_gp_df
# Formula: C10H16N2O2, Column: Zafira_2_gp_df
# Formula: C10H16N2O2, Column: Zafira_1_gp_df
# Formula: C10H16N2O2, Column: Auto_5_pm_df
# Formula: C10H16N2O2, Column: Auto_4_pm_df
# Formula: C10H16N2O2, Column: Auto_3_pm_df
# Formula: C10H16N2O2, Column: Auto_2_pm_df
# Formula: C10H16N2O2, Column: Auto_1_pm_df
# Formula: C10H16O, Column: Auto_5_gp_df
# Formula: C10H16O, Column: Auto_3_gp_df
# Formula: C10H16O, Column: Auto_2_gp_df
# Formula: C10H16O, Column: Auto_1_gp_df
# Formula: C10H16O, Column: Zafira_2_gp_df
# Formula: C10H16O, Column: Zafira_1_gp_df
# Formula: C10H16O, Column: Auto_5_pm_df
# Formula: C10H16O, Column: Auto_4_pm_df
# Formula: C10H16O, Column: Auto_3_pm_df
# Formula: C10H16O, Column: Auto_2_pm_df
# Formula: C10H16O, Column: Auto_1_pm_df
# Formula: C10H16O2, Column: Auto_5_gp_df
# Formula: C10H16O2, Column: Auto_4_gp_df
# Formula: C10H16O2, Column: Auto_3_gp_df
# Formula: C10H16O2, Column: Auto_2_gp_df
# Formula: C10H16O2, Column: Auto_1_gp_df
# Formula: C10H16O2, Column: Zafira_2_gp_df
# Formula: C10H16O2, Column: Zafira_1_gp_df
# Formula: C10H16O2, Column: Auto_5_pm_df
# Formula: C10H16O2, Column: Auto_3_pm_df
# Formula: C10H16O2, Column: Auto_2_pm_df
# Formula: C10H16O2, Column: Auto_1_pm_df
# Formula: C10H16O4, Column: Auto_5_gp_df
# Formula: C10H16O4, Column: Auto_4_gp_df
# Formula: C10H16O4, Column: Auto_3_gp_df
# Formula: C10H16O4, Column: Auto_1_gp_df
# Formula: C10H16O4, Column: Zafira_2_gp_df
# Formula: C10H16O4, Column: Zafira_1_gp_df
# Formula: C10H16O4, Column: Auto_5_pm_df
# Formula: C10H16O4, Column: Auto_4_pm_df
# Formula: C10H16O4, Column: Auto_3_pm_df
# Formula: C10H16O4, Column: Auto_2_pm_df
# Formula: C10H16O4, Column: Auto_1_pm_df
# Formula: C10H17F3O2, Column: Auto_5_gp_df
# Formula: C10H17F3O2, Column: Auto_4_gp_df
# Formula: C10H17F3O2, Column: Auto_2_gp_df
# Formula: C10H17F3O2, Column: Auto_1_gp_df
# Formula: C10H17F3O2, Column: Zafira_2_gp_df
# Formula: C10H17F3O2, Column: Zafira_1_gp_df
# Formula: C10H17F3O2, Column: Auto_5_pm_df
# Formula: C10H17F3O2, Column: Auto_4_pm_df
# Formula: C10H17F3O2, Column: Auto_3_pm_df
# Formula: C10H17F3O2, Column: Auto_2_pm_df
# Formula: C10H17F3O2, Column: Auto_1_pm_df
# Formula: C10H17NO2, Column: Auto_5_gp_df
# Formula: C10H17NO2, Column: Auto_4_gp_df
# Formula: C10H17NO2, Column: Auto_3_gp_df
# Formula: C10H17NO2, Column: Auto_2_gp_df
# Formula: C10H17NO2, Column: Auto_1_gp_df
# Formula: C10H17NO2, Column: Zafira_1_gp_df
# Formula: C10H17NO2, Column: Auto_5_pm_df
# Formula: C10H17NO2, Column: Auto_4_pm_df
# Formula: C10H17NO2, Column: Auto_3_pm_df
# Formula: C10H17NO2, Column: Auto_2_pm_df
# Formula: C10H17NO2, Column: Auto_1_pm_df
# Formula: C10H17NO3, Column: Auto_5_gp_df
# <ipython-input-7-97d9b4f17e14>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-7-97d9b4f17e14>:15: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-7-97d9b4f17e14>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-7-97d9b4f17e14>:15: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-7-97d9b4f17e14>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-7-97d9b4f17e14>:15: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-7-97d9b4f17e14>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-7-97d9b4f17e14>:15: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-7-97d9b4f17e14>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-7-97d9b4f17e14>:15: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-7-97d9b4f17e14>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-7-97d9b4f17e14>:15: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-7-97d9b4f17e14>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-7-97d9b4f17e14>:15: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-7-97d9b4f17e14>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-7-97d9b4f17e14>:15: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-7-97d9b4f17e14>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-7-97d9b4f17e14>:15: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-7-97d9b4f17e14>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# Formula: C10H17NO3, Column: Auto_4_gp_df
# Formula: C10H17NO3, Column: Auto_3_gp_df
# Formula: C10H17NO3, Column: Auto_2_gp_df
# Formula: C10H17NO3, Column: Zafira_2_gp_df
# Formula: C10H17NO3, Column: Zafira_1_gp_df
# Formula: C10H17NO3, Column: Auto_5_pm_df
# Formula: C10H17NO3, Column: Auto_4_pm_df
# Formula: C10H17NO3, Column: Auto_3_pm_df
# Formula: C10H17NO3, Column: Auto_2_pm_df
# Formula: C10H17NO3, Column: Auto_1_pm_df
# Formula: C10H18, Column: Auto_5_gp_df
# Formula: C10H18, Column: Auto_4_gp_df
# Formula: C10H18, Column: Auto_3_gp_df
# Formula: C10H18, Column: Auto_1_gp_df
# Formula: C10H18, Column: Zafira_2_gp_df
# Formula: C10H18, Column: Zafira_1_gp_df
# Formula: C10H18, Column: Auto_5_pm_df
# Formula: C10H18, Column: Auto_4_pm_df
# Formula: C10H18, Column: Auto_3_pm_df
# Formula: C10H18, Column: Auto_2_pm_df
# Formula: C10H18, Column: Auto_1_pm_df
# Formula: C10H18O, Column: Auto_5_gp_df
# Formula: C10H18O, Column: Auto_4_gp_df
# Formula: C10H18O, Column: Auto_3_gp_df
# Formula: C10H18O, Column: Auto_2_gp_df
# Formula: C10H18O, Column: Auto_1_gp_df
# Formula: C10H18O, Column: Zafira_2_gp_df
# Formula: C10H18O, Column: Auto_5_pm_df
# Formula: C10H18O, Column: Auto_4_pm_df
# Formula: C10H18O, Column: Auto_3_pm_df
# Formula: C10H18O, Column: Auto_2_pm_df
# Formula: C10H18O, Column: Auto_1_pm_df
# Formula: C10H18O2, Column: Auto_5_gp_df
# Formula: C10H18O2, Column: Auto_4_gp_df
# Formula: C10H18O2, Column: Auto_3_gp_df
# Formula: C10H18O2, Column: Auto_2_gp_df
# Formula: C10H18O2, Column: Auto_1_gp_df
# Formula: C10H18O2, Column: Zafira_1_gp_df
# Formula: C10H18O2, Column: Auto_5_pm_df
# Formula: C10H18O2, Column: Auto_4_pm_df
# Formula: C10H18O2, Column: Auto_3_pm_df
# Formula: C10H18O2, Column: Auto_2_pm_df
# Formula: C10H18O2, Column: Auto_1_pm_df
# Formula: C10H18O3, Column: Auto_5_gp_df
# Formula: C10H18O3, Column: Auto_4_gp_df
# Formula: C10H18O3, Column: Auto_3_gp_df
# Formula: C10H18O3, Column: Auto_2_gp_df
# Formula: C10H18O3, Column: Auto_1_gp_df
# Formula: C10H18O3, Column: Zafira_2_gp_df
# Formula: C10H18O3, Column: Zafira_1_gp_df
# Formula: C10H18O3, Column: Auto_4_pm_df
# Formula: C10H18O3, Column: Auto_3_pm_df
# Formula: C10H18O3, Column: Auto_2_pm_df
# Formula: C10H18O3, Column: Auto_1_pm_df
# Formula: C10H18O4, Column: Auto_5_gp_df
# Formula: C10H18O4, Column: Auto_4_gp_df
# Formula: C10H18O4, Column: Auto_3_gp_df
# Formula: C10H18O4, Column: Auto_2_gp_df
# Formula: C10H18O4, Column: Auto_1_gp_df
# Formula: C10H18O4, Column: Zafira_2_gp_df
# Formula: C10H18O4, Column: Auto_5_pm_df
# Formula: C10H18O4, Column: Auto_4_pm_df
# Formula: C10H18O4, Column: Auto_3_pm_df
# Formula: C10H18O4, Column: Auto_2_pm_df
# Formula: C10H18O4, Column: Auto_1_pm_df
# Formula: C10H18O5, Column: Auto_5_gp_df
# Formula: C10H18O5, Column: Auto_4_gp_df
# Formula: C10H18O5, Column: Auto_3_gp_df
# Formula: C10H18O5, Column: Auto_2_gp_df
# Formula: C10H18O5, Column: Auto_1_gp_df
# Formula: C10H18O5, Column: Zafira_1_gp_df
# Formula: C10H18O5, Column: Auto_5_pm_df
# Formula: C10H18O5, Column: Auto_4_pm_df
# Formula: C10H18O5, Column: Auto_3_pm_df
# Formula: C10H18O5, Column: Auto_2_pm_df
# Formula: C10H18O5, Column: Auto_1_pm_df
# Formula: C10H20, Column: Auto_5_gp_df
# Formula: C10H20, Column: Auto_4_gp_df
# Formula: C10H20, Column: Auto_2_gp_df
# Formula: C10H20, Column: Auto_1_gp_df
# Formula: C10H20, Column: Zafira_2_gp_df
# Formula: C10H20, Column: Zafira_1_gp_df
# Formula: C10H20, Column: Auto_5_pm_df
# Formula: C10H20, Column: Auto_4_pm_df
# Formula: C10H20, Column: Auto_3_pm_df
# Formula: C10H20, Column: Auto_2_pm_df
# Formula: C10H20, Column: Auto_1_pm_df
# Formula: C10H20O, Column: Auto_5_gp_df
# Formula: C10H20O, Column: Auto_4_gp_df
# Formula: C10H20O, Column: Auto_3_gp_df
# Formula: C10H20O, Column: Auto_2_gp_df
# Formula: C10H20O, Column: Auto_1_gp_df
# Formula: C10H20O, Column: Zafira_2_gp_df
# Formula: C10H20O, Column: Zafira_1_gp_df
# Formula: C10H20O, Column: Auto_5_pm_df
# Formula: C10H20O, Column: Auto_3_pm_df
# Formula: C10H20O, Column: Auto_2_pm_df
# Formula: C10H20O, Column: Auto_1_pm_df
# Formula: C10H20O2, Column: Auto_5_gp_df
# Formula: C10H20O2, Column: Auto_4_gp_df
# Formula: C10H20O2, Column: Auto_3_gp_df
# <ipython-input-7-97d9b4f17e14>:15: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-7-97d9b4f17e14>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-7-97d9b4f17e14>:15: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-7-97d9b4f17e14>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-7-97d9b4f17e14>:15: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-7-97d9b4f17e14>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-7-97d9b4f17e14>:15: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-7-97d9b4f17e14>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-7-97d9b4f17e14>:15: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-7-97d9b4f17e14>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-7-97d9b4f17e14>:15: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-7-97d9b4f17e14>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-7-97d9b4f17e14>:15: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-7-97d9b4f17e14>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-7-97d9b4f17e14>:15: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-7-97d9b4f17e14>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-7-97d9b4f17e14>:15: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-7-97d9b4f17e14>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# Formula: C10H20O2, Column: Auto_2_gp_df
# Formula: C10H20O2, Column: Auto_1_gp_df
# Formula: C10H20O2, Column: Zafira_2_gp_df
# Formula: C10H20O2, Column: Zafira_1_gp_df
# Formula: C10H20O2, Column: Auto_5_pm_df
# Formula: C10H20O2, Column: Auto_3_pm_df
# Formula: C10H20O2, Column: Auto_2_pm_df
# Formula: C10H20O2, Column: Auto_1_pm_df
# Formula: C10H20O3, Column: Auto_5_gp_df
# Formula: C10H20O3, Column: Auto_4_gp_df
# Formula: C10H20O3, Column: Auto_3_gp_df
# Formula: C10H20O3, Column: Auto_2_gp_df
# Formula: C10H20O3, Column: Auto_1_gp_df
# Formula: C10H20O3, Column: Zafira_2_gp_df
# Formula: C10H20O3, Column: Zafira_1_gp_df
# Formula: C10H20O3, Column: Auto_4_pm_df
# Formula: C10H20O3, Column: Auto_3_pm_df
# Formula: C10H20O3, Column: Auto_2_pm_df
# Formula: C10H20O3, Column: Auto_1_pm_df
# Formula: C10H20O4, Column: Auto_5_gp_df
# Formula: C10H20O4, Column: Auto_4_gp_df
# Formula: C10H20O4, Column: Auto_3_gp_df
# Formula: C10H20O4, Column: Auto_2_gp_df
# Formula: C10H20O4, Column: Auto_1_gp_df
# Formula: C10H20O4, Column: Zafira_2_gp_df
# Formula: C10H20O4, Column: Zafira_1_gp_df
# Formula: C10H20O4, Column: Auto_5_pm_df
# Formula: C10H20O4, Column: Auto_4_pm_df
# Formula: C10H20O4, Column: Auto_2_pm_df
# Formula: C10H20O4, Column: Auto_1_pm_df
# Formula: C10H22, Column: Auto_5_gp_df
# Formula: C10H22, Column: Auto_3_gp_df
# Formula: C10H22, Column: Auto_2_gp_df
# Formula: C10H22, Column: Auto_1_gp_df
# Formula: C10H22, Column: Zafira_2_gp_df
# Formula: C10H22, Column: Zafira_1_gp_df
# Formula: C10H22, Column: Auto_5_pm_df
# Formula: C10H22, Column: Auto_4_pm_df
# Formula: C10H22, Column: Auto_3_pm_df
# Formula: C10H22, Column: Auto_2_pm_df
# Formula: C10H22, Column: Auto_1_pm_df
# Formula: C10H22O, Column: Auto_5_gp_df
# Formula: C10H22O, Column: Auto_4_gp_df
# Formula: C10H22O, Column: Auto_3_gp_df
# Formula: C10H22O, Column: Auto_1_gp_df
# Formula: C10H22O, Column: Zafira_2_gp_df
# Formula: C10H22O, Column: Zafira_1_gp_df
# Formula: C10H22O, Column: Auto_5_pm_df
# Formula: C10H22O, Column: Auto_4_pm_df
# Formula: C10H22O, Column: Auto_3_pm_df
# Formula: C10H22O, Column: Auto_2_pm_df
# Formula: C10H22O, Column: Auto_1_pm_df
# Formula: C10H22O3, Column: Auto_5_gp_df
# Formula: C10H22O3, Column: Auto_4_gp_df
# Formula: C10H22O3, Column: Auto_3_gp_df
# Formula: C10H22O3, Column: Auto_2_gp_df
# Formula: C10H22O3, Column: Auto_1_gp_df
# Formula: C10H22O3, Column: Zafira_2_gp_df
# Formula: C10H22O3, Column: Auto_5_pm_df
# Formula: C10H22O3, Column: Auto_4_pm_df
# Formula: C10H22O3, Column: Auto_3_pm_df
# Formula: C10H22O3, Column: Auto_2_pm_df
# Formula: C10H22O3, Column: Auto_1_pm_df
# Formula: C10H8O, Column: Auto_5_gp_df
# Formula: C10H8O, Column: Auto_4_gp_df
# Formula: C10H8O, Column: Auto_3_gp_df
# Formula: C10H8O, Column: Auto_2_gp_df
# Formula: C10H8O, Column: Auto_1_gp_df
# Formula: C10H8O, Column: Zafira_1_gp_df
# Formula: C10H8O, Column: Auto_5_pm_df
# Formula: C10H8O, Column: Auto_4_pm_df
# Formula: C10H8O, Column: Auto_3_pm_df
# Formula: C10H8O, Column: Auto_2_pm_df
# Formula: C10H8O, Column: Auto_1_pm_df
# Formula: C10H9N, Column: Auto_5_gp_df
# Formula: C10H9N, Column: Auto_4_gp_df
# Formula: C10H9N, Column: Auto_3_gp_df
# Formula: C10H9N, Column: Auto_2_gp_df
# Formula: C10H9N, Column: Auto_1_gp_df
# Formula: C10H9N, Column: Zafira_2_gp_df
# Formula: C10H9N, Column: Auto_5_pm_df
# Formula: C10H9N, Column: Auto_4_pm_df
# Formula: C10H9N, Column: Auto_3_pm_df
# Formula: C10H9N, Column: Auto_2_pm_df
# Formula: C10H9N, Column: Auto_1_pm_df
# Formula: C10H9NO2, Column: Auto_5_gp_df
# Formula: C10H9NO2, Column: Auto_4_gp_df
# Formula: C10H9NO2, Column: Auto_3_gp_df
# Formula: C10H9NO2, Column: Auto_2_gp_df
# Formula: C10H9NO2, Column: Auto_1_gp_df
# Formula: C10H9NO2, Column: Zafira_1_gp_df
# Formula: C10H9NO2, Column: Auto_5_pm_df
# Formula: C10H9NO2, Column: Auto_4_pm_df
# Formula: C10H9NO2, Column: Auto_3_pm_df
# Formula: C10H9NO2, Column: Auto_2_pm_df
# Formula: C10H9NO2, Column: Auto_1_pm_df
# Formula: C10H9NO2S, Column: Auto_5_gp_df
# Formula: C10H9NO2S, Column: Auto_4_gp_df
# Formula: C10H9NO2S, Column: Auto_3_gp_df
# Formula: C10H9NO2S, Column: Auto_2_gp_df
# Formula: C10H9NO2S, Column: Zafira_2_gp_df
# Formula: C10H9NO2S, Column: Zafira_1_gp_df
# <ipython-input-7-97d9b4f17e14>:15: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-7-97d9b4f17e14>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-7-97d9b4f17e14>:15: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-7-97d9b4f17e14>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-7-97d9b4f17e14>:15: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-7-97d9b4f17e14>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-7-97d9b4f17e14>:15: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-7-97d9b4f17e14>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-7-97d9b4f17e14>:15: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-7-97d9b4f17e14>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-7-97d9b4f17e14>:15: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-7-97d9b4f17e14>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-7-97d9b4f17e14>:15: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-7-97d9b4f17e14>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-7-97d9b4f17e14>:15: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-7-97d9b4f17e14>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-7-97d9b4f17e14>:15: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-7-97d9b4f17e14>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-7-97d9b4f17e14>:15: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# Formula: C10H9NO2S, Column: Auto_5_pm_df
# Formula: C10H9NO2S, Column: Auto_4_pm_df
# Formula: C10H9NO2S, Column: Auto_3_pm_df
# Formula: C10H9NO2S, Column: Auto_2_pm_df
# Formula: C10H9NO2S, Column: Auto_1_pm_df
# Formula: C11H10O, Column: Auto_5_gp_df
# Formula: C11H10O, Column: Auto_4_gp_df
# Formula: C11H10O, Column: Auto_3_gp_df
# Formula: C11H10O, Column: Auto_2_gp_df
# Formula: C11H10O, Column: Auto_1_gp_df
# Formula: C11H10O, Column: Zafira_2_gp_df
# Formula: C11H10O, Column: Auto_5_pm_df
# Formula: C11H10O, Column: Auto_4_pm_df
# Formula: C11H10O, Column: Auto_3_pm_df
# Formula: C11H10O, Column: Auto_2_pm_df
# Formula: C11H10O, Column: Auto_1_pm_df
# Formula: C11H10O3, Column: Auto_5_gp_df
# Formula: C11H10O3, Column: Auto_4_gp_df
# Formula: C11H10O3, Column: Auto_2_gp_df
# Formula: C11H10O3, Column: Auto_1_gp_df
# Formula: C11H10O3, Column: Zafira_2_gp_df
# Formula: C11H10O3, Column: Zafira_1_gp_df
# Formula: C11H10O3, Column: Auto_5_pm_df
# Formula: C11H10O3, Column: Auto_4_pm_df
# Formula: C11H10O3, Column: Auto_3_pm_df
# Formula: C11H10O3, Column: Auto_2_pm_df
# Formula: C11H10O3, Column: Auto_1_pm_df
# Formula: C11H11N, Column: Auto_5_gp_df
# Formula: C11H11N, Column: Auto_4_gp_df
# Formula: C11H11N, Column: Auto_3_gp_df
# Formula: C11H11N, Column: Auto_2_gp_df
# Formula: C11H11N, Column: Auto_1_gp_df
# Formula: C11H11N, Column: Zafira_2_gp_df
# Formula: C11H11N, Column: Zafira_1_gp_df
# Formula: C11H11N, Column: Auto_4_pm_df
# Formula: C11H11N, Column: Auto_3_pm_df
# Formula: C11H11N, Column: Auto_2_pm_df
# Formula: C11H11N, Column: Auto_1_pm_df
# Formula: C11H12F3NO, Column: Auto_5_gp_df
# Formula: C11H12F3NO, Column: Auto_4_gp_df
# Formula: C11H12F3NO, Column: Auto_3_gp_df
# Formula: C11H12F3NO, Column: Auto_1_gp_df
# Formula: C11H12F3NO, Column: Zafira_2_gp_df
# Formula: C11H12F3NO, Column: Zafira_1_gp_df
# Formula: C11H12F3NO, Column: Auto_5_pm_df
# Formula: C11H12F3NO, Column: Auto_4_pm_df
# Formula: C11H12F3NO, Column: Auto_3_pm_df
# Formula: C11H12F3NO, Column: Auto_2_pm_df
# Formula: C11H12F3NO, Column: Auto_1_pm_df
# Formula: C11H12O, Column: Auto_5_gp_df
# Formula: C11H12O, Column: Auto_4_gp_df
# Formula: C11H12O, Column: Auto_3_gp_df
# Formula: C11H12O, Column: Auto_2_gp_df
# Formula: C11H12O, Column: Auto_1_gp_df
# Formula: C11H12O, Column: Zafira_2_gp_df
# Formula: C11H12O, Column: Zafira_1_gp_df
# Formula: C11H12O, Column: Auto_5_pm_df
# Formula: C11H12O, Column: Auto_4_pm_df
# Formula: C11H12O, Column: Auto_3_pm_df
# Formula: C11H12O, Column: Auto_2_pm_df
# Formula: C11H12O3, Column: Auto_5_gp_df
# Formula: C11H12O3, Column: Auto_3_gp_df
# Formula: C11H12O3, Column: Auto_2_gp_df
# Formula: C11H12O3, Column: Auto_1_gp_df
# Formula: C11H12O3, Column: Zafira_2_gp_df
# Formula: C11H12O3, Column: Zafira_1_gp_df
# Formula: C11H12O3, Column: Auto_5_pm_df
# Formula: C11H12O3, Column: Auto_4_pm_df
# Formula: C11H12O3, Column: Auto_3_pm_df
# Formula: C11H12O3, Column: Auto_2_pm_df
# Formula: C11H12O3, Column: Auto_1_pm_df
# Formula: C11H13F3O, Column: Auto_5_gp_df
# Formula: C11H13F3O, Column: Auto_4_gp_df
# Formula: C11H13F3O, Column: Auto_3_gp_df
# Formula: C11H13F3O, Column: Auto_2_gp_df
# Formula: C11H13F3O, Column: Auto_1_gp_df
# Formula: C11H13F3O, Column: Zafira_1_gp_df
# Formula: C11H13F3O, Column: Auto_5_pm_df
# Formula: C11H13F3O, Column: Auto_4_pm_df
# Formula: C11H13F3O, Column: Auto_3_pm_df
# Formula: C11H13F3O, Column: Auto_2_pm_df
# Formula: C11H13F3O, Column: Auto_1_pm_df
# Formula: C11H13NO3, Column: Auto_5_gp_df
# ...
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-7-97d9b4f17e14>:15: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-7-97d9b4f17e14>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-7-97d9b4f17e14>:15: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-7-97d9b4f17e14>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# Formula: C9H18O, Column: Auto_5_gp_df
# Formula: C9H18O, Column: Auto_4_gp_df
# Formula: C9H18O, Column: Auto_3_gp_df
# Formula: C9H18O, Column: Auto_2_gp_df
# Formula: C9H18O, Column: Auto_1_gp_df
# Formula: C9H18O, Column: Zafira_2_gp_df
# Formula: C9H18O, Column: Zafira_1_gp_df
# Formula: C9H18O, Column: Auto_4_pm_df
# Formula: C9H18O, Column: Auto_3_pm_df
# Formula: C9H18O, Column: Auto_2_pm_df
# Formula: C9H18O, Column: Auto_1_pm_df
# Formula: C9H18O2, Column: Auto_5_gp_df
# Formula: C9H18O2, Column: Auto_4_gp_df
# Formula: C9H18O2, Column: Auto_3_gp_df
# Formula: C9H18O2, Column: Auto_2_gp_df
# Formula: C9H18O2, Column: Auto_1_gp_df
# Formula: C9H18O2, Column: Zafira_2_gp_df
# Formula: C9H18O2, Column: Zafira_1_gp_df
# Formula: C9H18O2, Column: Auto_5_pm_df
# Formula: C9H18O2, Column: Auto_4_pm_df
# Formula: C9H18O2, Column: Auto_3_pm_df
# Formula: C9H18O2, Column: Auto_2_pm_df
# Formula: C9H18O3, Column: Auto_4_gp_df
# Formula: C9H18O3, Column: Auto_3_gp_df
# Formula: C9H18O3, Column: Auto_2_gp_df
# Formula: C9H18O3, Column: Auto_1_gp_df
# Formula: C9H18O3, Column: Zafira_2_gp_df
# Formula: C9H18O3, Column: Zafira_1_gp_df
# Formula: C9H18O3, Column: Auto_5_pm_df
# Formula: C9H18O3, Column: Auto_4_pm_df
# Formula: C9H18O3, Column: Auto_3_pm_df
# Formula: C9H18O3, Column: Auto_2_pm_df
# Formula: C9H18O3, Column: Auto_1_pm_df
# Formula: C9H19N, Column: Auto_5_gp_df
# Formula: C9H19N, Column: Auto_4_gp_df
# Formula: C9H19N, Column: Auto_2_gp_df
# Formula: C9H19N, Column: Auto_1_gp_df
# Formula: C9H19N, Column: Zafira_2_gp_df
# Formula: C9H19N, Column: Zafira_1_gp_df
# Formula: C9H19N, Column: Auto_5_pm_df
# Formula: C9H19N, Column: Auto_4_pm_df
# Formula: C9H19N, Column: Auto_3_pm_df
# Formula: C9H19N, Column: Auto_2_pm_df
# Formula: C9H19N, Column: Auto_1_pm_df
# Formula: C9H20, Column: Auto_4_gp_df
# Formula: C9H20, Column: Auto_3_gp_df
# Formula: C9H20, Column: Auto_2_gp_df
# Formula: C9H20, Column: Auto_1_gp_df
# Formula: C9H20, Column: Zafira_2_gp_df
# Formula: C9H20, Column: Zafira_1_gp_df
# Formula: C9H20, Column: Auto_5_pm_df
# Formula: C9H20, Column: Auto_4_pm_df
# Formula: C9H20, Column: Auto_3_pm_df
# Formula: C9H20, Column: Auto_2_pm_df
# Formula: C9H20, Column: Auto_1_pm_df
# Formula: C9H20O4, Column: Auto_5_gp_df
# Formula: C9H20O4, Column: Auto_4_gp_df
# Formula: C9H20O4, Column: Auto_3_gp_df
# Formula: C9H20O4, Column: Auto_2_gp_df
# Formula: C9H20O4, Column: Auto_1_gp_df
# Formula: C9H20O4, Column: Zafira_2_gp_df
# Formula: C9H20O4, Column: Zafira_1_gp_df
# Formula: C9H20O4, Column: Auto_3_pm_df
# Formula: C9H20O4, Column: Auto_2_pm_df
# Formula: C9H21O4P, Column: Auto_4_gp_df
# Formula: C9H21O4P, Column: Auto_3_gp_df
# Formula: C9H21O4P, Column: Auto_2_gp_df
# Formula: C9H21O4P, Column: Auto_1_gp_df
# Formula: C9H21O4P, Column: Zafira_2_gp_df
# Formula: C9H21O4P, Column: Zafira_1_gp_df
# Formula: C9H21O4P, Column: Auto_5_pm_df
# Formula: C9H21O4P, Column: Auto_4_pm_df
# Formula: C9H21O4P, Column: Auto_3_pm_df
# Formula: C9H21O4P, Column: Auto_2_pm_df
# Formula: C9H21O4P, Column: Auto_1_pm_df
# Formula: C9H22NO2PS, Column: Auto_5_gp_df
# Formula: C9H22NO2PS, Column: Auto_4_gp_df
# Formula: C9H22NO2PS, Column: Auto_3_gp_df
# Formula: C9H22NO2PS, Column: Auto_2_gp_df
# Formula: C9H22NO2PS, Column: Auto_1_gp_df
# Formula: C9H22NO2PS, Column: Zafira_2_gp_df
# Formula: C9H22NO2PS, Column: Zafira_1_gp_df
# Formula: C9H22NO2PS, Column: Auto_5_pm_df
# Formula: C9H22NO2PS, Column: Auto_4_pm_df
# Formula: C9H22NO2PS, Column: Auto_3_pm_df
# Formula: C9H22NO2PS, Column: Auto_2_pm_df
# Formula: C9H7N, Column: Auto_5_gp_df
# Formula: C9H7N, Column: Auto_4_gp_df
# Formula: C9H7N, Column: Auto_3_gp_df
# Formula: C9H7N, Column: Auto_2_gp_df
# Formula: C9H7N, Column: Auto_1_gp_df
# Formula: C9H7N, Column: Zafira_2_gp_df
# Formula: C9H7N, Column: Zafira_1_gp_df
# Formula: C9H7N, Column: Auto_5_pm_df
# Formula: C9H7N, Column: Auto_4_pm_df
# Formula: C9H7N, Column: Auto_3_pm_df
# Formula: C9H7N, Column: Auto_1_pm_df
# Formula: C9H7NO2, Column: Auto_5_gp_df
# Formula: C9H7NO2, Column: Auto_4_gp_df
# Formula: C9H7NO2, Column: Auto_3_gp_df
# Formula: C9H7NO2, Column: Auto_2_gp_df
# Formula: C9H7NO2, Column: Auto_1_gp_df
# Formula: C9H7NO2, Column: Zafira_2_gp_df
# Formula: C9H7NO2, Column: Auto_5_pm_df
# Formula: C9H7NO2, Column: Auto_4_pm_df
# Formula: C9H7NO2, Column: Auto_3_pm_df
# Formula: C9H7NO2, Column: Auto_2_pm_df
# Formula: C9H7NO2, Column: Auto_1_pm_df
# Formula: C9H8, Column: Auto_4_gp_df
# Formula: C9H8, Column: Auto_3_gp_df
# Formula: C9H8, Column: Auto_2_gp_df
# Formula: C9H8, Column: Auto_1_gp_df
# Formula: C9H8, Column: Zafira_2_gp_df
# Formula: C9H8, Column: Zafira_1_gp_df
# Formula: C9H8, Column: Auto_5_pm_df
# Formula: C9H8, Column: Auto_4_pm_df
# Formula: C9H8, Column: Auto_3_pm_df
# Formula: C9H8, Column: Auto_2_pm_df
# Formula: C9H8, Column: Auto_1_pm_df
# Formula: C9H8N2O2, Column: Auto_5_gp_df
# Formula: C9H8N2O2, Column: Auto_4_gp_df
# Formula: C9H8N2O2, Column: Auto_3_gp_df
# Formula: C9H8N2O2, Column: Auto_2_gp_df
# Formula: C9H8N2O2, Column: Auto_1_gp_df
# Formula: C9H8N2O2, Column: Zafira_2_gp_df
# Formula: C9H8N2O2, Column: Auto_5_pm_df
# Formula: C9H8N2O2, Column: Auto_4_pm_df
# Formula: C9H8N2O2, Column: Auto_3_pm_df
# Formula: C9H8N2O2, Column: Auto_2_pm_df
# <ipython-input-7-97d9b4f17e14>:15: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-7-97d9b4f17e14>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-7-97d9b4f17e14>:15: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-7-97d9b4f17e14>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-7-97d9b4f17e14>:15: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-7-97d9b4f17e14>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-7-97d9b4f17e14>:15: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-7-97d9b4f17e14>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-7-97d9b4f17e14>:15: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-7-97d9b4f17e14>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-7-97d9b4f17e14>:15: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-7-97d9b4f17e14>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# Formula: C9H8N2O2, Column: Auto_1_pm_df
# Formula: C9H8O3, Column: Auto_5_gp_df
# Formula: C9H8O3, Column: Auto_4_gp_df
# Formula: C9H8O3, Column: Auto_3_gp_df
# Formula: C9H8O3, Column: Auto_2_gp_df
# Formula: C9H8O3, Column: Auto_1_gp_df
# Formula: C9H8O3, Column: Zafira_2_gp_df
# Formula: C9H8O3, Column: Zafira_1_gp_df
# Formula: C9H8O3, Column: Auto_5_pm_df
# Formula: C9H8O3, Column: Auto_3_pm_df
# Formula: C9H8O3, Column: Auto_2_pm_df
# Formula: C9H8O3, Column: Auto_1_pm_df
#                                         Formula (mol ion)  Auto_5_gp_df  \
# 2-Methylindene                                     C10H10      0.000000
# 7-Methylindan-1-one                               C10H10O      0.000000
# 1(3H)-Isobenzofuranone, 3,3-dimethyl-            C10H10O2      0.000000
# 2-Propenoic acid, 3-(2-methoxyphenyl)-           C10H10O3      0.215324
# 1-Piperonyl-3,5-diamino-1,2,4-triazole         C10H11N5O2      0.010663
# ...                                                   ...           ...
# Benzeneacetonitrile, .alpha.-methylene-             C9H7N      0.040952
# 8-Quinolinol, 1-oxide                             C9H7NO2      0.008033
# Benzene, 1-ethynyl-4-methyl-                         C9H8      0.048361
# 2-Phenyl-5-methoxy-oxadiazol-1,3,4               C9H8N2O2      0.000000
# 2-Acetylbenzoic acid                               C9H8O3      0.000000
#
#                                          Auto_4_gp_df  Auto_3_gp_df  \
# 2-Methylindene                               0.001020      0.000000
# 7-Methylindan-1-one                          0.000000      0.000000
# 1(3H)-Isobenzofuranone, 3,3-dimethyl-        0.000000      0.000000
# 2-Propenoic acid, 3-(2-methoxyphenyl)-       0.000000      0.000000
# 1-Piperonyl-3,5-diamino-1,2,4-triazole       0.002702      0.000000
# ...                                               ...           ...
# Benzeneacetonitrile, .alpha.-methylene-      0.028706      0.038224
# 8-Quinolinol, 1-oxide                        0.000000      0.000000
# Benzene, 1-ethynyl-4-methyl-                 0.000000      0.035708
# 2-Phenyl-5-methoxy-oxadiazol-1,3,4           0.000000      0.000000
# 2-Acetylbenzoic acid                         0.000000      0.000000
#
#                                          Auto_2_gp_df  Auto_1_gp_df  \
# 2-Methylindene                               0.056242      0.000000
# 7-Methylindan-1-one                          0.011399      0.000000
# 1(3H)-Isobenzofuranone, 3,3-dimethyl-        0.000000      0.425445
# 2-Propenoic acid, 3-(2-methoxyphenyl)-       0.000000      0.272548
# 1-Piperonyl-3,5-diamino-1,2,4-triazole       0.000000      0.000000
# ...                                               ...           ...
# Benzeneacetonitrile, .alpha.-methylene-      0.049298      0.000000
# 8-Quinolinol, 1-oxide                        0.000000      0.000000
# Benzene, 1-ethynyl-4-methyl-                 0.000000      0.411682
# 2-Phenyl-5-methoxy-oxadiazol-1,3,4           0.000000      0.000000
# 2-Acetylbenzoic acid                         0.000000      0.000000
#
#                                          Zafira_2_gp_df  Zafira_1_gp_df  \
# 2-Methylindene                                 0.000000        0.000000
# 7-Methylindan-1-one                            0.061735        0.000000
# 1(3H)-Isobenzofuranone, 3,3-dimethyl-          0.000000        0.000000
# 2-Propenoic acid, 3-(2-methoxyphenyl)-         0.000000        0.001662
# 1-Piperonyl-3,5-diamino-1,2,4-triazole         0.000000        0.000000
# ...                                                 ...             ...
# Benzeneacetonitrile, .alpha.-methylene-        0.044932        0.000000
# 8-Quinolinol, 1-oxide                          0.000000        0.000451
# Benzene, 1-ethynyl-4-methyl-                   0.000000        0.005954
# 2-Phenyl-5-methoxy-oxadiazol-1,3,4             0.000000        0.001310
# 2-Acetylbenzoic acid                           0.501247        0.000000
#
#                                          Auto_5_pm_df  Auto_4_pm_df  \
# 2-Methylindene                                    0.0      0.000000
# 7-Methylindan-1-one                               0.0      0.000000
# 1(3H)-Isobenzofuranone, 3,3-dimethyl-             0.0      0.000000
# 2-Propenoic acid, 3-(2-methoxyphenyl)-            0.0      0.000000
# 1-Piperonyl-3,5-diamino-1,2,4-triazole            0.0      0.000000
# ...                                               ...           ...
# Benzeneacetonitrile, .alpha.-methylene-           0.0      0.000000
# 8-Quinolinol, 1-oxide                             0.0      0.000000
# Benzene, 1-ethynyl-4-methyl-                      0.0      0.000000
# 2-Phenyl-5-methoxy-oxadiazol-1,3,4                0.0      0.000000
# 2-Acetylbenzoic acid                              0.0      0.001341
#
#                                          Auto_3_pm_df  Auto_2_pm_df  \
# 2-Methylindene                                    0.0      0.000000
# 7-Methylindan-1-one                               0.0      0.000000
# 1(3H)-Isobenzofuranone, 3,3-dimethyl-             0.0      0.000000
# 2-Propenoic acid, 3-(2-methoxyphenyl)-            0.0      0.000000
# 1-Piperonyl-3,5-diamino-1,2,4-triazole            0.0      0.000000
# ...                                               ...           ...
# Benzeneacetonitrile, .alpha.-methylene-           0.0      0.004041
# 8-Quinolinol, 1-oxide                             0.0      0.000000
# Benzene, 1-ethynyl-4-methyl-                      0.0      0.000000
# 2-Phenyl-5-methoxy-oxadiazol-1,3,4                0.0      0.000000
# 2-Acetylbenzoic acid                              0.0      0.000000
#
#                                          Auto_1_pm_df
# 2-Methylindene                                    0.0
# 7-Methylindan-1-one                               0.0
# 1(3H)-Isobenzofuranone, 3,3-dimethyl-             0.0
# 2-Propenoic acid, 3-(2-methoxyphenyl)-            0.0
# 1-Piperonyl-3,5-diamino-1,2,4-triazole            0.0
# ...                                               ...
# Benzeneacetonitrile, .alpha.-methylene-           0.0
# 8-Quinolinol, 1-oxide                             0.0
# Benzene, 1-ethynyl-4-methyl-                      0.0
# 2-Phenyl-5-methoxy-oxadiazol-1,3,4                0.0
# 2-Acetylbenzoic acid                              0.0
#
# [570 rows x 13 columns]

# %%
compound_sample_df_no_duplicates = compound_sample_df.drop_duplicates(subset='Formula (mol ion)', keep=False)

# Concatenate the modified compound_sample_df with the combined_duplicated_rows DataFrame
final_result = pd.concat([compound_sample_df_no_duplicates, combined_duplicated_rows], ignore_index=False)

print(final_result.shape)

# Save the resulting dataframe to a CSV file
final_result.to_csv('/content/drive/My Drive/unknown_screening_data/Hitlist_non_duplicates_final.csv')
# Out:
# (2164, 13)

# %%
detection_frequency = final_result.iloc[:, 1:].gt(0).sum(axis=1) / (final_result.shape[1] - 1)

# Insert the new column after the 'Formula (mol ion)' column
final_result.insert(1, 'Detection Frequency', detection_frequency)

print(final_result.head())

# Save the result to a new CSV file
final_result.to_csv('/content/drive/My Drive/unknown_screening_data/Result_With_Detection_Frequency.csv')
# Out:
#                                                    Formula (mol ion)  \
# 2H-1,2-Oxaborin, 2,3,3-triethyl-3,6-dihydro-                C10H19BO
# Propanenitrile, 3,3',3''-nitrilotris-                        C9H12N4
# Propanoic acid, 2,3,3,3-tetrafluoro-2-methoxy-,...      C10H6ClF4NO5
# 2-(2-methoxyethoxy)propanoic acid, O-acetyl-                 C8H14O5
# 4-Chloro-N-[2-(1-piperidinyl)ethyl]benzamide             C14H19ClN2O
#
#                                                     Detection Frequency  \
# 2H-1,2-Oxaborin, 2,3,3-triethyl-3,6-dihydro-                   0.083333
# Propanenitrile, 3,3',3''-nitrilotris-                          0.083333
# Propanoic acid, 2,3,3,3-tetrafluoro-2-methoxy-,...             0.166667
# 2-(2-methoxyethoxy)propanoic acid, O-acetyl-                   0.083333
# 4-Chloro-N-[2-(1-piperidinyl)ethyl]benzamide                   0.083333
#
#                                                     Auto_5_gp_df  \
# 2H-1,2-Oxaborin, 2,3,3-triethyl-3,6-dihydro-             0.00000
# Propanenitrile, 3,3',3''-nitrilotris-                    0.00000
# Propanoic acid, 2,3,3,3-tetrafluoro-2-methoxy-,...       0.00000
# 2-(2-methoxyethoxy)propanoic acid, O-acetyl-             0.00000
# 4-Chloro-N-[2-(1-piperidinyl)ethyl]benzamide             0.00378
#
#                                                     Auto_4_gp_df  \
# 2H-1,2-Oxaborin, 2,3,3-triethyl-3,6-dihydro-                 0.0
# Propanenitrile, 3,3',3''-nitrilotris-                        0.0
# Propanoic acid, 2,3,3,3-tetrafluoro-2-methoxy-,...           0.0
# 2-(2-methoxyethoxy)propanoic acid, O-acetyl-                 0.0
# 4-Chloro-N-[2-(1-piperidinyl)ethyl]benzamide                 0.0
#
#                                                     Auto_3_gp_df  \
# 2H-1,2-Oxaborin, 2,3,3-triethyl-3,6-dihydro-            0.000000
# Propanenitrile, 3,3',3''-nitrilotris-                   0.012677
# Propanoic acid, 2,3,3,3-tetrafluoro-2-methoxy-,...      0.000000
# 2-(2-methoxyethoxy)propanoic acid, O-acetyl-            0.000000
# 4-Chloro-N-[2-(1-piperidinyl)ethyl]benzamide            0.000000
#
#                                                     Auto_2_gp_df  \
# 2H-1,2-Oxaborin, 2,3,3-triethyl-3,6-dihydro-                 0.0
# Propanenitrile, 3,3',3''-nitrilotris-                        0.0
# Propanoic acid, 2,3,3,3-tetrafluoro-2-methoxy-,...           0.0
# 2-(2-methoxyethoxy)propanoic acid, O-acetyl-                 0.0
# 4-Chloro-N-[2-(1-piperidinyl)ethyl]benzamide                 0.0
#
#                                                     Auto_1_gp_df  \
# 2H-1,2-Oxaborin, 2,3,3-triethyl-3,6-dihydro-            0.942981
# Propanenitrile, 3,3',3''-nitrilotris-                   0.000000
# Propanoic acid, 2,3,3,3-tetrafluoro-2-methoxy-,...      0.040515
# 2-(2-methoxyethoxy)propanoic acid, O-acetyl-            0.000000
# 4-Chloro-N-[2-(1-piperidinyl)ethyl]benzamide            0.000000
#
#                                                     Zafira_2_gp_df  \
# 2H-1,2-Oxaborin, 2,3,3-triethyl-3,6-dihydro-                   0.0
# Propanenitrile, 3,3',3''-nitrilotris-                          0.0
# Propanoic acid, 2,3,3,3-tetrafluoro-2-methoxy-,...             0.0
# 2-(2-methoxyethoxy)propanoic acid, O-acetyl-                   0.0
# 4-Chloro-N-[2-(1-piperidinyl)ethyl]benzamide                   0.0
#
#                                                     Zafira_1_gp_df  \
# 2H-1,2-Oxaborin, 2,3,3-triethyl-3,6-dihydro-                   0.0
# Propanenitrile, 3,3',3''-nitrilotris-                          0.0
# Propanoic acid, 2,3,3,3-tetrafluoro-2-methoxy-,...             0.0
# 2-(2-methoxyethoxy)propanoic acid, O-acetyl-                   0.0
# 4-Chloro-N-[2-(1-piperidinyl)ethyl]benzamide                   0.0
#
#                                                     Auto_5_pm_df  \
# 2H-1,2-Oxaborin, 2,3,3-triethyl-3,6-dihydro-                 0.0
# Propanenitrile, 3,3',3''-nitrilotris-                        0.0
# Propanoic acid, 2,3,3,3-tetrafluoro-2-methoxy-,...           0.0
# 2-(2-methoxyethoxy)propanoic acid, O-acetyl-                 0.0
# 4-Chloro-N-[2-(1-piperidinyl)ethyl]benzamide                 0.0
#
#                                                     Auto_4_pm_df  \
# 2H-1,2-Oxaborin, 2,3,3-triethyl-3,6-dihydro-                 0.0
# Propanenitrile, 3,3',3''-nitrilotris-                        0.0
# Propanoic acid, 2,3,3,3-tetrafluoro-2-methoxy-,...           0.0
# 2-(2-methoxyethoxy)propanoic acid, O-acetyl-                 0.0
# 4-Chloro-N-[2-(1-piperidinyl)ethyl]benzamide                 0.0
#
#                                                     Auto_3_pm_df  \
# 2H-1,2-Oxaborin, 2,3,3-triethyl-3,6-dihydro-                 0.0
# Propanenitrile, 3,3',3''-nitrilotris-                        0.0
# Propanoic acid, 2,3,3,3-tetrafluoro-2-methoxy-,...           0.0
# 2-(2-methoxyethoxy)propanoic acid, O-acetyl-                 0.0
# 4-Chloro-N-[2-(1-piperidinyl)ethyl]benzamide                 0.0
#
#                                                     Auto_2_pm_df  Auto_1_pm_df
# 2H-1,2-Oxaborin, 2,3,3-triethyl-3,6-dihydro-            0.000000           0.0
# Propanenitrile, 3,3',3''-nitrilotris-                   0.000000           0.0
# Propanoic acid, 2,3,3,3-tetrafluoro-2-methoxy-,...      0.004283           0.0
# 2-(2-methoxyethoxy)propanoic acid, O-acetyl-            0.055911           0.0
# 4-Chloro-N-[2-(1-piperidinyl)ethyl]benzamide            0.000000           0.0

# %%
detection_frequency_threshold = 0.2  # Adjust this threshold as needed

# Filter rows based on the detection frequency threshold
filtered_result = final_result[final_result['Detection Frequency'] >= detection_frequency_threshold]

print(filtered_result.shape)
# Save the filtered result to a new CSV file
filtered_result.to_csv('/content/drive/My Drive/unknown_screening_data/Filtered_Result_With_Detection_Frequency_02.csv')
# Out:
# (198, 14)
