# %% [markdown]
# <a href="https://colab.research.google.com/github/TillVollmer5/mass_spectroscopy/blob/main/Hitlist_unknown_screening.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from google.colab import drive
import pandas as pd

drive.mount('/content/drive', force_remount = True)
# Out:
# Mounted at /content/drive

# %%
Auto_5_gp_df = pd.read_csv('/content/drive/My Drive/unknown_screening_data/Auto5_PUF_120k_blank_filtered.csv')
Auto_4_gp_df = pd.read_csv('/content/drive/My Drive/unknown_screening_data/Auto4_PUF_120k_blank_filtered.csv')
Auto_3_gp_df = pd.read_csv('/content/drive/My Drive/unknown_screening_data/Auto3_PUF_120k_blank_filtered.csv')
Auto_2_gp_df = pd.read_csv('/content/drive/My Drive/unknown_screening_data/Auto2_PUF_120k_blank_filtered.csv')
Auto_1_gp_df = pd.read_csv('/content/drive/My Drive/unknown_screening_data/Auto1_PUF_120k_blank_filtered.csv')
Zafira_2_gp_df = pd.read_csv('/content/drive/My Drive/unknown_screening_data/Zafira2_PUF_120k_blank_filtered.csv')
Zafira_1_gp_df = pd.read_csv('/content/drive/My Drive/unknown_screening_data/Zafira1_PUF_120k_blank_filtered.csv')

Auto_5_pm_df = pd.read_csv('/content/drive/My Drive/unknown_screening_data/Auto5_PF_120k_blank_filtered.csv')
Auto_4_pm_df = pd.read_csv('/content/drive/My Drive/unknown_screening_data/Auto4_PF_120k_blank_filtered.csv')
Auto_3_pm_df = pd.read_csv('/content/drive/My Drive/unknown_screening_data/Auto3_PF_120k_blank_filtered.csv')
Auto_2_pm_df = pd.read_csv('/content/drive/My Drive/unknown_screening_data/Auto2_PF_120k_blank_filtered.csv')
Auto_1_pm_df = pd.read_csv('/content/drive/My Drive/unknown_screening_data/Auto1_PF_120k_blank_filtered.csv')
Zafira_2_pm_df = pd.read_csv('/content/drive/My Drive/unknown_screening_data/Zafira2_PF_120k_blank_filtered.csv')
Zafira_1_pm_df = pd.read_csv('/content/drive/My Drive/unknown_screening_data/Zafira1_PF_120k_blank_filtered.csv')

U181_60k_df = pd.read_csv('/content/drive/My Drive/unknown_screening_data/U181_60k_blank_filtered.csv')
U181_120k_df = pd.read_csv('/content/drive/My Drive/unknown_screening_data/U181_120k_blank_filtered.csv')
U166_df = pd.read_csv('/content/drive/My Drive/unknown_screening_data/U166_blank_filtered.csv')
U164_df = pd.read_csv('/content/drive/My Drive/unknown_screening_data/U164_blank_filtered.csv')

# %%
dfs = [('Auto_5_gp_df', Auto_5_gp_df), ('Auto_4_gp_df', Auto_4_gp_df),
       ('Auto_3_gp_df', Auto_3_gp_df), ('Auto_2_gp_df', Auto_2_gp_df),
       ('Auto_1_gp_df', Auto_1_gp_df), ('Auto_5_pm_df', Auto_5_pm_df),
       ('Auto_4_pm_df', Auto_4_pm_df), ('Auto_3_pm_df', Auto_3_pm_df),
       ('Auto_2_pm_df', Auto_2_pm_df), ('Auto_1_pm_df', Auto_1_pm_df)]
       #('Zafira_2_gp_df', Zafira_2_gp_df), ('Zafira_1_gp_df', Zafira_1_gp_df)
       #,('Zafira_2_pm_df', Zafira_2_pm_df), ('Zafira_1_pm_df', Zafira_1_pm_df)
       #,('U181_60k_df', U181_60k_df), ('U181_120k_df', U181_120k_df),
       #('U166_df', U166_df), ('U164_df', U164_df)]

# %%
complete_dfs = [('Auto_5_gp_df', Auto_5_gp_df), ('Auto_4_gp_df', Auto_4_gp_df),
       ('Auto_3_gp_df', Auto_3_gp_df), ('Auto_2_gp_df', Auto_2_gp_df),
       ('Auto_1_gp_df', Auto_1_gp_df), ('Auto_5_pm_df', Auto_5_pm_df),
       ('Auto_4_pm_df', Auto_4_pm_df), ('Auto_3_pm_df', Auto_3_pm_df),
       ('Auto_2_pm_df', Auto_2_pm_df), ('Auto_1_pm_df', Auto_1_pm_df),
       ('Zafira_2_gp_df', Zafira_2_gp_df), ('Zafira_1_gp_df', Zafira_1_gp_df),
       ('Zafira_2_pm_df', Zafira_2_pm_df), ('Zafira_1_pm_df', Zafira_1_pm_df),
       ('U181_60k_df', U181_60k_df), ('U181_120k_df', U181_120k_df),
       ('U166_df', U166_df), ('U164_df', U164_df)]

# %%
all_compounds = []
for _, df in dfs:
    all_compounds.extend(df['Component Name'].unique())

# Remove duplicates and create an empty dataframe with all compounds and samples
all_compounds = list(set(all_compounds))
compound_sample_df = pd.DataFrame(index=all_compounds)

# Add a new column for molecule formula
compound_sample_df['Formula (mol ion)'] = ''

# Fill the dataframe with area ratios and molecule formula
for df_name, df in dfs:
    for compound in all_compounds:
        # Check if the compound is in the current dataframe
        if compound in df['Component Name'].values:
            # Get the area ratio for the compound in the current sample
            area_ratio = df.loc[df['Component Name'] == compound, 'Area Ratio'].values[0]
            # Get the molecule formula for the compound in the current sample
            formula = df.loc[df['Component Name'] == compound, 'Formula (mol ion)'].values[0]

            # Set the values in the compound_sample_df
            compound_sample_df.loc[compound, df_name] = area_ratio
            compound_sample_df.loc[compound, 'Formula (mol ion)'] = formula
        else:
            # If compound is not in the current sample, set the value to 0 for area ratio
            compound_sample_df.loc[compound, df_name] = 0

# Display the resulting dataframe
print(compound_sample_df)
# Out:
#                                                    Formula (mol ion)  \
# Heptadecane                                                   C17H36
# Cyclohexanecarboxylic acid, 1-cyclohpentylethyl...          C14H24O2
# 2-Butanone, 4-(dimethylamino)-3-methyl-                      C7H15NO
# Carbonic acid, prop-1-en-2-yl tetradecyl ester              C18H34O3
# Benzenepropanoic acid, 3,5-bis(1,1-dimethylethy...          C18H28O3
# ...                                                              ...
# 2,5-Cyclohexadiene-1,4-dione, 2,6-bis(1,1-dimet...          C14H20O2
# 2-(6-Chloro-3-nitro-4-phenyl-quinolin-2-ylsulfa...     C25H17ClN2O5S
# Succinic acid, di(4-fluorophenethyl) ester                C20H20F2O4
# Isonicotinamide, N-(2,5-dioxo-1-phenethyl-4-tri...      C18H15F3N4O3
# 5'-Methoxyauraptene                                         C20H24O4
#
#                                                     Auto_5_gp_df  \
# Heptadecane                                             0.000000
# Cyclohexanecarboxylic acid, 1-cyclohpentylethyl...      0.000000
# 2-Butanone, 4-(dimethylamino)-3-methyl-                 0.000000
# Carbonic acid, prop-1-en-2-yl tetradecyl ester          0.000000
# Benzenepropanoic acid, 3,5-bis(1,1-dimethylethy...      0.000000
# ...                                                          ...
# 2,5-Cyclohexadiene-1,4-dione, 2,6-bis(1,1-dimet...      0.000000
# 2-(6-Chloro-3-nitro-4-phenyl-quinolin-2-ylsulfa...      0.058683
# Succinic acid, di(4-fluorophenethyl) ester              0.000000
# Isonicotinamide, N-(2,5-dioxo-1-phenethyl-4-tri...      0.000000
# 5'-Methoxyauraptene                                     0.000000
#
#                                                     Auto_4_gp_df  \
# Heptadecane                                                  0.0
# Cyclohexanecarboxylic acid, 1-cyclohpentylethyl...           0.0
# 2-Butanone, 4-(dimethylamino)-3-methyl-                      0.0
# Carbonic acid, prop-1-en-2-yl tetradecyl ester               0.0
# Benzenepropanoic acid, 3,5-bis(1,1-dimethylethy...           0.0
# ...                                                          ...
# 2,5-Cyclohexadiene-1,4-dione, 2,6-bis(1,1-dimet...           0.0
# 2-(6-Chloro-3-nitro-4-phenyl-quinolin-2-ylsulfa...           0.0
# Succinic acid, di(4-fluorophenethyl) ester                   0.0
# Isonicotinamide, N-(2,5-dioxo-1-phenethyl-4-tri...           0.0
# 5'-Methoxyauraptene                                          0.0
#
#                                                     Auto_3_gp_df  \
# Heptadecane                                             0.203217
# Cyclohexanecarboxylic acid, 1-cyclohpentylethyl...      0.000000
# 2-Butanone, 4-(dimethylamino)-3-methyl-                 0.054954
# Carbonic acid, prop-1-en-2-yl tetradecyl ester          0.000000
# Benzenepropanoic acid, 3,5-bis(1,1-dimethylethy...      0.000000
# ...                                                          ...
# 2,5-Cyclohexadiene-1,4-dione, 2,6-bis(1,1-dimet...      0.269945
# 2-(6-Chloro-3-nitro-4-phenyl-quinolin-2-ylsulfa...      0.000000
# Succinic acid, di(4-fluorophenethyl) ester              0.000000
# Isonicotinamide, N-(2,5-dioxo-1-phenethyl-4-tri...      0.000000
# 5'-Methoxyauraptene                                     0.000000
#
#                                                     Auto_2_gp_df  \
# Heptadecane                                             0.000000
# Cyclohexanecarboxylic acid, 1-cyclohpentylethyl...      0.026988
# 2-Butanone, 4-(dimethylamino)-3-methyl-                 0.000000
# Carbonic acid, prop-1-en-2-yl tetradecyl ester          1.099867
# Benzenepropanoic acid, 3,5-bis(1,1-dimethylethy...      0.000000
# ...                                                          ...
# 2,5-Cyclohexadiene-1,4-dione, 2,6-bis(1,1-dimet...      0.000000
# 2-(6-Chloro-3-nitro-4-phenyl-quinolin-2-ylsulfa...      0.000000
# Succinic acid, di(4-fluorophenethyl) ester              0.000000
# Isonicotinamide, N-(2,5-dioxo-1-phenethyl-4-tri...      0.000000
# 5'-Methoxyauraptene                                     0.000000
#
#                                                     Auto_1_gp_df  \
# Heptadecane                                              0.00000
# Cyclohexanecarboxylic acid, 1-cyclohpentylethyl...       0.00000
# 2-Butanone, 4-(dimethylamino)-3-methyl-                  0.00000
# Carbonic acid, prop-1-en-2-yl tetradecyl ester           0.00000
# Benzenepropanoic acid, 3,5-bis(1,1-dimethylethy...       0.00000
# ...                                                          ...
# 2,5-Cyclohexadiene-1,4-dione, 2,6-bis(1,1-dimet...       0.00000
# 2-(6-Chloro-3-nitro-4-phenyl-quinolin-2-ylsulfa...       0.00000
# Succinic acid, di(4-fluorophenethyl) ester               0.00577
# Isonicotinamide, N-(2,5-dioxo-1-phenethyl-4-tri...       0.00000
# 5'-Methoxyauraptene                                      0.00000
#
#                                                     Auto_5_pm_df  \
# Heptadecane                                             0.000000
# Cyclohexanecarboxylic acid, 1-cyclohpentylethyl...      0.000000
# 2-Butanone, 4-(dimethylamino)-3-methyl-                 0.000000
# Carbonic acid, prop-1-en-2-yl tetradecyl ester          0.000000
# Benzenepropanoic acid, 3,5-bis(1,1-dimethylethy...      0.023838
# ...                                                          ...
# 2,5-Cyclohexadiene-1,4-dione, 2,6-bis(1,1-dimet...      0.000000
# 2-(6-Chloro-3-nitro-4-phenyl-quinolin-2-ylsulfa...      0.000000
# Succinic acid, di(4-fluorophenethyl) ester              0.000000
# Isonicotinamide, N-(2,5-dioxo-1-phenethyl-4-tri...      0.000000
# 5'-Methoxyauraptene                                     0.000000
#
#                                                     Auto_4_pm_df  \
# Heptadecane                                                  0.0
# Cyclohexanecarboxylic acid, 1-cyclohpentylethyl...           0.0
# 2-Butanone, 4-(dimethylamino)-3-methyl-                      0.0
# Carbonic acid, prop-1-en-2-yl tetradecyl ester               0.0
# Benzenepropanoic acid, 3,5-bis(1,1-dimethylethy...           0.0
# ...                                                          ...
# 2,5-Cyclohexadiene-1,4-dione, 2,6-bis(1,1-dimet...           0.0
# 2-(6-Chloro-3-nitro-4-phenyl-quinolin-2-ylsulfa...           0.0
# Succinic acid, di(4-fluorophenethyl) ester                   0.0
# Isonicotinamide, N-(2,5-dioxo-1-phenethyl-4-tri...           0.0
# 5'-Methoxyauraptene                                          0.0
#
#                                                     Auto_3_pm_df  \
# Heptadecane                                             0.000000
# Cyclohexanecarboxylic acid, 1-cyclohpentylethyl...      0.000000
# 2-Butanone, 4-(dimethylamino)-3-methyl-                 0.000000
# Carbonic acid, prop-1-en-2-yl tetradecyl ester          0.000000
# Benzenepropanoic acid, 3,5-bis(1,1-dimethylethy...      0.000000
# ...                                                          ...
# 2,5-Cyclohexadiene-1,4-dione, 2,6-bis(1,1-dimet...      0.000000
# 2-(6-Chloro-3-nitro-4-phenyl-quinolin-2-ylsulfa...      0.000000
# Succinic acid, di(4-fluorophenethyl) ester              0.000000
# Isonicotinamide, N-(2,5-dioxo-1-phenethyl-4-tri...      0.000000
# 5'-Methoxyauraptene                                     0.053628
#
#                                                     Auto_2_pm_df  Auto_1_pm_df
# Heptadecane                                                  0.0      0.000000
# Cyclohexanecarboxylic acid, 1-cyclohpentylethyl...           0.0      0.000000
# 2-Butanone, 4-(dimethylamino)-3-methyl-                      0.0      0.000000
# Carbonic acid, prop-1-en-2-yl tetradecyl ester               0.0      0.000000
# Benzenepropanoic acid, 3,5-bis(1,1-dimethylethy...           0.0      0.000000
# ...                                                          ...           ...
# 2,5-Cyclohexadiene-1,4-dione, 2,6-bis(1,1-dimet...           0.0      0.000000
# 2-(6-Chloro-3-nitro-4-phenyl-quinolin-2-ylsulfa...           0.0      0.000000
# Succinic acid, di(4-fluorophenethyl) ester                   0.0      0.000000
# Isonicotinamide, N-(2,5-dioxo-1-phenethyl-4-tri...           0.0      0.006168
# 5'-Methoxyauraptene                                          0.0      0.000000
#
# [2593 rows x 11 columns]

# %%
all_compounds = []
for _, df in complete_dfs:
    all_compounds.extend(df['Component Name'].unique())

# Remove duplicates and create an empty dataframe with all compounds and samples
all_compounds = list(set(all_compounds))
complete_compound_sample_df = pd.DataFrame(index=all_compounds)

# Add a new column for molecule formula
complete_compound_sample_df['Formula (mol ion)'] = ''

# Fill the dataframe with area ratios and molecule formula
for df_name, df in complete_dfs:
    for compound in all_compounds:
        # Check if the compound is in the current dataframe
        if compound in df['Component Name'].values:
            # Get the area ratio for the compound in the current sample
            area_ratio = df.loc[df['Component Name'] == compound, 'Area Ratio'].values[0]
            # Get the molecule formula for the compound in the current sample
            formula = df.loc[df['Component Name'] == compound, 'Formula (mol ion)'].values[0]

            # Set the values in the compound_sample_df
            complete_compound_sample_df.loc[compound, df_name] = area_ratio
            complete_compound_sample_df.loc[compound, 'Formula (mol ion)'] = formula
        else:
            # If compound is not in the current sample, set the value to 0 for area ratio
            complete_compound_sample_df.loc[compound, df_name] = 0

# Display the resulting dataframe
print(complete_compound_sample_df)
# Out:
#                                                    Formula (mol ion)  \
# Cyclopentanol, 1-ethyl-                                       C7H14O
# Dicyclopropyl carbinol                                        C7H12O
# Sebacic acid, di(4-trifluoromethoxybenzyl) ester          C26H28F6O6
# Cyclohexanecarboxylic acid, 1-cyclohpentylethyl...          C14H24O2
# N,N',N''-Tris(3-methylthioureidocarbamyl)phosph...     C9H21N12O4PS3
# ...                                                              ...
# Aziridine, 2-hexyl-                                           C8H17N
# 3-(2-Methylnaphtho[1,2-d]oxazolium)-1-propanesu...        C15H15NO4S
# Succinic acid, di(4-fluorophenethyl) ester                C20H20F2O4
# Isonicotinamide, N-(2,5-dioxo-1-phenethyl-4-tri...      C18H15F3N4O3
# Carbamodithioic acid, dibutyl-, propyl ester               C12H25NS2
#
#                                                     Auto_5_gp_df  \
# Cyclopentanol, 1-ethyl-                                      0.0
# Dicyclopropyl carbinol                                       0.0
# Sebacic acid, di(4-trifluoromethoxybenzyl) ester             0.0
# Cyclohexanecarboxylic acid, 1-cyclohpentylethyl...           0.0
# N,N',N''-Tris(3-methylthioureidocarbamyl)phosph...           0.0
# ...                                                          ...
# Aziridine, 2-hexyl-                                          0.0
# 3-(2-Methylnaphtho[1,2-d]oxazolium)-1-propanesu...           0.0
# Succinic acid, di(4-fluorophenethyl) ester                   0.0
# Isonicotinamide, N-(2,5-dioxo-1-phenethyl-4-tri...           0.0
# Carbamodithioic acid, dibutyl-, propyl ester                 0.0
#
#                                                     Auto_4_gp_df  \
# Cyclopentanol, 1-ethyl-                                      0.0
# Dicyclopropyl carbinol                                       0.0
# Sebacic acid, di(4-trifluoromethoxybenzyl) ester             0.0
# Cyclohexanecarboxylic acid, 1-cyclohpentylethyl...           0.0
# N,N',N''-Tris(3-methylthioureidocarbamyl)phosph...           0.0
# ...                                                          ...
# Aziridine, 2-hexyl-                                          0.0
# 3-(2-Methylnaphtho[1,2-d]oxazolium)-1-propanesu...           0.0
# Succinic acid, di(4-fluorophenethyl) ester                   0.0
# Isonicotinamide, N-(2,5-dioxo-1-phenethyl-4-tri...           0.0
# Carbamodithioic acid, dibutyl-, propyl ester                 0.0
#
#                                                     Auto_3_gp_df  \
# Cyclopentanol, 1-ethyl-                                      0.0
# Dicyclopropyl carbinol                                       0.0
# Sebacic acid, di(4-trifluoromethoxybenzyl) ester             0.0
# Cyclohexanecarboxylic acid, 1-cyclohpentylethyl...           0.0
# N,N',N''-Tris(3-methylthioureidocarbamyl)phosph...           0.0
# ...                                                          ...
# Aziridine, 2-hexyl-                                          0.0
# 3-(2-Methylnaphtho[1,2-d]oxazolium)-1-propanesu...           0.0
# Succinic acid, di(4-fluorophenethyl) ester                   0.0
# Isonicotinamide, N-(2,5-dioxo-1-phenethyl-4-tri...           0.0
# Carbamodithioic acid, dibutyl-, propyl ester                 0.0
#
#                                                     Auto_2_gp_df  \
# Cyclopentanol, 1-ethyl-                                 0.000000
# Dicyclopropyl carbinol                                  0.000000
# Sebacic acid, di(4-trifluoromethoxybenzyl) ester        0.000000
# Cyclohexanecarboxylic acid, 1-cyclohpentylethyl...      0.026988
# N,N',N''-Tris(3-methylthioureidocarbamyl)phosph...      0.000000
# ...                                                          ...
# Aziridine, 2-hexyl-                                     0.000000
# 3-(2-Methylnaphtho[1,2-d]oxazolium)-1-propanesu...      0.000000
# Succinic acid, di(4-fluorophenethyl) ester              0.000000
# Isonicotinamide, N-(2,5-dioxo-1-phenethyl-4-tri...      0.000000
# Carbamodithioic acid, dibutyl-, propyl ester            0.000000
#
#                                                     Auto_1_gp_df  \
# Cyclopentanol, 1-ethyl-                                  0.00000
# Dicyclopropyl carbinol                                   0.00000
# Sebacic acid, di(4-trifluoromethoxybenzyl) ester         0.00000
# Cyclohexanecarboxylic acid, 1-cyclohpentylethyl...       0.00000
# N,N',N''-Tris(3-methylthioureidocarbamyl)phosph...       0.00000
# ...                                                          ...
# Aziridine, 2-hexyl-                                      0.00000
# 3-(2-Methylnaphtho[1,2-d]oxazolium)-1-propanesu...       0.00000
# Succinic acid, di(4-fluorophenethyl) ester               0.00577
# Isonicotinamide, N-(2,5-dioxo-1-phenethyl-4-tri...       0.00000
# Carbamodithioic acid, dibutyl-, propyl ester             0.00000
#
#                                                     Auto_5_pm_df  \
# Cyclopentanol, 1-ethyl-                                      0.0
# Dicyclopropyl carbinol                                       0.0
# Sebacic acid, di(4-trifluoromethoxybenzyl) ester             0.0
# Cyclohexanecarboxylic acid, 1-cyclohpentylethyl...           0.0
# N,N',N''-Tris(3-methylthioureidocarbamyl)phosph...           0.0
# ...                                                          ...
# Aziridine, 2-hexyl-                                          0.0
# 3-(2-Methylnaphtho[1,2-d]oxazolium)-1-propanesu...           0.0
# Succinic acid, di(4-fluorophenethyl) ester                   0.0
# Isonicotinamide, N-(2,5-dioxo-1-phenethyl-4-tri...           0.0
# Carbamodithioic acid, dibutyl-, propyl ester                 0.0
#
#                                                     Auto_4_pm_df  \
# Cyclopentanol, 1-ethyl-                                 0.000000
# Dicyclopropyl carbinol                                  0.000000
# Sebacic acid, di(4-trifluoromethoxybenzyl) ester        0.000000
# Cyclohexanecarboxylic acid, 1-cyclohpentylethyl...      0.000000
# N,N',N''-Tris(3-methylthioureidocarbamyl)phosph...      0.000000
# ...                                                          ...
# Aziridine, 2-hexyl-                                     0.002457
# 3-(2-Methylnaphtho[1,2-d]oxazolium)-1-propanesu...      0.000000
# Succinic acid, di(4-fluorophenethyl) ester              0.000000
# Isonicotinamide, N-(2,5-dioxo-1-phenethyl-4-tri...      0.000000
# Carbamodithioic acid, dibutyl-, propyl ester            0.000000
#
#                                                     Auto_3_pm_df  \
# Cyclopentanol, 1-ethyl-                                      0.0
# Dicyclopropyl carbinol                                       0.0
# Sebacic acid, di(4-trifluoromethoxybenzyl) ester             0.0
# Cyclohexanecarboxylic acid, 1-cyclohpentylethyl...           0.0
# N,N',N''-Tris(3-methylthioureidocarbamyl)phosph...           0.0
# ...                                                          ...
# Aziridine, 2-hexyl-                                          0.0
# 3-(2-Methylnaphtho[1,2-d]oxazolium)-1-propanesu...           0.0
# Succinic acid, di(4-fluorophenethyl) ester                   0.0
# Isonicotinamide, N-(2,5-dioxo-1-phenethyl-4-tri...           0.0
# Carbamodithioic acid, dibutyl-, propyl ester                 0.0
#
#                                                     Auto_2_pm_df  \
# Cyclopentanol, 1-ethyl-                                      0.0
# Dicyclopropyl carbinol                                       0.0
# Sebacic acid, di(4-trifluoromethoxybenzyl) ester             0.0
# Cyclohexanecarboxylic acid, 1-cyclohpentylethyl...           0.0
# N,N',N''-Tris(3-methylthioureidocarbamyl)phosph...           0.0
# ...                                                          ...
# Aziridine, 2-hexyl-                                          0.0
# 3-(2-Methylnaphtho[1,2-d]oxazolium)-1-propanesu...           0.0
# Succinic acid, di(4-fluorophenethyl) ester                   0.0
# Isonicotinamide, N-(2,5-dioxo-1-phenethyl-4-tri...           0.0
# Carbamodithioic acid, dibutyl-, propyl ester                 0.0
#
#                                                     Auto_1_pm_df  \
# Cyclopentanol, 1-ethyl-                                 0.000000
# Dicyclopropyl carbinol                                  0.000000
# Sebacic acid, di(4-trifluoromethoxybenzyl) ester        0.000000
# Cyclohexanecarboxylic acid, 1-cyclohpentylethyl...      0.000000
# N,N',N''-Tris(3-methylthioureidocarbamyl)phosph...      0.000000
# ...                                                          ...
# Aziridine, 2-hexyl-                                     0.000000
# 3-(2-Methylnaphtho[1,2-d]oxazolium)-1-propanesu...      0.000000
# Succinic acid, di(4-fluorophenethyl) ester              0.000000
# Isonicotinamide, N-(2,5-dioxo-1-phenethyl-4-tri...      0.006168
# Carbamodithioic acid, dibutyl-, propyl ester            0.000000
#
#                                                     Zafira_2_gp_df  \
# Cyclopentanol, 1-ethyl-                                   0.000000
# Dicyclopropyl carbinol                                    0.000000
# Sebacic acid, di(4-trifluoromethoxybenzyl) ester          0.000000
# Cyclohexanecarboxylic acid, 1-cyclohpentylethyl...        0.000000
# N,N',N''-Tris(3-methylthioureidocarbamyl)phosph...        0.015577
# ...                                                            ...
# Aziridine, 2-hexyl-                                       0.000000
# 3-(2-Methylnaphtho[1,2-d]oxazolium)-1-propanesu...        0.000000
# Succinic acid, di(4-fluorophenethyl) ester                0.000000
# Isonicotinamide, N-(2,5-dioxo-1-phenethyl-4-tri...        0.000000
# Carbamodithioic acid, dibutyl-, propyl ester              0.000000
#
#                                                     Zafira_1_gp_df  \
# Cyclopentanol, 1-ethyl-                                   0.000000
# Dicyclopropyl carbinol                                    0.000000
# Sebacic acid, di(4-trifluoromethoxybenzyl) ester          0.000000
# Cyclohexanecarboxylic acid, 1-cyclohpentylethyl...        0.000000
# N,N',N''-Tris(3-methylthioureidocarbamyl)phosph...        0.000000
# ...                                                            ...
# Aziridine, 2-hexyl-                                       0.000000
# 3-(2-Methylnaphtho[1,2-d]oxazolium)-1-propanesu...        0.000000
# Succinic acid, di(4-fluorophenethyl) ester                0.000000
# Isonicotinamide, N-(2,5-dioxo-1-phenethyl-4-tri...        0.003962
# Carbamodithioic acid, dibutyl-, propyl ester              0.000000
#
#                                                     Zafira_2_pm_df  \
# Cyclopentanol, 1-ethyl-                                        0.0
# Dicyclopropyl carbinol                                         0.0
# Sebacic acid, di(4-trifluoromethoxybenzyl) ester               0.0
# Cyclohexanecarboxylic acid, 1-cyclohpentylethyl...             0.0
# N,N',N''-Tris(3-methylthioureidocarbamyl)phosph...             0.0
# ...                                                            ...
# Aziridine, 2-hexyl-                                            0.0
# 3-(2-Methylnaphtho[1,2-d]oxazolium)-1-propanesu...             0.0
# Succinic acid, di(4-fluorophenethyl) ester                     0.0
# Isonicotinamide, N-(2,5-dioxo-1-phenethyl-4-tri...             0.0
# Carbamodithioic acid, dibutyl-, propyl ester                   0.0
#
#                                                     Zafira_1_pm_df  \
# Cyclopentanol, 1-ethyl-                                        0.0
# Dicyclopropyl carbinol                                         0.0
# Sebacic acid, di(4-trifluoromethoxybenzyl) ester               0.0
# Cyclohexanecarboxylic acid, 1-cyclohpentylethyl...             0.0
# N,N',N''-Tris(3-methylthioureidocarbamyl)phosph...             0.0
# ...                                                            ...
# Aziridine, 2-hexyl-                                            0.0
# 3-(2-Methylnaphtho[1,2-d]oxazolium)-1-propanesu...             0.0
# Succinic acid, di(4-fluorophenethyl) ester                     0.0
# Isonicotinamide, N-(2,5-dioxo-1-phenethyl-4-tri...             0.0
# Carbamodithioic acid, dibutyl-, propyl ester                   0.0
#
#                                                     U181_60k_df  U181_120k_df  \
# Cyclopentanol, 1-ethyl-                                0.000000      0.000000
# Dicyclopropyl carbinol                                 0.011698      0.000000
# Sebacic acid, di(4-trifluoromethoxybenzyl) ester       0.000000      0.000000
# Cyclohexanecarboxylic acid, 1-cyclohpentylethyl...     0.006286      0.000000
# N,N',N''-Tris(3-methylthioureidocarbamyl)phosph...     0.000000      0.000000
# ...                                                         ...           ...
# Aziridine, 2-hexyl-                                    0.000000      0.000000
# 3-(2-Methylnaphtho[1,2-d]oxazolium)-1-propanesu...     0.000000      0.000312
# Succinic acid, di(4-fluorophenethyl) ester             0.000000      0.000000
# Isonicotinamide, N-(2,5-dioxo-1-phenethyl-4-tri...     0.000000      0.000000
# Carbamodithioic acid, dibutyl-, propyl ester           0.001222      0.009516
#
#                                                      U166_df   U164_df
# Cyclopentanol, 1-ethyl-                             0.000000  0.026972
# Dicyclopropyl carbinol                              0.000000  0.000000
# Sebacic acid, di(4-trifluoromethoxybenzyl) ester    0.000049  0.000000
# Cyclohexanecarboxylic acid, 1-cyclohpentylethyl...  0.000000  0.000000
# N,N',N''-Tris(3-methylthioureidocarbamyl)phosph...  0.000000  0.000000
# ...                                                      ...       ...
# Aziridine, 2-hexyl-                                 0.000000  0.000000
# 3-(2-Methylnaphtho[1,2-d]oxazolium)-1-propanesu...  0.000000  0.000000
# Succinic acid, di(4-fluorophenethyl) ester          0.000000  0.000000
# Isonicotinamide, N-(2,5-dioxo-1-phenethyl-4-tri...  0.000000  0.000000
# Carbamodithioic acid, dibutyl-, propyl ester        0.000261  0.000000
#
# [6707 rows x 19 columns]

# %%
duplicated_rows = compound_sample_df[compound_sample_df.duplicated(subset='Formula (mol ion)', keep=False)]
complete_duplicated_rows = complete_compound_sample_df[complete_compound_sample_df.duplicated(subset='Formula (mol ion)', keep=False)]
# Display the resulting dataframe with duplicated rows
print(duplicated_rows)
# Out:
#                                                    Formula (mol ion)  \
# Heptadecane                                                   C17H36
# 2-Butanone, 4-(dimethylamino)-3-methyl-                      C7H15NO
# 1-(Furan-2-yl)-4-methylpentan-1-one                         C10H14O2
# Carbamic acid, 4-methoxyphenyl-, allyl ester               C11H13NO3
# Ethylidenecyclobutane                                          C6H10
# ...                                                              ...
# Cumenyl tiglate, m-                                         C14H18O2
# Cinoxate                                                    C14H18O4
# 2,2'-Oxybis(ethane-2,1-diyl) bis(2-methylbutano...          C14H26O5
# 2,5-Cyclohexadiene-1,4-dione, 2,6-bis(1,1-dimet...          C14H20O2
# 5'-Methoxyauraptene                                         C20H24O4
#
#                                                     Auto_5_gp_df  \
# Heptadecane                                                  0.0
# 2-Butanone, 4-(dimethylamino)-3-methyl-                      0.0
# 1-(Furan-2-yl)-4-methylpentan-1-one                          0.0
# Carbamic acid, 4-methoxyphenyl-, allyl ester                 0.0
# Ethylidenecyclobutane                                        0.0
# ...                                                          ...
# Cumenyl tiglate, m-                                          0.0
# Cinoxate                                                     0.0
# 2,2'-Oxybis(ethane-2,1-diyl) bis(2-methylbutano...           0.0
# 2,5-Cyclohexadiene-1,4-dione, 2,6-bis(1,1-dimet...           0.0
# 5'-Methoxyauraptene                                          0.0
#
#                                                     Auto_4_gp_df  \
# Heptadecane                                             0.000000
# 2-Butanone, 4-(dimethylamino)-3-methyl-                 0.000000
# 1-(Furan-2-yl)-4-methylpentan-1-one                     0.000000
# Carbamic acid, 4-methoxyphenyl-, allyl ester            0.000000
# Ethylidenecyclobutane                                   0.000000
# ...                                                          ...
# Cumenyl tiglate, m-                                     0.016038
# Cinoxate                                                0.000000
# 2,2'-Oxybis(ethane-2,1-diyl) bis(2-methylbutano...      0.000000
# 2,5-Cyclohexadiene-1,4-dione, 2,6-bis(1,1-dimet...      0.000000
# 5'-Methoxyauraptene                                     0.000000
#
#                                                     Auto_3_gp_df  \
# Heptadecane                                             0.203217
# 2-Butanone, 4-(dimethylamino)-3-methyl-                 0.054954
# 1-(Furan-2-yl)-4-methylpentan-1-one                     0.000000
# Carbamic acid, 4-methoxyphenyl-, allyl ester            0.000000
# Ethylidenecyclobutane                                   0.000000
# ...                                                          ...
# Cumenyl tiglate, m-                                     0.000000
# Cinoxate                                                0.000000
# 2,2'-Oxybis(ethane-2,1-diyl) bis(2-methylbutano...      0.000000
# 2,5-Cyclohexadiene-1,4-dione, 2,6-bis(1,1-dimet...      0.269945
# 5'-Methoxyauraptene                                     0.000000
#
#                                                     Auto_2_gp_df  \
# Heptadecane                                                  0.0
# 2-Butanone, 4-(dimethylamino)-3-methyl-                      0.0
# 1-(Furan-2-yl)-4-methylpentan-1-one                          0.0
# Carbamic acid, 4-methoxyphenyl-, allyl ester                 0.0
# Ethylidenecyclobutane                                        0.0
# ...                                                          ...
# Cumenyl tiglate, m-                                          0.0
# Cinoxate                                                     0.0
# 2,2'-Oxybis(ethane-2,1-diyl) bis(2-methylbutano...           0.0
# 2,5-Cyclohexadiene-1,4-dione, 2,6-bis(1,1-dimet...           0.0
# 5'-Methoxyauraptene                                          0.0
#
#                                                     Auto_1_gp_df  \
# Heptadecane                                             0.000000
# 2-Butanone, 4-(dimethylamino)-3-methyl-                 0.000000
# 1-(Furan-2-yl)-4-methylpentan-1-one                     0.000000
# Carbamic acid, 4-methoxyphenyl-, allyl ester            0.008367
# Ethylidenecyclobutane                                   0.000000
# ...                                                          ...
# Cumenyl tiglate, m-                                     0.000000
# Cinoxate                                                0.047845
# 2,2'-Oxybis(ethane-2,1-diyl) bis(2-methylbutano...      0.000000
# 2,5-Cyclohexadiene-1,4-dione, 2,6-bis(1,1-dimet...      0.000000
# 5'-Methoxyauraptene                                     0.000000
#
#                                                     Auto_5_pm_df  \
# Heptadecane                                                  0.0
# 2-Butanone, 4-(dimethylamino)-3-methyl-                      0.0
# 1-(Furan-2-yl)-4-methylpentan-1-one                          0.0
# Carbamic acid, 4-methoxyphenyl-, allyl ester                 0.0
# Ethylidenecyclobutane                                        0.0
# ...                                                          ...
# Cumenyl tiglate, m-                                          0.0
# Cinoxate                                                     0.0
# 2,2'-Oxybis(ethane-2,1-diyl) bis(2-methylbutano...           0.0
# 2,5-Cyclohexadiene-1,4-dione, 2,6-bis(1,1-dimet...           0.0
# 5'-Methoxyauraptene                                          0.0
#
#                                                     Auto_4_pm_df  \
# Heptadecane                                             0.000000
# 2-Butanone, 4-(dimethylamino)-3-methyl-                 0.000000
# 1-(Furan-2-yl)-4-methylpentan-1-one                     0.007488
# Carbamic acid, 4-methoxyphenyl-, allyl ester            0.000000
# Ethylidenecyclobutane                                   0.000000
# ...                                                          ...
# Cumenyl tiglate, m-                                     0.000000
# Cinoxate                                                0.000000
# 2,2'-Oxybis(ethane-2,1-diyl) bis(2-methylbutano...      0.000000
# 2,5-Cyclohexadiene-1,4-dione, 2,6-bis(1,1-dimet...      0.000000
# 5'-Methoxyauraptene                                     0.000000
#
#                                                     Auto_3_pm_df  \
# Heptadecane                                             0.000000
# 2-Butanone, 4-(dimethylamino)-3-methyl-                 0.000000
# 1-(Furan-2-yl)-4-methylpentan-1-one                     0.000000
# Carbamic acid, 4-methoxyphenyl-, allyl ester            0.000000
# Ethylidenecyclobutane                                   0.001611
# ...                                                          ...
# Cumenyl tiglate, m-                                     0.000000
# Cinoxate                                                0.000000
# 2,2'-Oxybis(ethane-2,1-diyl) bis(2-methylbutano...      0.000000
# 2,5-Cyclohexadiene-1,4-dione, 2,6-bis(1,1-dimet...      0.000000
# 5'-Methoxyauraptene                                     0.053628
#
#                                                     Auto_2_pm_df  Auto_1_pm_df
# Heptadecane                                             0.000000           0.0
# 2-Butanone, 4-(dimethylamino)-3-methyl-                 0.000000           0.0
# 1-(Furan-2-yl)-4-methylpentan-1-one                     0.000000           0.0
# Carbamic acid, 4-methoxyphenyl-, allyl ester            0.000000           0.0
# Ethylidenecyclobutane                                   0.000000           0.0
# ...                                                          ...           ...
# Cumenyl tiglate, m-                                     0.000000           0.0
# Cinoxate                                                0.000000           0.0
# 2,2'-Oxybis(ethane-2,1-diyl) bis(2-methylbutano...      0.003546           0.0
# 2,5-Cyclohexadiene-1,4-dione, 2,6-bis(1,1-dimet...      0.000000           0.0
# 5'-Methoxyauraptene                                     0.000000           0.0
#
# [1357 rows x 11 columns]

# %%
combined_duplicated_rows = pd.DataFrame(columns=duplicated_rows.columns)

for formula, group in duplicated_rows.groupby('Formula (mol ion)'):
    # Initialize the selected row with the row having the minimum non-zero values
    selected_row = group.loc[group.ne(0).sum(axis=1).idxmin()].copy()

    # Iterate over columns to check the condition
    for col in group.columns[1:]:  # Skip the 'Formula (mol ion)' column
        # Check if there's a zero in the same column for the selected row
        if selected_row[col] == 0:
            #print(f"Formula: {formula}, Column: {col}")

            # Find the row with the maximum non-zero values across all columns
            max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]

            # Combine the rows if there are two non-zero values in the same column
            selected_row[col] = max_nonzero_row[col]

    # Add the selected row to the combined dataframe
    combined_duplicated_rows = combined_duplicated_rows.append(selected_row)

# Display the resulting dataframe with combined duplicated rows
#print(combined_duplicated_rows)

# Save the resulting dataframe to a CSV file
combined_duplicated_rows.to_csv('/content/drive/My Drive/unknown_screening_data/Hitlist_non_duplicates_total_reduction.csv')
# Out:
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)
# <ipython-input-23-bea69445ae65>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-23-bea69445ae65>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_duplicated_rows = combined_duplicated_rows.append(selected_row)

# %%
complete_combined_duplicated_rows = pd.DataFrame(columns=duplicated_rows.columns)

for formula, group in complete_duplicated_rows.groupby('Formula (mol ion)'):
    # Initialize the selected row with the row having the minimum non-zero values
    selected_row = group.loc[group.ne(0).sum(axis=1).idxmin()].copy()

    # Iterate over columns to check the condition
    for col in group.columns[1:]:  # Skip the 'Formula (mol ion)' column
        # Check if there's a zero in the same column for the selected row
        if selected_row[col] == 0:
            #print(f"Formula: {formula}, Column: {col}")

            # Find the row with the maximum non-zero values across all columns
            max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]

            # Combine the rows if there are two non-zero values in the same column
            selected_row[col] = max_nonzero_row[col]

    # Add the selected row to the combined dataframe
    complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)

# Save the resulting dataframe to a CSV file
complete_combined_duplicated_rows.to_csv('/content/drive/My Drive/unknown_screening_data/Hitlist_non_duplicates_total_reduction_complete.csv')
# Out:
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# ...
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)
# <ipython-input-24-7e7fb53f859e>:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_nonzero_row = group.loc[group.sum(axis=1).idxmax()]
# <ipython-input-24-7e7fb53f859e>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   complete_combined_duplicated_rows = complete_combined_duplicated_rows.append(selected_row)

# %%
compound_sample_df_no_duplicates = compound_sample_df.drop_duplicates(subset='Formula (mol ion)', keep=False)

# Concatenate the modified compound_sample_df with the combined_duplicated_rows DataFrame
final_result = pd.concat([compound_sample_df_no_duplicates, combined_duplicated_rows], ignore_index=False)

print(final_result.shape)

# Save the resulting dataframe to a CSV file
final_result.to_csv('/content/drive/My Drive/unknown_screening_data/Hitlist_non_duplicates_final.csv')
# Out:
# (1625, 11)

# %%
complete_compound_sample_df_no_duplicates = complete_compound_sample_df.drop_duplicates(subset='Formula (mol ion)', keep=False)

# Concatenate the modified compound_sample_df with the combined_duplicated_rows DataFrame
complete_final_result = pd.concat([complete_compound_sample_df_no_duplicates, complete_combined_duplicated_rows], ignore_index=False)

print(complete_final_result.shape)

# Save the resulting dataframe to a CSV file
complete_final_result.to_csv('/content/drive/My Drive/unknown_screening_data/Hitlist_non_duplicates_final_complete.csv')
# Out:
# (3506, 19)

# %%
detection_frequency = final_result.iloc[:, 1:].gt(0).sum(axis=1) / (final_result.shape[1] - 1)

# Insert the new column after the 'Formula (mol ion)' column
final_result.insert(1, 'Detection Frequency', detection_frequency)
print(final_result.shape)
# Save the result to a new CSV file
final_result.to_csv('/content/drive/My Drive/unknown_screening_data/Result_With_Detection_Frequency.csv')
# Out:
# (1625, 12)

# %%
complete_detection_frequency = complete_final_result.iloc[:, 1:].gt(0).sum(axis=1) / (complete_final_result.shape[1] - 1)

# Insert the new column after the 'Formula (mol ion)' column
complete_final_result.insert(1, 'Detection Frequency', detection_frequency)
print(complete_final_result.shape)
# Save the result to a new CSV file
complete_final_result.to_csv('/content/drive/My Drive/unknown_screening_data/Result_With_Detection_Frequency_complete.csv')
# Out:
# (3506, 20)

# %%
detection_frequency_threshold = 0.3  # Adjust this threshold as needed

# Filter rows based on the detection frequency threshold
filtered_result = final_result[final_result['Detection Frequency'] >= detection_frequency_threshold]

print(filtered_result.shape)
# Save the filtered result to a new CSV file
filtered_result.to_csv('/content/drive/My Drive/unknown_screening_data/Filtered_Result_With_Detection_Frequency.csv')
# Out:
# (123, 12)

# %%
detection_frequency_threshold = 0.2  # Adjust this threshold as needed

# Filter rows based on the detection frequency threshold
complete_filtered_result = complete_final_result[complete_final_result['Detection Frequency'] >= detection_frequency_threshold]

print(complete_filtered_result.shape)
# Save the filtered result to a new CSV file
complete_filtered_result.to_csv('/content/drive/My Drive/unknown_screening_data/Filtered_Result_With_Detection_Frequency_complete.csv')
# Out:
# (189, 20)

# %%
sorted_df = final_result.sort_values(by='Detection Frequency', ascending=False)
print(sorted_df.head())
sorted_df.to_csv('/content/drive/My Drive/unknown_screening_data/Detection_frequency_non_dublicates.csv')
# Out:
#                                                    Formula (mol ion)  \
# Cyclopenta[g]-2-benzopyran, 1,3,4,6,7,8-hexahyd...           C18H26O
# Succinic acid, 2-methylpent-3-yl phenethyl ester            C18H26O4
# 3-Ethyl-4,4-dimethyl-2-(2-methylpropenyl)cycloh...           C14H22O
# 3-(2,4-Dimethoxyphenyl)butan-2-one                          C12H16O3
# Benzenamine, 4-(1,1,3,3-tetramethylbutyl)-N-[4-...           C28H43N
#
#                                                     Detection Frequency  \
# Cyclopenta[g]-2-benzopyran, 1,3,4,6,7,8-hexahyd...                  1.0
# Succinic acid, 2-methylpent-3-yl phenethyl ester                    0.7
# 3-Ethyl-4,4-dimethyl-2-(2-methylpropenyl)cycloh...                  0.7
# 3-(2,4-Dimethoxyphenyl)butan-2-one                                  0.7
# Benzenamine, 4-(1,1,3,3-tetramethylbutyl)-N-[4-...                  0.6
#
#                                                     Auto_5_gp_df  \
# Cyclopenta[g]-2-benzopyran, 1,3,4,6,7,8-hexahyd...      0.020710
# Succinic acid, 2-methylpent-3-yl phenethyl ester        0.000000
# 3-Ethyl-4,4-dimethyl-2-(2-methylpropenyl)cycloh...      0.000000
# 3-(2,4-Dimethoxyphenyl)butan-2-one                      0.000000
# Benzenamine, 4-(1,1,3,3-tetramethylbutyl)-N-[4-...      0.478398
#
#                                                     Auto_4_gp_df  \
# Cyclopenta[g]-2-benzopyran, 1,3,4,6,7,8-hexahyd...      0.023002
# Succinic acid, 2-methylpent-3-yl phenethyl ester        0.630627
# 3-Ethyl-4,4-dimethyl-2-(2-methylpropenyl)cycloh...      0.075751
# 3-(2,4-Dimethoxyphenyl)butan-2-one                      0.000000
# Benzenamine, 4-(1,1,3,3-tetramethylbutyl)-N-[4-...      0.440723
#
#                                                     Auto_3_gp_df  \
# Cyclopenta[g]-2-benzopyran, 1,3,4,6,7,8-hexahyd...      0.062474
# Succinic acid, 2-methylpent-3-yl phenethyl ester        0.084026
# 3-Ethyl-4,4-dimethyl-2-(2-methylpropenyl)cycloh...      0.000000
# 3-(2,4-Dimethoxyphenyl)butan-2-one                      0.035406
# Benzenamine, 4-(1,1,3,3-tetramethylbutyl)-N-[4-...      0.686774
#
#                                                     Auto_2_gp_df  \
# Cyclopenta[g]-2-benzopyran, 1,3,4,6,7,8-hexahyd...      0.018509
# Succinic acid, 2-methylpent-3-yl phenethyl ester        0.492219
# 3-Ethyl-4,4-dimethyl-2-(2-methylpropenyl)cycloh...      5.698121
# 3-(2,4-Dimethoxyphenyl)butan-2-one                      0.007161
# Benzenamine, 4-(1,1,3,3-tetramethylbutyl)-N-[4-...      0.009769
#
#                                                     Auto_1_gp_df  \
# Cyclopenta[g]-2-benzopyran, 1,3,4,6,7,8-hexahyd...      0.026337
# Succinic acid, 2-methylpent-3-yl phenethyl ester        1.895849
# 3-Ethyl-4,4-dimethyl-2-(2-methylpropenyl)cycloh...      0.281784
# 3-(2,4-Dimethoxyphenyl)butan-2-one                      0.033341
# Benzenamine, 4-(1,1,3,3-tetramethylbutyl)-N-[4-...      2.696240
#
#                                                     Auto_5_pm_df  \
# Cyclopenta[g]-2-benzopyran, 1,3,4,6,7,8-hexahyd...      0.011045
# Succinic acid, 2-methylpent-3-yl phenethyl ester        0.000000
# 3-Ethyl-4,4-dimethyl-2-(2-methylpropenyl)cycloh...      0.007582
# 3-(2,4-Dimethoxyphenyl)butan-2-one                      0.000000
# Benzenamine, 4-(1,1,3,3-tetramethylbutyl)-N-[4-...      0.000000
#
#                                                     Auto_4_pm_df  \
# Cyclopenta[g]-2-benzopyran, 1,3,4,6,7,8-hexahyd...      0.008268
# Succinic acid, 2-methylpent-3-yl phenethyl ester        0.372327
# 3-Ethyl-4,4-dimethyl-2-(2-methylpropenyl)cycloh...      0.890661
# 3-(2,4-Dimethoxyphenyl)butan-2-one                      0.007111
# Benzenamine, 4-(1,1,3,3-tetramethylbutyl)-N-[4-...      0.000000
#
#                                                     Auto_3_pm_df  \
# Cyclopenta[g]-2-benzopyran, 1,3,4,6,7,8-hexahyd...      0.015836
# Succinic acid, 2-methylpent-3-yl phenethyl ester        2.035997
# 3-Ethyl-4,4-dimethyl-2-(2-methylpropenyl)cycloh...      0.000000
# 3-(2,4-Dimethoxyphenyl)butan-2-one                      0.013401
# Benzenamine, 4-(1,1,3,3-tetramethylbutyl)-N-[4-...      0.459409
#
#                                                     Auto_2_pm_df  Auto_1_pm_df
# Cyclopenta[g]-2-benzopyran, 1,3,4,6,7,8-hexahyd...      0.021498      0.038783
# Succinic acid, 2-methylpent-3-yl phenethyl ester        0.402487      0.000000
# 3-Ethyl-4,4-dimethyl-2-(2-methylpropenyl)cycloh...      0.390869      0.054656
# 3-(2,4-Dimethoxyphenyl)butan-2-one                      0.005988      0.008934
# Benzenamine, 4-(1,1,3,3-tetramethylbutyl)-N-[4-...      0.000000      0.000000

# %%
complete_sorted_df = complete_final_result.sort_values(by='Detection Frequency', ascending=False)
print(complete_sorted_df.head())
complete_sorted_df.to_csv('/content/drive/My Drive/unknown_screening_data/Detection_frequency_non_dublicates_complete.csv')
# Out:
#                                                    Formula (mol ion)  \
# Propanoyl fluoride, 2,3,3,3-tetrafluoro-2-[1,1,...           C9F18O3
# 4-pentylphenyl 4-propylbenzoate                             C21H26O2
# 3-(1-Ethoxy-ethoxy)-butan-1-ol                               C8H18O3
# 2-Ethynyl pyridine                                             C7H5N
# Tetraethoxymethane                                           C9H20O4
#
#                                                     Detection Frequency  \
# Propanoyl fluoride, 2,3,3,3-tetrafluoro-2-[1,1,...                  0.6
# 4-pentylphenyl 4-propylbenzoate                                     0.6
# 3-(1-Ethoxy-ethoxy)-butan-1-ol                                      0.6
# 2-Ethynyl pyridine                                                  0.6
# Tetraethoxymethane                                                  0.6
#
#                                                     Auto_5_gp_df  \
# Propanoyl fluoride, 2,3,3,3-tetrafluoro-2-[1,1,...      0.002785
# 4-pentylphenyl 4-propylbenzoate                         0.000000
# 3-(1-Ethoxy-ethoxy)-butan-1-ol                          0.470541
# 2-Ethynyl pyridine                                      0.257023
# Tetraethoxymethane                                      0.208427
#
#                                                     Auto_4_gp_df  \
# Propanoyl fluoride, 2,3,3,3-tetrafluoro-2-[1,1,...      0.000000
# 4-pentylphenyl 4-propylbenzoate                         0.167154
# 3-(1-Ethoxy-ethoxy)-butan-1-ol                          0.000000
# 2-Ethynyl pyridine                                      0.052449
# Tetraethoxymethane                                      0.000000
#
#                                                     Auto_3_gp_df  \
# Propanoyl fluoride, 2,3,3,3-tetrafluoro-2-[1,1,...      0.000000
# 4-pentylphenyl 4-propylbenzoate                         0.000000
# 3-(1-Ethoxy-ethoxy)-butan-1-ol                          0.000000
# 2-Ethynyl pyridine                                      0.043961
# Tetraethoxymethane                                      0.000000
#
#                                                     Auto_2_gp_df  \
# Propanoyl fluoride, 2,3,3,3-tetrafluoro-2-[1,1,...      0.000000
# 4-pentylphenyl 4-propylbenzoate                         0.047192
# 3-(1-Ethoxy-ethoxy)-butan-1-ol                          0.000000
# 2-Ethynyl pyridine                                      0.248549
# Tetraethoxymethane                                      0.000000
#
#                                                     Auto_1_gp_df  \
# Propanoyl fluoride, 2,3,3,3-tetrafluoro-2-[1,1,...      0.000000
# 4-pentylphenyl 4-propylbenzoate                         0.015757
# 3-(1-Ethoxy-ethoxy)-butan-1-ol                          0.017573
# 2-Ethynyl pyridine                                      0.505677
# Tetraethoxymethane                                      0.000000
#
#                                                     Auto_5_pm_df  \
# Propanoyl fluoride, 2,3,3,3-tetrafluoro-2-[1,1,...      0.017485
# 4-pentylphenyl 4-propylbenzoate                         0.000000
# 3-(1-Ethoxy-ethoxy)-butan-1-ol                          0.521804
# 2-Ethynyl pyridine                                      0.006693
# Tetraethoxymethane                                      0.026604
#
#                                                     Auto_4_pm_df  \
# Propanoyl fluoride, 2,3,3,3-tetrafluoro-2-[1,1,...      0.004850
# 4-pentylphenyl 4-propylbenzoate                         0.016257
# 3-(1-Ethoxy-ethoxy)-butan-1-ol                          0.041571
# 2-Ethynyl pyridine                                      0.000000
# Tetraethoxymethane                                      0.040975
#
#                                                     Auto_3_pm_df  \
# Propanoyl fluoride, 2,3,3,3-tetrafluoro-2-[1,1,...      0.007075
# 4-pentylphenyl 4-propylbenzoate                         0.073950
# 3-(1-Ethoxy-ethoxy)-butan-1-ol                          0.000000
# 2-Ethynyl pyridine                                      0.000000
# Tetraethoxymethane                                      0.297338
#
#                                                     Auto_2_pm_df  \
# Propanoyl fluoride, 2,3,3,3-tetrafluoro-2-[1,1,...      0.001359
# 4-pentylphenyl 4-propylbenzoate                         0.008428
# 3-(1-Ethoxy-ethoxy)-butan-1-ol                          0.281242
# 2-Ethynyl pyridine                                      0.000000
# Tetraethoxymethane                                      0.056198
#
#                                                     Auto_1_pm_df  \
# Propanoyl fluoride, 2,3,3,3-tetrafluoro-2-[1,1,...      0.016450
# 4-pentylphenyl 4-propylbenzoate                         0.000000
# 3-(1-Ethoxy-ethoxy)-butan-1-ol                          0.232384
# 2-Ethynyl pyridine                                      0.000000
# Tetraethoxymethane                                      0.093662
#
#                                                     Zafira_2_gp_df  \
# Propanoyl fluoride, 2,3,3,3-tetrafluoro-2-[1,1,...        0.000000
# 4-pentylphenyl 4-propylbenzoate                           0.007403
# 3-(1-Ethoxy-ethoxy)-butan-1-ol                            0.000000
# 2-Ethynyl pyridine                                        0.000000
# Tetraethoxymethane                                        0.000000
#
#                                                     Zafira_1_gp_df  \
# Propanoyl fluoride, 2,3,3,3-tetrafluoro-2-[1,1,...        0.000000
# 4-pentylphenyl 4-propylbenzoate                           0.015993
# 3-(1-Ethoxy-ethoxy)-butan-1-ol                            0.000000
# 2-Ethynyl pyridine                                        0.000000
# Tetraethoxymethane                                        0.000000
#
#                                                     Zafira_2_pm_df  \
# Propanoyl fluoride, 2,3,3,3-tetrafluoro-2-[1,1,...        0.000000
# 4-pentylphenyl 4-propylbenzoate                           0.001194
# 3-(1-Ethoxy-ethoxy)-butan-1-ol                            0.000000
# 2-Ethynyl pyridine                                        0.000000
# Tetraethoxymethane                                        0.025825
#
#                                                     Zafira_1_pm_df  \
# Propanoyl fluoride, 2,3,3,3-tetrafluoro-2-[1,1,...        0.000000
# 4-pentylphenyl 4-propylbenzoate                           0.001445
# 3-(1-Ethoxy-ethoxy)-butan-1-ol                            0.000000
# 2-Ethynyl pyridine                                        0.000000
# Tetraethoxymethane                                        0.013805
#
#                                                     U181_60k_df  U181_120k_df  \
# Propanoyl fluoride, 2,3,3,3-tetrafluoro-2-[1,1,...     0.000000      0.000000
# 4-pentylphenyl 4-propylbenzoate                        0.000414      0.000000
# 3-(1-Ethoxy-ethoxy)-butan-1-ol                         0.000000      0.000000
# 2-Ethynyl pyridine                                     0.000567      0.000615
# Tetraethoxymethane                                     0.000000      0.000000
#
#                                                     U166_df  U164_df
# Propanoyl fluoride, 2,3,3,3-tetrafluoro-2-[1,1,...      0.0      0.0
# 4-pentylphenyl 4-propylbenzoate                         0.0      0.0
# 3-(1-Ethoxy-ethoxy)-butan-1-ol                          0.0      0.0
# 2-Ethynyl pyridine                                      0.0      0.0
# Tetraethoxymethane                                      0.0      0.0
